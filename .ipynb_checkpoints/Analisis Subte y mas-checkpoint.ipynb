# %%
import datetime as datetime
import pandas as pd
import numpy as np
#import seaborn as sns
import matplotlib.pyplot as plt

#Permite ver los graficos sin colocar plt.show
# %matplotlib inline 

plt.style.use('default')
#plt.rcParams['figure.figsize'] = (15, 5)


#Funcion para calcular distancias entre coordenadas (lat, lon)
from math import sin,cos,sqrt,asin,pi

#Formula del Harvesine sacada de
#https://joseguerreroa.wordpress.com/2012/11/13/distancia-entre-dos-puntos-de-la-superficie-terrestre-mediante-la-formula-de-haversine-con-python/
#coord = (lat, long)
def distancia(coord1, coord2):
    rTierra = 6374000 #metros
    c = pi/180 #para pasar a raddianes
    d = 2*rTierra*asin(sqrt(sin(c*(coord2[0]-coord1[0])/2)**2 + cos(c*coord1[0])*cos(c*coord2[0])*sin(c*(coord2[1]-coord1[1])/2)**2))
    return d

#reg = created_on, place_name, lat, lon, price_usd_per_m2
def distanciaANuevasEstaciones(reg):
    created_on, place_name, lat, lon, price_usd_per_m2 = reg
    geoPos = lat, lon
    #Ubicacion de las estaciones
    Cordoba = (-34.598691, -58.403841) #Inicio Obras: 17 ene 2012 - Inauguracion: 18 dic 2015
    SantaFe = (-34.594848, -58.402517) #Inicio Obras: 17 ene 2012 - Inauguracion: 12 jul 2016
    LasHeras = (-34.587879, -58.397970) #Inicio Obras: 17 ene 2012 - Inauguracion: 18 dic 2015

    distACordoba = distancia(geoPos, Cordoba)
    distASantaFe = distancia(geoPos, SantaFe)
    distALasHeras = distancia(geoPos, LasHeras)
    

    return min(distACordoba, distASantaFe, distALasHeras)

data17 = pd.read_csv("properati-AR-2017-08-01-properties-sell.csv", low_memory = False)
data16 = pd.read_csv("properati-AR-2016-12-01-properties-sell.csv", low_memory = False)
data15 = pd.read_csv("properati-AR-2015-12-01-properties-sell.csv", low_memory = False)
data14 = pd.read_csv("properati-AR-2015-12-01-properties-sell.csv", low_memory = False)
frames = [data14, data15, data16, data17]
data = pd.concat(frames)
data.head()
# Out:
#   country_name  created_on currency  \
# 0          NaN  2012-08-08      NaN
# 1          NaN  2012-08-08      NaN
# 2          NaN  2012-09-19      USD
# 3          NaN  2012-10-10      USD
# 4          NaN  2012-10-10      USD
#
#                                          description expenses  \
# 0  Excelente depto. en planta alta con patio y co...      NaN
# 1  Venta chalet 4 ambientes en Villa Ballester  e...      NaN
# 2  CASA CON LOCAL EN VENTA EN PADUA.  2 DORMITORI...      NaN
# 3  2 AMBIENTES, VENTA, VILLA CRESPO    CON RENTA....       50
# 4  CASA, VENTA, VILLA CRESPO    "EXCELENTE CASA E...      NaN
#
#                                                extra  floor  geonames_id   id  \
# 0  {"images":["http://www.amaira.com.ar/buscador/...    NaN    3433778.0  NaN
# 1  {"images":["http://www.amaira.com.ar/buscador/...    NaN    3427467.0  NaN
# 2  {"images":["http://www.amaira.com.ar/buscador/...    NaN    3429244.0  NaN
# 3  {"apto_profesional":true,"images":["http://www...    1.0    3427458.0  NaN
# 4  {"baulera":true,"dependencia":true,"apto_profe...    NaN    3430234.0  NaN
#
#                                      image_thumbnail          ...            \
# 0  http://thumbs3.properati.com/2/hrxzmGbOVe0AAWf...          ...
# 1  http://thumbs3.properati.com/5/a4W8KzDBTc_SzTL...          ...
# 2  http://thumbs3.properati.com/3/4WSbwKA0arL7bbQ...          ...
# 3  http://thumbs3.properati.com/4/hqn-p5RqpJu7eVj...          ...
# 4  http://thumbs3.properati.com/6/szVEIqerNvrkp-o...          ...
#
#    price_aprox_usd price_per_m2  price_usd_per_m2  \
# 0              NaN          NaN               NaN
# 1              NaN          NaN               NaN
# 2         120000.0  1290.322581         360.36036
# 3          76500.0  1912.500000        1912.50000
# 4         570000.0  1727.272727        1425.00000
#
#                                        properati_url property_type rooms  \
# 0  http://general-san-martin-bs-as-g-b-a-zona-nor...     apartment   3.0
# 1  http://villa-ballester.properati.com.ar/be_ven...         house   5.0
# 2  http://san-antonio-de-padua.properati.com.ar/u...         house   NaN
# 3  http://villa-crespo.properati.com.ar/13tz_vent...     apartment   2.0
# 4  http://palermo.properati.com.ar/13v3_venta_dep...     apartment   5.0
#
#    state_name  surface_covered_in_m2  surface_total_in_m2  \
# 0         NaN                    NaN                  NaN
# 1         NaN                  480.0                480.0
# 2         NaN                   93.0                333.0
# 3         NaN                   40.0                 40.0
# 4         NaN                  330.0                400.0
#
#                    title
# 0  DEPARTAMENTO EN VENTA
# 1          CASA EN VENTA
# 2          CASA EN VENTA
# 3  DEPARTAMENTO EN VENTA
# 4  DEPARTAMENTO EN VENTA
#
# [5 rows x 28 columns]

# %%
data.drop_duplicates(subset=['lat', 'lon', 'price_usd_per_m2'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 493527 entries, 0 to 187481
# Data columns (total 28 columns):
# country_name                  245641 non-null object
# created_on                    493527 non-null object
# currency                      410945 non-null object
# description                   493510 non-null object
# expenses                      33353 non-null object
# extra                         247886 non-null object
# floor                         56681 non-null float64
# geonames_id                   419545 non-null float64
# id                            245641 non-null object
# image_thumbnail               486477 non-null object
# lat                           371658 non-null float64
# lat-lon                       371658 non-null object
# lon                           371652 non-null float64
# operation                     493527 non-null object
# place_name                    493463 non-null object
# place_with_parent_names       493527 non-null object
# price                         413289 non-null float64
# price_aprox_local_currency    413289 non-null float64
# price_aprox_usd               413289 non-null float64
# price_per_m2                  337457 non-null float64
# price_usd_per_m2              260452 non-null float64
# properati_url                 493527 non-null object
# property_type                 493527 non-null object
# rooms                         244480 non-null float64
# state_name                    245641 non-null object
# surface_covered_in_m2         389111 non-null float64
# surface_total_in_m2           319555 non-null float64
# title                         493527 non-null object
# dtypes: float64(12), object(16)
# memory usage: 109.2+ MB

# %%
#Solo me quedo con CAP FED y GBA
dataCapGba = data.loc[(data.state_name.str.contains('Capital Federal') | data.state_name.str.contains('G.B.A') ), ['created_on','operation', 'property_type', 'state_name', 'place_name', 'lat', 'lon', 'price', 'surface_total_in_m2', 'surface_covered_in_m2', 'price_usd_per_m2', 'price_per_m2', 'floor', 'rooms', 'expenses', 'description']]

# %%
dataCapGbaMenoresA10K = dataCapGba.loc[dataCapGba['price_usd_per_m2'] < 10000,:]
dataCapGbamayoresA1000 = dataCapGbaMenoresA10K.loc[dataCapGbaMenoresA10K['price_usd_per_m2'] > 1000,:]
dataCapGbamayoresA1000.sort_values('price_usd_per_m2', ascending = False)
# Out:
#         created_on operation property_type                state_name  \
# 97079   2017-05-09      sell         house           Capital Federal
# 92241   2017-04-28      sell     apartment           Capital Federal
# 96840   2017-05-09      sell     apartment           Capital Federal
# 247     2013-05-24      sell     apartment  Bs.As. G.B.A. Zona Norte
# 121426  2017-07-04      sell         house  Bs.As. G.B.A. Zona Norte
# 86357   2017-04-12      sell         house  Bs.As. G.B.A. Zona Norte
# 91033   2017-04-28      sell     apartment  Bs.As. G.B.A. Zona Norte
# 54741   2016-12-01      sell     apartment           Capital Federal
# 32588   2016-12-01      sell     apartment           Capital Federal
# 106661  2017-05-31      sell     apartment           Capital Federal
# 87380   2017-04-18      sell         house  Bs.As. G.B.A. Zona Oeste
# 154679  2017-07-19      sell     apartment           Capital Federal
# 91102   2017-04-28      sell     apartment  Bs.As. G.B.A. Zona Oeste
# 245     2013-05-24      sell     apartment  Bs.As. G.B.A. Zona Norte
# 31249   2016-11-25      sell     apartment           Capital Federal
# 53806   2016-11-25      sell     apartment           Capital Federal
# 32595   2016-12-01      sell     apartment           Capital Federal
# 54747   2016-12-01      sell     apartment           Capital Federal
# 71787   2017-02-14      sell     apartment           Capital Federal
# 98849   2017-05-11      sell     apartment           Capital Federal
# 154660  2017-07-19      sell     apartment           Capital Federal
# 172747  2017-07-19      sell     apartment           Capital Federal
# 63817   2017-01-25      sell         store           Capital Federal
# 130962  2017-07-19      sell     apartment           Capital Federal
# 88599   2017-04-21      sell         store           Capital Federal
# 147737  2017-07-19      sell     apartment           Capital Federal
# 180572  2017-07-27      sell     apartment           Capital Federal
# 91128   2017-04-28      sell     apartment  Bs.As. G.B.A. Zona Oeste
# 71607   2017-02-13      sell     apartment           Capital Federal
# 28634   2016-04-27      sell         store  Bs.As. G.B.A. Zona Norte
# ...            ...       ...           ...                       ...
# 31490   2016-06-09      sell         house  Bs.As. G.B.A. Zona Oeste
# 65135   2017-01-27      sell         house  Bs.As. G.B.A. Zona Norte
# 47450   2016-11-17      sell         house  Bs.As. G.B.A. Zona Norte
# 132508  2017-07-19      sell         house  Bs.As. G.B.A. Zona Norte
# 130191  2017-07-19      sell         house    Bs.As. G.B.A. Zona Sur
# 40584   2016-08-27      sell         house  Bs.As. G.B.A. Zona Norte
# 12994   2016-08-27      sell         house  Bs.As. G.B.A. Zona Norte
# 44420   2016-10-28      sell         house  Bs.As. G.B.A. Zona Norte
# 114592  2017-06-17      sell         house  Bs.As. G.B.A. Zona Oeste
# 77847   2017-03-15      sell         house  Bs.As. G.B.A. Zona Norte
# 43442   2016-11-17      sell     apartment  Bs.As. G.B.A. Zona Norte
# 45960   2016-11-26      sell            PH           Capital Federal
# 19491   2015-10-07      sell         store           Capital Federal
# 34462   2016-12-07      sell         house    Bs.As. G.B.A. Zona Sur
# 12683   2016-08-25      sell         house  Bs.As. G.B.A. Zona Oeste
# 40344   2016-08-25      sell         house  Bs.As. G.B.A. Zona Oeste
# 94787   2017-05-04      sell         house  Bs.As. G.B.A. Zona Norte
# 72637   2017-02-18      sell         house           Capital Federal
# 16465   2015-07-30      sell         house  Bs.As. G.B.A. Zona Oeste
# 90523   2017-04-26      sell            PH  Bs.As. G.B.A. Zona Norte
# 139929  2017-07-19      sell         house    Bs.As. G.B.A. Zona Sur
# 84643   2017-04-06      sell         house  Bs.As. G.B.A. Zona Norte
# 15348   2015-07-30      sell         house  Bs.As. G.B.A. Zona Oeste
# 16190   2015-07-30      sell         house  Bs.As. G.B.A. Zona Oeste
# 94490   2017-05-03      sell     apartment  Bs.As. G.B.A. Zona Norte
# 50798   2016-09-29      sell     apartment  Bs.As. G.B.A. Zona Norte
# 161508  2017-07-19      sell         house  Bs.As. G.B.A. Zona Norte
# 75189   2017-03-02      sell         house  Bs.As. G.B.A. Zona Norte
# 75190   2017-03-02      sell         house  Bs.As. G.B.A. Zona Norte
# 96831   2017-05-09      sell         house  Bs.As. G.B.A. Zona Norte
#
#                       place_name        lat        lon      price  \
# 97079                    Palermo -34.578327 -58.400505  2990000.0
# 92241                      Boedo        NaN        NaN   347850.0
# 96840              Puerto Madero -34.611493 -58.360985  1600000.0
# 247                        Pilar -34.452738 -58.915705   347200.0
# 121426                  Acassuso -34.472209 -58.499679  9900000.0
# 86357                      Tigre        NaN        NaN   198000.0
# 91033   Bs.As. G.B.A. Zona Norte        NaN        NaN   395000.0
# 54741              Palermo Chico -34.576562 -58.404856  2100000.0
# 32588              Palermo Chico -34.576562 -58.404856  2100000.0
# 106661                   Palermo -34.577818 -58.406038  2490000.0
# 87380                Ramos Mejía        NaN        NaN    98000.0
# 154679             Puerto Madero -34.617978 -58.362848   585000.0
# 91102                    Caseros        NaN        NaN   350000.0
# 245                        Pilar -34.452738 -58.915705   359600.0
# 31249                   Belgrano -34.552549 -58.439538  5500000.0
# 53806                   Belgrano -34.552549 -58.439538  5500000.0
# 32595                    Palermo -34.583982 -58.410648  1200000.0
# 54747                    Palermo -34.583982 -58.410648  1200000.0
# 71787              Puerto Madero -34.609931 -58.361219  3200000.0
# 98849                    Palermo -34.579549 -58.407713  1400000.0
# 154660             Puerto Madero -34.617978 -58.362848   386000.0
# 172747             Puerto Madero        NaN        NaN   355953.0
# 63817       Centro / Microcentro -34.603684 -58.381559   250000.0
# 130962                   Palermo        NaN        NaN  3500000.0
# 88599       Centro / Microcentro -34.603684 -58.381559   250000.0
# 147737                   Palermo -34.575780 -58.405806  3100000.0
# 180572             Puerto Madero -34.612109 -58.362547  1820000.0
# 91128                      Morón -34.651763 -58.605267   450000.0
# 71607                   Recoleta -34.590932 -58.384223  2200000.0
# 28634                      Tigre -34.425087 -58.579658   430000.0
# ...                          ...        ...        ...        ...
# 31490                Ramos Mejía -34.651040 -58.557381   190000.0
# 65135                   Martínez        NaN        NaN  2500000.0
# 47450                 Boca Ratón -34.455906 -58.908329   390000.0
# 132508                Loma Verde        NaN        NaN   198000.0
# 130191                   Quilmes -34.734603 -58.251278   200000.0
# 40584                     Olivos        NaN        NaN  1450000.0
# 12994                     Olivos        NaN        NaN  1450000.0
# 44420                 San Isidro -34.493677 -58.552697   212000.0
# 114592               Ramos Mejía        NaN        NaN   215000.0
# 77847               La Peregrina        NaN        NaN   225000.0
# 43442                      Pilar        NaN        NaN   865000.0
# 45960           Villa del Parque -34.620377 -58.476371   240000.0
# 19491                      Boedo -34.627303 -58.418610   260000.0
# 34462                 Lanús Este -34.712539 -58.387733   550000.0
# 12683                   Castelar -34.654684 -58.640656   295000.0
# 40344                   Castelar -34.654684 -58.640656   295000.0
# 94787                  Benavidez        NaN        NaN  1250000.0
# 72637            Capital Federal        NaN        NaN  1250000.0
# 16465                  San Justo        NaN        NaN   330000.0
# 90523                     Olivos -34.508154 -58.493354   330000.0
# 139929                 City Bell        NaN        NaN   330000.0
# 84643   Bs.As. G.B.A. Zona Norte        NaN        NaN   335000.0
# 15348                Ramos Mejía        NaN        NaN   750000.0
# 16190                Ramos Mejía        NaN        NaN   750000.0
# 94490                      Pilar        NaN        NaN  1890000.0
# 50798                Bella Vista -34.548712 -58.690712  1230000.0
# 161508             Vicente López        NaN        NaN   570000.0
# 75189          Barrio Los Alisos -34.413595 -58.674913   650000.0
# 75190          Barrio La Alameda -34.413736 -58.674741   650000.0
# 96831                   Nordelta        NaN        NaN   650000.0
#
#         surface_total_in_m2  surface_covered_in_m2  price_usd_per_m2  \
# 97079                 300.0                  380.0       9966.666667
# 92241                  35.0                   35.0       9938.571429
# 96840                 161.0                  161.0       9937.888199
# 247                    35.0                   31.0       9920.000000
# 121426               1000.0                 1000.0       9900.000000
# 86357                  20.0                  120.0       9900.000000
# 91033                  40.0                   40.0       9875.000000
# 54741                 213.0                  205.0       9859.154930
# 32588                 213.0                  205.0       9859.154930
# 106661                254.0                  220.0       9803.149606
# 87380                  10.0                   60.0       9800.000000
# 154679                 60.0                   49.0       9750.000000
# 91102                  36.0                   36.0       9722.222222
# 245                    37.0                   33.0       9718.918919
# 31249                 566.0                  473.0       9717.314488
# 53806                 566.0                  473.0       9717.314488
# 32595                 124.0                  120.0       9677.419355
# 54747                 124.0                  120.0       9677.419355
# 71787                 331.0                  331.0       9667.673716
# 98849                 145.0                  145.0       9655.172414
# 154660                 40.0                   34.0       9650.000000
# 172747                 37.0                    NaN       9620.351351
# 63817                  26.0                   26.0       9615.384615
# 130962                364.0                  364.0       9615.384615
# 88599                  26.0                   26.0       9615.384615
# 147737                323.0                    NaN       9597.523220
# 180572                190.0                  184.0       9578.947368
# 91128                  47.0                   47.0       9574.468085
# 71607                 230.0                  230.0       9565.217391
# 28634                  45.0                    NaN       9555.555556
# ...                     ...                    ...               ...
# 31490                 189.0                  139.0       1005.291005
# 65135                2487.0                  450.0       1005.227181
# 47450                 388.0                  350.0       1005.154639
# 132508                197.0                  197.0       1005.076142
# 130191                199.0                  150.0       1005.025126
# 40584                1443.0                  700.0       1004.851005
# 12994                1443.0                  700.0       1004.851005
# 44420                 211.0                  131.0       1004.739336
# 114592                214.0                  163.0       1004.672897
# 77847                 224.0                  170.0       1004.464286
# 43442                  56.0                   56.0       1004.449643
# 45960                 239.0                  161.0       1004.184100
# 19491                 259.0                  188.0       1003.861004
# 34462                 548.0                  548.0       1003.649635
# 12683                 294.0                  197.0       1003.401361
# 40344                 294.0                  197.0       1003.401361
# 94787                1246.0                  361.0       1003.210273
# 72637                1246.0                  360.0       1003.210273
# 16465                 329.0                  110.0       1003.039514
# 90523                 329.0                  140.0       1003.039514
# 139929                329.0                  329.0       1003.039514
# 84643                 334.0                  234.0       1002.994012
# 15348                 748.0                  310.0       1002.673797
# 16190                 748.0                  310.0       1002.673797
# 94490                 110.0                   40.0       1002.264364
# 50798                  80.0                   45.0       1001.889625
# 161508                569.0                  293.0       1001.757469
# 75189                 649.0                  250.0       1001.540832
# 75190                 649.0                  250.0       1001.540832
# 96831                 649.0                  250.0       1001.540832
#
#         price_per_m2  floor  rooms expenses  \
# 97079    7868.421053    NaN    NaN      NaN
# 92241    9938.571429    NaN    1.0      NaN
# 96840    9937.888199    NaN    NaN      NaN
# 247     11200.000000    NaN    1.0      NaN
# 121426   9900.000000    NaN    NaN      NaN
# 86357    1650.000000    NaN    NaN      NaN
# 91033    9875.000000    NaN    1.0      NaN
# 54741   10243.902439    NaN    4.0      NaN
# 32588   10243.902439    NaN    4.0      NaN
# 106661  11318.181818    NaN    NaN      NaN
# 87380    1633.333333    NaN    3.0      NaN
# 154679  11938.775510    NaN    NaN      NaN
# 91102    9722.222222    NaN    2.0      NaN
# 245     10896.969697    NaN    1.0      NaN
# 31249   11627.906977    NaN    5.0      NaN
# 53806   11627.906977    NaN    5.0      NaN
# 32595   10000.000000    NaN    4.0      NaN
# 54747   10000.000000    NaN    4.0      NaN
# 71787    9667.673716    NaN    5.0      NaN
# 98849    9655.172414    NaN    4.0      NaN
# 154660  11352.941176    NaN    NaN      NaN
# 172747           NaN    NaN    NaN      NaN
# 63817    9615.384615    NaN    NaN      NaN
# 130962   9615.384615    NaN    NaN        1
# 88599    9615.384615    NaN    NaN      NaN
# 147737           NaN    NaN    NaN      NaN
# 180572   9891.304348    NaN    4.0      NaN
# 91128    9574.468085    NaN    2.0      NaN
# 71607    9565.217391    NaN    4.0      NaN
# 28634            NaN    NaN    NaN      NaN
# ...              ...    ...    ...      ...
# 31490    1366.906475    NaN    NaN      NaN
# 65135    5555.555556    NaN    NaN      NaN
# 47450    1114.285714    NaN    NaN      NaN
# 132508   1005.076142    NaN    NaN      NaN
# 130191   1333.333333    NaN    NaN      NaN
# 40584    2071.428571    NaN    NaN      NaN
# 12994    2071.428571    NaN    NaN      NaN
# 44420    1618.320611    NaN    5.0      NaN
# 114592   1319.018405    NaN    4.0      NaN
# 77847    1323.529412    NaN    NaN      NaN
# 43442   15446.428571    NaN    3.0      NaN
# 45960    1490.683230    NaN    4.0      NaN
# 19491    1382.978723    NaN    7.0      NaN
# 34462    1003.649635    NaN    NaN      NaN
# 12683    1497.461929    NaN    NaN      NaN
# 40344    1497.461929    NaN    NaN      NaN
# 94787    3462.603878    NaN    NaN      NaN
# 72637    3472.222222    NaN    NaN      NaN
# 16465    3000.000000    NaN    5.0      NaN
# 90523    2357.142857    NaN    4.0      NaN
# 139929   1003.039514    NaN    NaN      NaN
# 84643    1431.623932    NaN    NaN      NaN
# 15348    2419.354839    NaN    4.0      NaN
# 16190    2419.354839    NaN    4.0      NaN
# 94490   47250.000000    NaN    NaN      NaN
# 50798   27333.333333    NaN    NaN      NaN
# 161508   1945.392491    NaN    NaN      NaN
# 75189    2600.000000    NaN    NaN      NaN
# 75190    2600.000000    NaN    NaN      NaN
# 96831    2600.000000    NaN    NaN      NaN
#
#                                               description
# 97079   Casa en excelente estado, reciclada, gran Livi...
# 92241   fac025- Monoambiente en el contrafrente a part...
# 96840   ALVEAR TOWER. Espectacular departamento en el ...
# 247     HERMOSO MONOAMBIENTE CON BALCON AL FRENTE A ES...
# 121426  Casa importante en lote privilegiado con vista...
# 86357   Muy lindo triplex a estrenar de en el complejo...
# 91033   Departamento Nuevo, 2 amb al frente en 1 Piso....
# 54741   Le Parc Figueroa Alcorta es la síntesis perfec...
# 32588   Le Parc Figueroa Alcorta es la síntesis perfec...
# 106661  CODIGO: 617-1112 ubicado en: Jeronimo Salguero...
# 87380   Duplex 3 amb c/ frente con dos banos patio  im...
# 154679  Departamentos SUITES EN SLS LUX Puerto Madero....
# 91102   HERMOSOS DEPARTAMENTOS EN POZO DESDE $306000,$...
# 245     HERMOSO MONOAMBIENTE A ESTRENAR CON BALCON AL ...
# 31249   Forum Alcorta es un emprendimiento ubicado en ...
# 53806   Forum Alcorta es un emprendimiento ubicado en ...
# 32595   Para CLIENTES EXCLUSIVOS,  torre de PRIMER NIV...
# 54747   Para CLIENTES EXCLUSIVOS,  torre de PRIMER NIV...
# 71787   Unico piso completo de 331 mts en Torre Renoir...
# 98849   Exclusivo departamento en la Torre Bellini 4 A...
# 154660  Departamentos SUITES EN SLS LUX Puerto Madero!...
# 172747  Suite 801PRECIOS DESDE: -Suite Hotel: 36.9m2 U...
# 63817   EXCELENTE LOCAL SOBRE SARMIENTO A MTS DE LIBER...
# 130962  TORRE MIRABILIA PALERMOPALIER PRIVADO Y DE SER...
# 88599   EXCELENTE LOCAL SOBRE SARMIENTO A MTS DE LIBER...
# 147737  Vendido! Le parc Alcorta. Creo que eso dice to...
# 180572  Departamento con vista a todos los puntos card...
# 91128    .Publicado por RAMOS PROPIEDADES a traves INM...
# 71607   Semi piso muy luminoso y con regia vista, al f...
# 28634   CODIGO:  ubicado en: PIZARRO  1310 Y 1312 TIGR...
# ...                                                   ...
# 31490   de Casa 4 AMBIENTES en Ramos Mejía excelente b...
# 65135   En el corazÃ³n de Martinez, entre las icÃ³nica...
# 47450   Impecable chalet desarrollado en 2 plantas con...
# 132508  Oportunidad: Financia, escucha ofertas, acepta...
# 130191  Con detalles en piedra, y madera en la abertur...
# 40584   IMPORTANTE RESIDENCIA EN IMPECABLE ESTADO - RE...
# 12994   IMPORTANTE RESIDENCIA EN IMPECABLE ESTADO - RE...
# 44420   CASA APTO PROFESIONAL - SHOWROOMZONIF.: Rmb1Me...
# 114592  Chalet  s/lote 215 m2   4 ambientes  3 dormito...
# 77847   Club de Campo LA PEREGRINA se encuentra ubicad...
# 43442   Excelente opción de 2 dormitorios de 56 metros...
# 45960   Venta de PH 4 AMBIENTES con posibilidades de 5...
# 19491   EDIFICIO ANTIGUO EN MUY BUEN ESTADO DE CONSERV...
# 34462   Excepcional chalet sobre lote de 17,32 mts de ...
# 12683   Venta de Casa 4 AMBIENTES en Castelar. Planta ...
# 40344   Venta de Casa 4 AMBIENTES en Castelar. Planta ...
# 94787   arpinterÃ­a de PVC simil madera en el exterior...
# 72637   Buena vista al lago principal de santa barbara...
# 16465   Casa estilo americana de 5 amb. con excelente ...
# 90523   Muy buen Triplex a una cuadra de Av. Maipú. Li...
# 139929  Se trata de una casa con moderno diseño, desar...
# 84643   Casa en muy buen estado con excelente parque y...
# 15348   Excelente casa en doble lote de 17,32x 43,20 m...
# 16190   Excelente casa en doble lote de 17,32x 43,20 m...
# 94490   En la bajada del KM 46, sobre la Av. CaamaÃ±o,...
# 50798   DEPARTAMENTO DOS AMBIENTES A LA VENTA EN BELLA...
# 161508  Sólida casa en excelente ubicación sobre lote ...
# 75189   Excelente casa en Barrio Las Tipas, Nordelta. ...
# 75190   Excelente casa en Barrio Las Tipas, Nordelta. ...
# 96831   CARACTERISTICAS Superficie Terreno: 649 m2Supe...
#
# [82691 rows x 16 columns]

# %%
dataCapGbaSupmayor5 = dataCapGbamayoresA1000.loc[dataCapGbamayoresA1000['surface_total_in_m2'] > 5, :]
dataCapGbaSupmayor5.loc[:, "year"] = dataCapGbaSupmayor5.apply(lambda x: x["created_on"].partition("-")[0], axis = 1)

# %% [markdown]
# ## Precio por m2 en relacion a la cercania al Subte H y al año de su inauguracion
# ##### Lo voy a hacer para cada estacion por separado tambien asi se ve mejor

# %%
cercanasANuevasEstaciones = dataCapGbaSupmayor5.loc[dataCapGbaSupmayor5.lat.notnull() & dataCapGbaSupmayor5.lon.notnull(), ['year', 'place_name', 'lat', 'lon', 'price_usd_per_m2']]
cercanasANuevasEstaciones.loc[:, 'distanciaAEstacion'] = cercanasANuevasEstaciones.apply(distanciaANuevasEstaciones, axis = 1)
#Solo dejo las propiedades que estan a menos de 600mts
cercanasANuevasEstaciones = cercanasANuevasEstaciones.loc[cercanasANuevasEstaciones["distanciaAEstacion"] < 600, :]

cercanasGrafico = cercanasANuevasEstaciones.drop('lat', axis=1).drop('lon', axis=1).drop('place_name', axis=1).drop('distanciaAEstacion', axis=1)
cercanasGrafico.groupby('year').agg(np.mean).unstack(level=0).plot(kind ='bar')

# %% [markdown]
# ## Separando por zonas GBA Norte/Sur/Oeste y Capital Federal

# %%
publicaciones = dataCapGbaSupmayor5.loc[:, ['state_name', 'property_type', 'year', 'price_usd_per_m2']].groupby(['state_name', 'property_type', 'year']).count()
publicacionesCapFed = dataCapGbaSupmayor5.loc[dataCapGbaSupmayor5['state_name'].str.contains('Capital Federal'), ['property_type', 'year', 'price_usd_per_m2']].groupby(['property_type', 'year']).count()
publicacionesGBANorte = dataCapGbaSupmayor5.loc[dataCapGbaSupmayor5['state_name'].str.contains('Bs.As. G.B.A. Zona Norte'), ['property_type', 'year', 'price_usd_per_m2']].groupby(['property_type', 'year']).count()
publicacionesGBASur = dataCapGbaSupmayor5.loc[dataCapGbaSupmayor5['state_name'].str.contains('Bs.As. G.B.A. Zona Sur'), ['property_type', 'year', 'price_usd_per_m2']].groupby(['property_type', 'year']).count()
publicacionesGBAOeste = dataCapGbaSupmayor5.loc[dataCapGbaSupmayor5['state_name'].str.contains('Bs.As. G.B.A. Zona Oeste'), ['property_type', 'year', 'price_usd_per_m2']].groupby(['property_type', 'year']).count()

publicaciones = publicaciones.rename(columns = {'price_usd_per_m2': 'Cantidad de publicaciones'})
publicaciones.unstack(level=0).plot(kind='bar', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000005EF696A0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000005F619A90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000005F85A518>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000005FB5A400>], dtype=object)

# %%
##Agrupando por barrio de CABA y año y tomando unicamente los que tengan mas de 10 publicaciones por año
CABAPorBarrioYAnio = dataCapGbaSupmayor5.loc[dataCapGbaSupmayor5.state_name.str.contains('Capital Federal'), :]
CABAPorBarrioYAnio.loc[:, "year"] = CABAPorBarrioYAnio.apply(lambda x: x["created_on"].partition("-")[0], axis = 1)
CABAPorBarrioYAnio = CABAPorBarrioYAnio.loc[:, ["year", "place_name", "price_usd_per_m2"]]
CABAPorBarrioYAnio = CABAPorBarrioYAnio.groupby(["place_name", "year"]).agg([np.mean, np.size])
CABAPorBarrioYAnio = CABAPorBarrioYAnio.loc[CABAPorBarrioYAnio['price_usd_per_m2']['size'] > 10, :]
#CABAPorBarrioYAnio.loc[CABAPorBarrioYAnio['price_usd_per_m2']>=CABAPorBarrioYAnio.groupby(['place_name','year']).transform(np.mean)['price_usd_per_m2'],]
CABAPorBarrioYAnio
# Out:
#                          price_usd_per_m2
#                                      mean    size
# place_name          year
# Abasto              2016      2044.499113    42.0
#                     2017      2119.452961    83.0
# Agronomía           2016      2162.766473    56.0
#                     2017      2139.282478    24.0
# Almagro             2014      1801.717737    21.0
#                     2015      2266.894082    76.0
#                     2016      2113.773003   643.0
#                     2017      2228.842669   848.0
# Balvanera           2014      1776.271874    22.0
#                     2015      1657.254069    15.0
#                     2016      1843.080828   483.0
#                     2017      1955.709567   474.0
# Barracas            2015      1844.998535    12.0
#                     2016      1856.342263   284.0
#                     2017      1991.897913   329.0
# Barrio Norte        2014      2308.834111    17.0
#                     2015      2296.562086    23.0
#                     2016      2872.548598   777.0
#                     2017      3040.962998   936.0
# Belgrano            2014      2740.470687    52.0
#                     2015      2708.278120    64.0
#                     2016      3235.180081  1271.0
#                     2017      3126.336773  2200.0
# Boca                2016      1553.117467    86.0
#                     2017      1712.830470   149.0
# Boedo               2015      1668.117070    43.0
#                     2016      1763.820227   224.0
#                     2017      2600.923968   431.0
# Caballito           2015      2027.467179    30.0
#                     2016      2354.410076  1022.0
# ...                                   ...     ...
# Velez Sarsfield     2017      1735.604911    22.0
# Versalles           2016      1712.840495    26.0
#                     2017      1599.685371    24.0
# Villa Crespo        2014      3376.053995    15.0
#                     2015      2538.953034    39.0
#                     2016      2466.350272   805.0
#                     2017      2516.723186  1076.0
# Villa Devoto        2016      2157.017862   208.0
#                     2017      2157.052897   264.0
# Villa General Mitre 2016      1829.717064    30.0
#                     2017      1886.599674    37.0
# Villa Lugano        2016      1428.680156    48.0
#                     2017      1458.199647    78.0
# Villa Luro          2015      1902.771916    13.0
#                     2016      1796.976453   128.0
#                     2017      2077.737122   296.0
# Villa Ortuzar       2016      2233.904577    63.0
#                     2017      2358.035158    77.0
# Villa Pueyrredón    2016      1870.531863    92.0
#                     2017      2169.186792   114.0
# Villa Real          2016      1834.161662    20.0
#                     2017      1549.883948    24.0
# Villa Santa Rita    2016      1818.126908    44.0
#                     2017      1862.924460    28.0
# Villa Urquiza       2014      1839.871215    15.0
#                     2015      2211.276258    20.0
#                     2016      2515.749901   554.0
#                     2017      2480.803994  1110.0
# Villa del Parque    2016      1991.021354   184.0
#                     2017      2282.759303   339.0
#
# [160 rows x 2 columns]

# %%
CABAPorBarrioYAnio.plot(kind='bar', figsize=(120,18))
plt.bar(CABAPorBarrioYAnio.index.values, CABAPorBarrioYAnio['price_usd_per_m2']['mean'])
plt.suptitle("Precio promedio m2 por barrio y año")
plt.xlabel("Barrio por Año")
plt.ylabel("Precio USD promedio del m2")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-864ea7d394e5> in <module>()
#       1 CABAPorBarrioYAnio.plot(kind='bar', figsize=(120,18))
# ----> 2 plt.bar(CABAPorBarrioYAnio.index.values, CABAPorBarrioYAnio['price_usd_per_m2']['mean'])
#       3 plt.suptitle("Precio promedio m2 por barrio y año")
#       4 plt.xlabel("Barrio por Año")
#       5 plt.ylabel("Precio USD promedio del m2")
#
# c:\python27\lib\site-packages\matplotlib\pyplot.pyc in bar(left, height, width, bottom, hold, data, **kwargs)
#    2702     try:
#    2703         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2704                      **kwargs)
#    2705     finally:
#    2706         ax._hold = washold
#
# c:\python27\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# c:\python27\lib\site-packages\matplotlib\axes\_axes.pyc in bar(self, left, height, width, bottom, **kwargs)
#    2103         if align == 'center':
#    2104             if orientation == 'vertical':
# -> 2105                 left = [left[i] - width[i] / 2. for i in xrange(len(left))]
#    2106             elif orientation == 'horizontal':
#    2107                 bottom = [bottom[i] - height[i] / 2.
#
# TypeError: unsupported operand type(s) for -: 'tuple' and 'float'
