# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

data = pd.read_csv("dataFiltrada.csv", low_memory = False)
data = data.loc[data['price'] < 15000000,:].drop('Unnamed: 0', axis = 1)
data['created_on'] = pd.to_datetime(data['created_on'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45997 entries, 0 to 46002
# Data columns (total 23 columns):
# index                      45997 non-null int64
# created_on                 45997 non-null datetime64[ns]
# operation                  45997 non-null object
# property_type              45997 non-null object
# state_name                 45997 non-null object
# place_name                 45997 non-null object
# lat                        45997 non-null float64
# lon                        45997 non-null float64
# price                      45997 non-null float64
# surface_total_in_m2        45997 non-null float64
# price_usd_per_m2           45997 non-null float64
# media_por_barrio           45997 non-null float64
# cant_prop                  45997 non-null float64
# mediana_por_barrio         45997 non-null float64
# geoPos                     45997 non-null object
# distancia_al_centro        45997 non-null float64
# distanciaAIndoamericano    45997 non-null float64
# distanciaAFuerteApache     45997 non-null float64
# distanciaACarlosGardel     45997 non-null float64
# cant_subtes_cercanos       45997 non-null int64
# cant_trenes_cercanos       45997 non-null int64
# distancia_delitoMenor      23913 non-null float64
# distancia_delitoGrave      23913 non-null float64
# dtypes: datetime64[ns](1), float64(14), int64(3), object(5)
# memory usage: 8.4+ MB

# %%
def tipoDePropiedad(x):
    tipos = {
        "apartment" : 1,
        "house" : 2,
        "PH" : 3,
        "store" : 4
    }
    return tipos[x] if x in tipos else x


def fechaNumerica(x):
    return 10000*x.year + 100*x.month + x.day

# %%
data.loc[:, 'property_type'] = data.property_type.apply(tipoDePropiedad)
#data.loc[:, 'distancia_al_centro'] = data.distancia_al_centro.apply(lambda x: int(x))
data.loc[:, 'created_on'] = data.created_on.apply(fechaNumerica)
dataCapital = data.loc[data.state_name.str.contains('Capital Federal'), :]

# %%
dataCapital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23913 entries, 3214 to 44445
# Data columns (total 23 columns):
# index                      23913 non-null int64
# created_on                 23913 non-null int64
# operation                  23913 non-null object
# property_type              23913 non-null int64
# state_name                 23913 non-null object
# place_name                 23913 non-null object
# lat                        23913 non-null float64
# lon                        23913 non-null float64
# price                      23913 non-null float64
# surface_total_in_m2        23913 non-null float64
# price_usd_per_m2           23913 non-null float64
# media_por_barrio           23913 non-null float64
# cant_prop                  23913 non-null float64
# mediana_por_barrio         23913 non-null float64
# geoPos                     23913 non-null object
# distancia_al_centro        23913 non-null float64
# distanciaAIndoamericano    23913 non-null float64
# distanciaAFuerteApache     23913 non-null float64
# distanciaACarlosGardel     23913 non-null float64
# cant_subtes_cercanos       23913 non-null int64
# cant_trenes_cercanos       23913 non-null int64
# distancia_delitoMenor      23913 non-null float64
# distancia_delitoGrave      23913 non-null float64
# dtypes: float64(14), int64(5), object(4)
# memory usage: 4.4+ MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score, KFold
from sklearn.linear_model import LinearRegression

columnas = ['created_on', 'property_type', 'lat', 'lon', 'surface_total_in_m2',\
            'cant_prop', 'distancia_al_centro', 'distanciaAIndoamericano',\
            'cant_subtes_cercanos', 'cant_trenes_cercanos', 'distancia_delitoMenor', 'distancia_delitoGrave']

x = np.array(dataCapital.loc[:,columnas])
y = np.array(dataCapital['price_usd_per_m2'])
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
from sklearn.metrics import mean_squared_error
def linearR(x_train, x_test, y_train, y_test):
    linreg = LinearRegression()
    linreg.fit(x_train, y_train)
    y_pred = linreg.predict(x_test)
    #return y_pred
    return np.sqrt(mean_squared_error(y_test, y_pred))

# %%
np.sqrt(mean_squared_error(y_test, pred))

# %%
import itertools


columnas = ['created_on', 'property_type', 'lat', 'lon', 'surface_total_in_m2',\
            'cant_prop', 'distancia_al_centro', 'distanciaAIndoamericano',\
            'cant_subtes_cercanos', 'cant_trenes_cercanos', 'distancia_delitoMenor', 'distancia_delitoGrave']

list_columnas = []

for r in range(2, len(columnas)):

    res = itertools.combinations(columnas, r)
    for e in res:
        list_columnas.append(list(e))
list_columnas
# Out:
# [['created_on', 'property_type'],
#  ['created_on', 'lat'],
#  ['created_on', 'lon'],
#  ['created_on', 'surface_total_in_m2'],
#  ['created_on', 'cant_prop'],
#  ['created_on', 'distancia_al_centro'],
#  ['created_on', 'distanciaAIndoamericano'],
#  ['created_on', 'cant_subtes_cercanos'],
#  ['created_on', 'cant_trenes_cercanos'],
#  ['created_on', 'distancia_delitoMenor'],
#  ['created_on', 'distancia_delitoGrave'],
#  ['property_type', 'lat'],
#  ['property_type', 'lon'],
#  ['property_type', 'surface_total_in_m2'],
#  ['property_type', 'cant_prop'],
#  ['property_type', 'distancia_al_centro'],
#  ['property_type', 'distanciaAIndoamericano'],
#  ['property_type', 'cant_subtes_cercanos'],
#  ['property_type', 'cant_trenes_cercanos'],
#  ['property_type', 'distancia_delitoMenor'],
#  ['property_type', 'distancia_delitoGrave'],
#  ['lat', 'lon'],
#  ['lat', 'surface_total_in_m2'],
#  ['lat', 'cant_prop'],
#  ['lat', 'distancia_al_centro'],
#  ['lat', 'distanciaAIndoamericano'],
#  ['lat', 'cant_subtes_cercanos'],
#  ['lat', 'cant_trenes_cercanos'],
#  ['lat', 'distancia_delitoMenor'],
#  ['lat', 'distancia_delitoGrave'],
#  ['lon', 'surface_total_in_m2'],
#  ['lon', 'cant_prop'],
#  ['lon', 'distancia_al_centro'],
#  ['lon', 'distanciaAIndoamericano'],
#  ['lon', 'cant_subtes_cercanos'],
#  ['lon', 'cant_trenes_cercanos'],
#  ['lon', 'distancia_delitoMenor'],
#  ['lon', 'distancia_delitoGrave'],
#  ['surface_total_in_m2', 'cant_prop'],
#  ['surface_total_in_m2', 'distancia_al_centro'],
#  ['surface_total_in_m2', 'distanciaAIndoamericano'],
#  ['surface_total_in_m2', 'cant_subtes_cercanos'],
#  ['surface_total_in_m2', 'cant_trenes_cercanos'],
#  ['surface_total_in_m2', 'distancia_delitoMenor'],
#  ['surface_total_in_m2', 'distancia_delitoGrave'],
#  ['cant_prop', 'distancia_al_centro'],
#  ['cant_prop', 'distanciaAIndoamericano'],
#  ['cant_prop', 'cant_subtes_cercanos'],
#  ['cant_prop', 'cant_trenes_cercanos'],
#  ['cant_prop', 'distancia_delitoMenor'],
#  ['cant_prop', 'distancia_delitoGrave'],
#  ['distancia_al_centro', 'distanciaAIndoamericano'],
#  ['distancia_al_centro', 'cant_subtes_cercanos'],
#  ['distancia_al_centro', 'cant_trenes_cercanos'],
#  ['distancia_al_centro', 'distancia_delitoMenor'],
#  ['distancia_al_centro', 'distancia_delitoGrave'],
#  ['distanciaAIndoamericano', 'cant_subtes_cercanos'],
#  ['distanciaAIndoamericano', 'cant_trenes_cercanos'],
#  ['distanciaAIndoamericano', 'distancia_delitoMenor'],
#  ['distanciaAIndoamericano', 'distancia_delitoGrave'],
#  ['cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['created_on', 'property_type', 'lat'],
#  ['created_on', 'property_type', 'lon'],
#  ['created_on', 'property_type', 'surface_total_in_m2'],
#  ['created_on', 'property_type', 'cant_prop'],
#  ['created_on', 'property_type', 'distancia_al_centro'],
#  ['created_on', 'property_type', 'distanciaAIndoamericano'],
#  ['created_on', 'property_type', 'cant_subtes_cercanos'],
#  ['created_on', 'property_type', 'cant_trenes_cercanos'],
#  ['created_on', 'property_type', 'distancia_delitoMenor'],
#  ['created_on', 'property_type', 'distancia_delitoGrave'],
#  ['created_on', 'lat', 'lon'],
#  ['created_on', 'lat', 'surface_total_in_m2'],
#  ['created_on', 'lat', 'cant_prop'],
#  ['created_on', 'lat', 'distancia_al_centro'],
#  ['created_on', 'lat', 'distanciaAIndoamericano'],
#  ['created_on', 'lat', 'cant_subtes_cercanos'],
#  ['created_on', 'lat', 'cant_trenes_cercanos'],
#  ['created_on', 'lat', 'distancia_delitoMenor'],
#  ['created_on', 'lat', 'distancia_delitoGrave'],
#  ['created_on', 'lon', 'surface_total_in_m2'],
#  ['created_on', 'lon', 'cant_prop'],
#  ['created_on', 'lon', 'distancia_al_centro'],
#  ['created_on', 'lon', 'distanciaAIndoamericano'],
#  ['created_on', 'lon', 'cant_subtes_cercanos'],
#  ['created_on', 'lon', 'cant_trenes_cercanos'],
#  ['created_on', 'lon', 'distancia_delitoMenor'],
#  ['created_on', 'lon', 'distancia_delitoGrave'],
#  ['created_on', 'surface_total_in_m2', 'cant_prop'],
#  ['created_on', 'surface_total_in_m2', 'distancia_al_centro'],
#  ['created_on', 'surface_total_in_m2', 'distanciaAIndoamericano'],
#  ['created_on', 'surface_total_in_m2', 'cant_subtes_cercanos'],
#  ['created_on', 'surface_total_in_m2', 'cant_trenes_cercanos'],
#  ['created_on', 'surface_total_in_m2', 'distancia_delitoMenor'],
#  ['created_on', 'surface_total_in_m2', 'distancia_delitoGrave'],
#  ['created_on', 'cant_prop', 'distancia_al_centro'],
#  ['created_on', 'cant_prop', 'distanciaAIndoamericano'],
#  ['created_on', 'cant_prop', 'cant_subtes_cercanos'],
#  ['created_on', 'cant_prop', 'cant_trenes_cercanos'],
#  ['created_on', 'cant_prop', 'distancia_delitoMenor'],
#  ['created_on', 'cant_prop', 'distancia_delitoGrave'],
#  ['created_on', 'distancia_al_centro', 'distanciaAIndoamericano'],
#  ['created_on', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['created_on', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['created_on', 'distancia_al_centro', 'distancia_delitoMenor'],
#  ['created_on', 'distancia_al_centro', 'distancia_delitoGrave'],
#  ['created_on', 'distanciaAIndoamericano', 'cant_subtes_cercanos'],
#  ['created_on', 'distanciaAIndoamericano', 'cant_trenes_cercanos'],
#  ['created_on', 'distanciaAIndoamericano', 'distancia_delitoMenor'],
#  ['created_on', 'distanciaAIndoamericano', 'distancia_delitoGrave'],
#  ['created_on', 'cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['created_on', 'cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['created_on', 'cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['created_on', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['created_on', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['created_on', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['property_type', 'lat', 'lon'],
#  ['property_type', 'lat', 'surface_total_in_m2'],
#  ['property_type', 'lat', 'cant_prop'],
#  ['property_type', 'lat', 'distancia_al_centro'],
#  ['property_type', 'lat', 'distanciaAIndoamericano'],
#  ['property_type', 'lat', 'cant_subtes_cercanos'],
#  ['property_type', 'lat', 'cant_trenes_cercanos'],
#  ['property_type', 'lat', 'distancia_delitoMenor'],
#  ['property_type', 'lat', 'distancia_delitoGrave'],
#  ['property_type', 'lon', 'surface_total_in_m2'],
#  ['property_type', 'lon', 'cant_prop'],
#  ['property_type', 'lon', 'distancia_al_centro'],
#  ['property_type', 'lon', 'distanciaAIndoamericano'],
#  ['property_type', 'lon', 'cant_subtes_cercanos'],
#  ['property_type', 'lon', 'cant_trenes_cercanos'],
#  ['property_type', 'lon', 'distancia_delitoMenor'],
#  ['property_type', 'lon', 'distancia_delitoGrave'],
#  ['property_type', 'surface_total_in_m2', 'cant_prop'],
#  ['property_type', 'surface_total_in_m2', 'distancia_al_centro'],
#  ['property_type', 'surface_total_in_m2', 'distanciaAIndoamericano'],
#  ['property_type', 'surface_total_in_m2', 'cant_subtes_cercanos'],
#  ['property_type', 'surface_total_in_m2', 'cant_trenes_cercanos'],
#  ['property_type', 'surface_total_in_m2', 'distancia_delitoMenor'],
#  ['property_type', 'surface_total_in_m2', 'distancia_delitoGrave'],
#  ['property_type', 'cant_prop', 'distancia_al_centro'],
#  ['property_type', 'cant_prop', 'distanciaAIndoamericano'],
#  ['property_type', 'cant_prop', 'cant_subtes_cercanos'],
#  ['property_type', 'cant_prop', 'cant_trenes_cercanos'],
#  ['property_type', 'cant_prop', 'distancia_delitoMenor'],
#  ['property_type', 'cant_prop', 'distancia_delitoGrave'],
#  ['property_type', 'distancia_al_centro', 'distanciaAIndoamericano'],
#  ['property_type', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['property_type', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['property_type', 'distancia_al_centro', 'distancia_delitoMenor'],
#  ['property_type', 'distancia_al_centro', 'distancia_delitoGrave'],
#  ['property_type', 'distanciaAIndoamericano', 'cant_subtes_cercanos'],
#  ['property_type', 'distanciaAIndoamericano', 'cant_trenes_cercanos'],
#  ['property_type', 'distanciaAIndoamericano', 'distancia_delitoMenor'],
#  ['property_type', 'distanciaAIndoamericano', 'distancia_delitoGrave'],
#  ['property_type', 'cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['property_type', 'cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['property_type', 'cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['property_type', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['property_type', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['property_type', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['lat', 'lon', 'surface_total_in_m2'],
#  ['lat', 'lon', 'cant_prop'],
#  ['lat', 'lon', 'distancia_al_centro'],
#  ['lat', 'lon', 'distanciaAIndoamericano'],
#  ['lat', 'lon', 'cant_subtes_cercanos'],
#  ['lat', 'lon', 'cant_trenes_cercanos'],
#  ['lat', 'lon', 'distancia_delitoMenor'],
#  ['lat', 'lon', 'distancia_delitoGrave'],
#  ['lat', 'surface_total_in_m2', 'cant_prop'],
#  ['lat', 'surface_total_in_m2', 'distancia_al_centro'],
#  ['lat', 'surface_total_in_m2', 'distanciaAIndoamericano'],
#  ['lat', 'surface_total_in_m2', 'cant_subtes_cercanos'],
#  ['lat', 'surface_total_in_m2', 'cant_trenes_cercanos'],
#  ['lat', 'surface_total_in_m2', 'distancia_delitoMenor'],
#  ['lat', 'surface_total_in_m2', 'distancia_delitoGrave'],
#  ['lat', 'cant_prop', 'distancia_al_centro'],
#  ['lat', 'cant_prop', 'distanciaAIndoamericano'],
#  ['lat', 'cant_prop', 'cant_subtes_cercanos'],
#  ['lat', 'cant_prop', 'cant_trenes_cercanos'],
#  ['lat', 'cant_prop', 'distancia_delitoMenor'],
#  ['lat', 'cant_prop', 'distancia_delitoGrave'],
#  ['lat', 'distancia_al_centro', 'distanciaAIndoamericano'],
#  ['lat', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['lat', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['lat', 'distancia_al_centro', 'distancia_delitoMenor'],
#  ['lat', 'distancia_al_centro', 'distancia_delitoGrave'],
#  ['lat', 'distanciaAIndoamericano', 'cant_subtes_cercanos'],
#  ['lat', 'distanciaAIndoamericano', 'cant_trenes_cercanos'],
#  ['lat', 'distanciaAIndoamericano', 'distancia_delitoMenor'],
#  ['lat', 'distanciaAIndoamericano', 'distancia_delitoGrave'],
#  ['lat', 'cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['lat', 'cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['lat', 'cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['lat', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['lat', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['lat', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['lon', 'surface_total_in_m2', 'cant_prop'],
#  ['lon', 'surface_total_in_m2', 'distancia_al_centro'],
#  ['lon', 'surface_total_in_m2', 'distanciaAIndoamericano'],
#  ['lon', 'surface_total_in_m2', 'cant_subtes_cercanos'],
#  ['lon', 'surface_total_in_m2', 'cant_trenes_cercanos'],
#  ['lon', 'surface_total_in_m2', 'distancia_delitoMenor'],
#  ['lon', 'surface_total_in_m2', 'distancia_delitoGrave'],
#  ['lon', 'cant_prop', 'distancia_al_centro'],
#  ['lon', 'cant_prop', 'distanciaAIndoamericano'],
#  ['lon', 'cant_prop', 'cant_subtes_cercanos'],
#  ['lon', 'cant_prop', 'cant_trenes_cercanos'],
#  ['lon', 'cant_prop', 'distancia_delitoMenor'],
#  ['lon', 'cant_prop', 'distancia_delitoGrave'],
#  ['lon', 'distancia_al_centro', 'distanciaAIndoamericano'],
#  ['lon', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['lon', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['lon', 'distancia_al_centro', 'distancia_delitoMenor'],
#  ['lon', 'distancia_al_centro', 'distancia_delitoGrave'],
#  ['lon', 'distanciaAIndoamericano', 'cant_subtes_cercanos'],
#  ['lon', 'distanciaAIndoamericano', 'cant_trenes_cercanos'],
#  ['lon', 'distanciaAIndoamericano', 'distancia_delitoMenor'],
#  ['lon', 'distanciaAIndoamericano', 'distancia_delitoGrave'],
#  ['lon', 'cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['lon', 'cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['lon', 'cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['lon', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['lon', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['lon', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['surface_total_in_m2', 'cant_prop', 'distancia_al_centro'],
#  ['surface_total_in_m2', 'cant_prop', 'distanciaAIndoamericano'],
#  ['surface_total_in_m2', 'cant_prop', 'cant_subtes_cercanos'],
#  ['surface_total_in_m2', 'cant_prop', 'cant_trenes_cercanos'],
#  ['surface_total_in_m2', 'cant_prop', 'distancia_delitoMenor'],
#  ['surface_total_in_m2', 'cant_prop', 'distancia_delitoGrave'],
#  ['surface_total_in_m2', 'distancia_al_centro', 'distanciaAIndoamericano'],
#  ['surface_total_in_m2', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['surface_total_in_m2', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['surface_total_in_m2', 'distancia_al_centro', 'distancia_delitoMenor'],
#  ['surface_total_in_m2', 'distancia_al_centro', 'distancia_delitoGrave'],
#  ['surface_total_in_m2', 'distanciaAIndoamericano', 'cant_subtes_cercanos'],
#  ['surface_total_in_m2', 'distanciaAIndoamericano', 'cant_trenes_cercanos'],
#  ['surface_total_in_m2', 'distanciaAIndoamericano', 'distancia_delitoMenor'],
#  ['surface_total_in_m2', 'distanciaAIndoamericano', 'distancia_delitoGrave'],
#  ['surface_total_in_m2', 'cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['surface_total_in_m2', 'cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['surface_total_in_m2', 'cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['surface_total_in_m2', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['surface_total_in_m2', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['surface_total_in_m2', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['cant_prop', 'distancia_al_centro', 'distanciaAIndoamericano'],
#  ['cant_prop', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['cant_prop', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['cant_prop', 'distancia_al_centro', 'distancia_delitoMenor'],
#  ['cant_prop', 'distancia_al_centro', 'distancia_delitoGrave'],
#  ['cant_prop', 'distanciaAIndoamericano', 'cant_subtes_cercanos'],
#  ['cant_prop', 'distanciaAIndoamericano', 'cant_trenes_cercanos'],
#  ['cant_prop', 'distanciaAIndoamericano', 'distancia_delitoMenor'],
#  ['cant_prop', 'distanciaAIndoamericano', 'distancia_delitoGrave'],
#  ['cant_prop', 'cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['cant_prop', 'cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['cant_prop', 'cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['cant_prop', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['cant_prop', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['cant_prop', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['distancia_al_centro', 'distanciaAIndoamericano', 'cant_subtes_cercanos'],
#  ['distancia_al_centro', 'distanciaAIndoamericano', 'cant_trenes_cercanos'],
#  ['distancia_al_centro', 'distanciaAIndoamericano', 'distancia_delitoMenor'],
#  ['distancia_al_centro', 'distanciaAIndoamericano', 'distancia_delitoGrave'],
#  ['distancia_al_centro', 'cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['distancia_al_centro', 'cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['distancia_al_centro', 'cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['distancia_al_centro', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['distancia_al_centro', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['distancia_al_centro', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['distanciaAIndoamericano', 'cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['distanciaAIndoamericano', 'cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['distanciaAIndoamericano', 'cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['distanciaAIndoamericano', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['distanciaAIndoamericano', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['distanciaAIndoamericano', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['cant_subtes_cercanos', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['cant_subtes_cercanos', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['cant_subtes_cercanos', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['cant_trenes_cercanos', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['created_on', 'property_type', 'lat', 'lon'],
#  ['created_on', 'property_type', 'lat', 'surface_total_in_m2'],
#  ['created_on', 'property_type', 'lat', 'cant_prop'],
#  ['created_on', 'property_type', 'lat', 'distancia_al_centro'],
#  ['created_on', 'property_type', 'lat', 'distanciaAIndoamericano'],
#  ['created_on', 'property_type', 'lat', 'cant_subtes_cercanos'],
#  ['created_on', 'property_type', 'lat', 'cant_trenes_cercanos'],
#  ['created_on', 'property_type', 'lat', 'distancia_delitoMenor'],
#  ['created_on', 'property_type', 'lat', 'distancia_delitoGrave'],
#  ['created_on', 'property_type', 'lon', 'surface_total_in_m2'],
#  ['created_on', 'property_type', 'lon', 'cant_prop'],
#  ['created_on', 'property_type', 'lon', 'distancia_al_centro'],
#  ['created_on', 'property_type', 'lon', 'distanciaAIndoamericano'],
#  ['created_on', 'property_type', 'lon', 'cant_subtes_cercanos'],
#  ['created_on', 'property_type', 'lon', 'cant_trenes_cercanos'],
#  ['created_on', 'property_type', 'lon', 'distancia_delitoMenor'],
#  ['created_on', 'property_type', 'lon', 'distancia_delitoGrave'],
#  ['created_on', 'property_type', 'surface_total_in_m2', 'cant_prop'],
#  ['created_on', 'property_type', 'surface_total_in_m2', 'distancia_al_centro'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'distancia_delitoGrave'],
#  ['created_on', 'property_type', 'cant_prop', 'distancia_al_centro'],
#  ['created_on', 'property_type', 'cant_prop', 'distanciaAIndoamericano'],
#  ['created_on', 'property_type', 'cant_prop', 'cant_subtes_cercanos'],
#  ['created_on', 'property_type', 'cant_prop', 'cant_trenes_cercanos'],
#  ['created_on', 'property_type', 'cant_prop', 'distancia_delitoMenor'],
#  ['created_on', 'property_type', 'cant_prop', 'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'distancia_al_centro',
#   'distanciaAIndoamericano'],
#  ['created_on',
#   'property_type',
#   'distancia_al_centro',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'property_type',
#   'distancia_al_centro',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'property_type',
#   'distancia_al_centro',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'distancia_al_centro',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'property_type',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'property_type',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'property_type',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on', 'lat', 'lon', 'surface_total_in_m2'],
#  ['created_on', 'lat', 'lon', 'cant_prop'],
#  ['created_on', 'lat', 'lon', 'distancia_al_centro'],
#  ['created_on', 'lat', 'lon', 'distanciaAIndoamericano'],
#  ['created_on', 'lat', 'lon', 'cant_subtes_cercanos'],
#  ['created_on', 'lat', 'lon', 'cant_trenes_cercanos'],
#  ['created_on', 'lat', 'lon', 'distancia_delitoMenor'],
#  ['created_on', 'lat', 'lon', 'distancia_delitoGrave'],
#  ['created_on', 'lat', 'surface_total_in_m2', 'cant_prop'],
#  ['created_on', 'lat', 'surface_total_in_m2', 'distancia_al_centro'],
#  ['created_on', 'lat', 'surface_total_in_m2', 'distanciaAIndoamericano'],
#  ['created_on', 'lat', 'surface_total_in_m2', 'cant_subtes_cercanos'],
#  ['created_on', 'lat', 'surface_total_in_m2', 'cant_trenes_cercanos'],
#  ['created_on', 'lat', 'surface_total_in_m2', 'distancia_delitoMenor'],
#  ['created_on', 'lat', 'surface_total_in_m2', 'distancia_delitoGrave'],
#  ['created_on', 'lat', 'cant_prop', 'distancia_al_centro'],
#  ['created_on', 'lat', 'cant_prop', 'distanciaAIndoamericano'],
#  ['created_on', 'lat', 'cant_prop', 'cant_subtes_cercanos'],
#  ['created_on', 'lat', 'cant_prop', 'cant_trenes_cercanos'],
#  ['created_on', 'lat', 'cant_prop', 'distancia_delitoMenor'],
#  ['created_on', 'lat', 'cant_prop', 'distancia_delitoGrave'],
#  ['created_on', 'lat', 'distancia_al_centro', 'distanciaAIndoamericano'],
#  ['created_on', 'lat', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['created_on', 'lat', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['created_on', 'lat', 'distancia_al_centro', 'distancia_delitoMenor'],
#  ['created_on', 'lat', 'distancia_al_centro', 'distancia_delitoGrave'],
#  ['created_on', 'lat', 'distanciaAIndoamericano', 'cant_subtes_cercanos'],
#  ['created_on', 'lat', 'distanciaAIndoamericano', 'cant_trenes_cercanos'],
#  ['created_on', 'lat', 'distanciaAIndoamericano', 'distancia_delitoMenor'],
#  ['created_on', 'lat', 'distanciaAIndoamericano', 'distancia_delitoGrave'],
#  ['created_on', 'lat', 'cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['created_on', 'lat', 'cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['created_on', 'lat', 'cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['created_on', 'lat', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['created_on', 'lat', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['created_on', 'lat', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['created_on', 'lon', 'surface_total_in_m2', 'cant_prop'],
#  ['created_on', 'lon', 'surface_total_in_m2', 'distancia_al_centro'],
#  ['created_on', 'lon', 'surface_total_in_m2', 'distanciaAIndoamericano'],
#  ['created_on', 'lon', 'surface_total_in_m2', 'cant_subtes_cercanos'],
#  ['created_on', 'lon', 'surface_total_in_m2', 'cant_trenes_cercanos'],
#  ['created_on', 'lon', 'surface_total_in_m2', 'distancia_delitoMenor'],
#  ['created_on', 'lon', 'surface_total_in_m2', 'distancia_delitoGrave'],
#  ['created_on', 'lon', 'cant_prop', 'distancia_al_centro'],
#  ['created_on', 'lon', 'cant_prop', 'distanciaAIndoamericano'],
#  ['created_on', 'lon', 'cant_prop', 'cant_subtes_cercanos'],
#  ['created_on', 'lon', 'cant_prop', 'cant_trenes_cercanos'],
#  ['created_on', 'lon', 'cant_prop', 'distancia_delitoMenor'],
#  ['created_on', 'lon', 'cant_prop', 'distancia_delitoGrave'],
#  ['created_on', 'lon', 'distancia_al_centro', 'distanciaAIndoamericano'],
#  ['created_on', 'lon', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['created_on', 'lon', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['created_on', 'lon', 'distancia_al_centro', 'distancia_delitoMenor'],
#  ['created_on', 'lon', 'distancia_al_centro', 'distancia_delitoGrave'],
#  ['created_on', 'lon', 'distanciaAIndoamericano', 'cant_subtes_cercanos'],
#  ['created_on', 'lon', 'distanciaAIndoamericano', 'cant_trenes_cercanos'],
#  ['created_on', 'lon', 'distanciaAIndoamericano', 'distancia_delitoMenor'],
#  ['created_on', 'lon', 'distanciaAIndoamericano', 'distancia_delitoGrave'],
#  ['created_on', 'lon', 'cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['created_on', 'lon', 'cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['created_on', 'lon', 'cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['created_on', 'lon', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['created_on', 'lon', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['created_on', 'lon', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['created_on', 'surface_total_in_m2', 'cant_prop', 'distancia_al_centro'],
#  ['created_on', 'surface_total_in_m2', 'cant_prop', 'distanciaAIndoamericano'],
#  ['created_on', 'surface_total_in_m2', 'cant_prop', 'cant_subtes_cercanos'],
#  ['created_on', 'surface_total_in_m2', 'cant_prop', 'cant_trenes_cercanos'],
#  ['created_on', 'surface_total_in_m2', 'cant_prop', 'distancia_delitoMenor'],
#  ['created_on', 'surface_total_in_m2', 'cant_prop', 'distancia_delitoGrave'],
#  ['created_on',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distanciaAIndoamericano'],
#  ['created_on',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'surface_total_in_m2',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'surface_total_in_m2',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'surface_total_in_m2',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on', 'cant_prop', 'distancia_al_centro', 'distanciaAIndoamericano'],
#  ['created_on', 'cant_prop', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['created_on', 'cant_prop', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['created_on', 'cant_prop', 'distancia_al_centro', 'distancia_delitoMenor'],
#  ['created_on', 'cant_prop', 'distancia_al_centro', 'distancia_delitoGrave'],
#  ['created_on',
#   'cant_prop',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'cant_prop',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'cant_prop',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'cant_prop',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ['created_on', 'cant_prop', 'cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['created_on', 'cant_prop', 'cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['created_on', 'cant_prop', 'cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['created_on', 'cant_prop', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['created_on', 'cant_prop', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['created_on', 'cant_prop', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['created_on',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'distancia_al_centro',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'distancia_al_centro',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'distancia_al_centro',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'distancia_al_centro',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'distancia_al_centro',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'distancia_al_centro',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['property_type', 'lat', 'lon', 'surface_total_in_m2'],
#  ['property_type', 'lat', 'lon', 'cant_prop'],
#  ['property_type', 'lat', 'lon', 'distancia_al_centro'],
#  ['property_type', 'lat', 'lon', 'distanciaAIndoamericano'],
#  ['property_type', 'lat', 'lon', 'cant_subtes_cercanos'],
#  ['property_type', 'lat', 'lon', 'cant_trenes_cercanos'],
#  ['property_type', 'lat', 'lon', 'distancia_delitoMenor'],
#  ['property_type', 'lat', 'lon', 'distancia_delitoGrave'],
#  ['property_type', 'lat', 'surface_total_in_m2', 'cant_prop'],
#  ['property_type', 'lat', 'surface_total_in_m2', 'distancia_al_centro'],
#  ['property_type', 'lat', 'surface_total_in_m2', 'distanciaAIndoamericano'],
#  ['property_type', 'lat', 'surface_total_in_m2', 'cant_subtes_cercanos'],
#  ['property_type', 'lat', 'surface_total_in_m2', 'cant_trenes_cercanos'],
#  ['property_type', 'lat', 'surface_total_in_m2', 'distancia_delitoMenor'],
#  ['property_type', 'lat', 'surface_total_in_m2', 'distancia_delitoGrave'],
#  ['property_type', 'lat', 'cant_prop', 'distancia_al_centro'],
#  ['property_type', 'lat', 'cant_prop', 'distanciaAIndoamericano'],
#  ['property_type', 'lat', 'cant_prop', 'cant_subtes_cercanos'],
#  ['property_type', 'lat', 'cant_prop', 'cant_trenes_cercanos'],
#  ['property_type', 'lat', 'cant_prop', 'distancia_delitoMenor'],
#  ['property_type', 'lat', 'cant_prop', 'distancia_delitoGrave'],
#  ['property_type', 'lat', 'distancia_al_centro', 'distanciaAIndoamericano'],
#  ['property_type', 'lat', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['property_type', 'lat', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['property_type', 'lat', 'distancia_al_centro', 'distancia_delitoMenor'],
#  ['property_type', 'lat', 'distancia_al_centro', 'distancia_delitoGrave'],
#  ['property_type', 'lat', 'distanciaAIndoamericano', 'cant_subtes_cercanos'],
#  ['property_type', 'lat', 'distanciaAIndoamericano', 'cant_trenes_cercanos'],
#  ['property_type', 'lat', 'distanciaAIndoamericano', 'distancia_delitoMenor'],
#  ['property_type', 'lat', 'distanciaAIndoamericano', 'distancia_delitoGrave'],
#  ['property_type', 'lat', 'cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['property_type', 'lat', 'cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['property_type', 'lat', 'cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['property_type', 'lat', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['property_type', 'lat', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['property_type', 'lat', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['property_type', 'lon', 'surface_total_in_m2', 'cant_prop'],
#  ['property_type', 'lon', 'surface_total_in_m2', 'distancia_al_centro'],
#  ['property_type', 'lon', 'surface_total_in_m2', 'distanciaAIndoamericano'],
#  ['property_type', 'lon', 'surface_total_in_m2', 'cant_subtes_cercanos'],
#  ['property_type', 'lon', 'surface_total_in_m2', 'cant_trenes_cercanos'],
#  ['property_type', 'lon', 'surface_total_in_m2', 'distancia_delitoMenor'],
#  ['property_type', 'lon', 'surface_total_in_m2', 'distancia_delitoGrave'],
#  ['property_type', 'lon', 'cant_prop', 'distancia_al_centro'],
#  ['property_type', 'lon', 'cant_prop', 'distanciaAIndoamericano'],
#  ['property_type', 'lon', 'cant_prop', 'cant_subtes_cercanos'],
#  ['property_type', 'lon', 'cant_prop', 'cant_trenes_cercanos'],
#  ['property_type', 'lon', 'cant_prop', 'distancia_delitoMenor'],
#  ['property_type', 'lon', 'cant_prop', 'distancia_delitoGrave'],
#  ['property_type', 'lon', 'distancia_al_centro', 'distanciaAIndoamericano'],
#  ['property_type', 'lon', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['property_type', 'lon', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['property_type', 'lon', 'distancia_al_centro', 'distancia_delitoMenor'],
#  ['property_type', 'lon', 'distancia_al_centro', 'distancia_delitoGrave'],
#  ['property_type', 'lon', 'distanciaAIndoamericano', 'cant_subtes_cercanos'],
#  ['property_type', 'lon', 'distanciaAIndoamericano', 'cant_trenes_cercanos'],
#  ['property_type', 'lon', 'distanciaAIndoamericano', 'distancia_delitoMenor'],
#  ['property_type', 'lon', 'distanciaAIndoamericano', 'distancia_delitoGrave'],
#  ['property_type', 'lon', 'cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['property_type', 'lon', 'cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['property_type', 'lon', 'cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['property_type', 'lon', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['property_type', 'lon', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['property_type', 'lon', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['property_type', 'surface_total_in_m2', 'cant_prop', 'distancia_al_centro'],
#  ['property_type',
#   'surface_total_in_m2',
#   'cant_prop',
#   'distanciaAIndoamericano'],
#  ['property_type', 'surface_total_in_m2', 'cant_prop', 'cant_subtes_cercanos'],
#  ['property_type', 'surface_total_in_m2', 'cant_prop', 'cant_trenes_cercanos'],
#  ['property_type',
#   'surface_total_in_m2',
#   'cant_prop',
#   'distancia_delitoMenor'],
#  ['property_type',
#   'surface_total_in_m2',
#   'cant_prop',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distanciaAIndoamericano'],
#  ['property_type',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'cant_subtes_cercanos'],
#  ['property_type',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'cant_trenes_cercanos'],
#  ['property_type',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distancia_delitoMenor'],
#  ['property_type',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['property_type',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['property_type',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['property_type',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['property_type',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['property_type',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'surface_total_in_m2',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['property_type',
#   'surface_total_in_m2',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'surface_total_in_m2',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'cant_prop',
#   'distancia_al_centro',
#   'distanciaAIndoamericano'],
#  ['property_type', 'cant_prop', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['property_type', 'cant_prop', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['property_type',
#   'cant_prop',
#   'distancia_al_centro',
#   'distancia_delitoMenor'],
#  ['property_type',
#   'cant_prop',
#   'distancia_al_centro',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'cant_prop',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['property_type',
#   'cant_prop',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['property_type',
#   'cant_prop',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['property_type',
#   'cant_prop',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'cant_prop',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['property_type',
#   'cant_prop',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['property_type',
#   'cant_prop',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'cant_prop',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['property_type',
#   'cant_prop',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'cant_prop',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['property_type',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['property_type',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['property_type',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'distancia_al_centro',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['property_type',
#   'distancia_al_centro',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['property_type',
#   'distancia_al_centro',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'distancia_al_centro',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['property_type',
#   'distancia_al_centro',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'distancia_al_centro',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['property_type',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['property_type',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['property_type',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['property_type',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['property_type',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['lat', 'lon', 'surface_total_in_m2', 'cant_prop'],
#  ['lat', 'lon', 'surface_total_in_m2', 'distancia_al_centro'],
#  ['lat', 'lon', 'surface_total_in_m2', 'distanciaAIndoamericano'],
#  ['lat', 'lon', 'surface_total_in_m2', 'cant_subtes_cercanos'],
#  ['lat', 'lon', 'surface_total_in_m2', 'cant_trenes_cercanos'],
#  ['lat', 'lon', 'surface_total_in_m2', 'distancia_delitoMenor'],
#  ['lat', 'lon', 'surface_total_in_m2', 'distancia_delitoGrave'],
#  ['lat', 'lon', 'cant_prop', 'distancia_al_centro'],
#  ['lat', 'lon', 'cant_prop', 'distanciaAIndoamericano'],
#  ['lat', 'lon', 'cant_prop', 'cant_subtes_cercanos'],
#  ['lat', 'lon', 'cant_prop', 'cant_trenes_cercanos'],
#  ['lat', 'lon', 'cant_prop', 'distancia_delitoMenor'],
#  ['lat', 'lon', 'cant_prop', 'distancia_delitoGrave'],
#  ['lat', 'lon', 'distancia_al_centro', 'distanciaAIndoamericano'],
#  ['lat', 'lon', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['lat', 'lon', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['lat', 'lon', 'distancia_al_centro', 'distancia_delitoMenor'],
#  ['lat', 'lon', 'distancia_al_centro', 'distancia_delitoGrave'],
#  ['lat', 'lon', 'distanciaAIndoamericano', 'cant_subtes_cercanos'],
#  ['lat', 'lon', 'distanciaAIndoamericano', 'cant_trenes_cercanos'],
#  ['lat', 'lon', 'distanciaAIndoamericano', 'distancia_delitoMenor'],
#  ['lat', 'lon', 'distanciaAIndoamericano', 'distancia_delitoGrave'],
#  ['lat', 'lon', 'cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['lat', 'lon', 'cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['lat', 'lon', 'cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['lat', 'lon', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['lat', 'lon', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['lat', 'lon', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['lat', 'surface_total_in_m2', 'cant_prop', 'distancia_al_centro'],
#  ['lat', 'surface_total_in_m2', 'cant_prop', 'distanciaAIndoamericano'],
#  ['lat', 'surface_total_in_m2', 'cant_prop', 'cant_subtes_cercanos'],
#  ['lat', 'surface_total_in_m2', 'cant_prop', 'cant_trenes_cercanos'],
#  ['lat', 'surface_total_in_m2', 'cant_prop', 'distancia_delitoMenor'],
#  ['lat', 'surface_total_in_m2', 'cant_prop', 'distancia_delitoGrave'],
#  ['lat',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distanciaAIndoamericano'],
#  ['lat', 'surface_total_in_m2', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['lat', 'surface_total_in_m2', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['lat',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distancia_delitoMenor'],
#  ['lat',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distancia_delitoGrave'],
#  ['lat',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['lat',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['lat',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['lat',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ['lat',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['lat',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['lat',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['lat',
#   'surface_total_in_m2',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['lat',
#   'surface_total_in_m2',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['lat',
#   'surface_total_in_m2',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['lat', 'cant_prop', 'distancia_al_centro', 'distanciaAIndoamericano'],
#  ['lat', 'cant_prop', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['lat', 'cant_prop', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['lat', 'cant_prop', 'distancia_al_centro', 'distancia_delitoMenor'],
#  ['lat', 'cant_prop', 'distancia_al_centro', 'distancia_delitoGrave'],
#  ['lat', 'cant_prop', 'distanciaAIndoamericano', 'cant_subtes_cercanos'],
#  ['lat', 'cant_prop', 'distanciaAIndoamericano', 'cant_trenes_cercanos'],
#  ['lat', 'cant_prop', 'distanciaAIndoamericano', 'distancia_delitoMenor'],
#  ['lat', 'cant_prop', 'distanciaAIndoamericano', 'distancia_delitoGrave'],
#  ['lat', 'cant_prop', 'cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['lat', 'cant_prop', 'cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['lat', 'cant_prop', 'cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['lat', 'cant_prop', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['lat', 'cant_prop', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['lat', 'cant_prop', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['lat',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['lat',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['lat',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['lat',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ['lat',
#   'distancia_al_centro',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['lat',
#   'distancia_al_centro',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['lat',
#   'distancia_al_centro',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['lat',
#   'distancia_al_centro',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['lat',
#   'distancia_al_centro',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['lat',
#   'distancia_al_centro',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['lat',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['lat',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['lat',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['lat',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['lat',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['lat',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['lat',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['lat',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['lat',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['lat',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['lon', 'surface_total_in_m2', 'cant_prop', 'distancia_al_centro'],
#  ['lon', 'surface_total_in_m2', 'cant_prop', 'distanciaAIndoamericano'],
#  ['lon', 'surface_total_in_m2', 'cant_prop', 'cant_subtes_cercanos'],
#  ['lon', 'surface_total_in_m2', 'cant_prop', 'cant_trenes_cercanos'],
#  ['lon', 'surface_total_in_m2', 'cant_prop', 'distancia_delitoMenor'],
#  ['lon', 'surface_total_in_m2', 'cant_prop', 'distancia_delitoGrave'],
#  ['lon',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distanciaAIndoamericano'],
#  ['lon', 'surface_total_in_m2', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['lon', 'surface_total_in_m2', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['lon',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distancia_delitoMenor'],
#  ['lon',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distancia_delitoGrave'],
#  ['lon',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['lon',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['lon',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['lon',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ['lon',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['lon',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['lon',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['lon',
#   'surface_total_in_m2',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['lon',
#   'surface_total_in_m2',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['lon',
#   'surface_total_in_m2',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['lon', 'cant_prop', 'distancia_al_centro', 'distanciaAIndoamericano'],
#  ['lon', 'cant_prop', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['lon', 'cant_prop', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['lon', 'cant_prop', 'distancia_al_centro', 'distancia_delitoMenor'],
#  ['lon', 'cant_prop', 'distancia_al_centro', 'distancia_delitoGrave'],
#  ['lon', 'cant_prop', 'distanciaAIndoamericano', 'cant_subtes_cercanos'],
#  ['lon', 'cant_prop', 'distanciaAIndoamericano', 'cant_trenes_cercanos'],
#  ['lon', 'cant_prop', 'distanciaAIndoamericano', 'distancia_delitoMenor'],
#  ['lon', 'cant_prop', 'distanciaAIndoamericano', 'distancia_delitoGrave'],
#  ['lon', 'cant_prop', 'cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['lon', 'cant_prop', 'cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['lon', 'cant_prop', 'cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['lon', 'cant_prop', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['lon', 'cant_prop', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['lon', 'cant_prop', 'distancia_delitoMenor', 'distancia_delitoGrave'],
#  ['lon',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['lon',
#   'distancia_al_centro',
# ...
#  ['created_on',
#   'property_type',
#   'lon',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'lon',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'lon',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'lon',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'cant_prop',
#   'distancia_al_centro'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'cant_prop',
#   'distanciaAIndoamericano'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'cant_prop',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'cant_prop',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'cant_prop',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'cant_prop',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distanciaAIndoamericano'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'cant_prop',
#   'distancia_al_centro',
#   'distanciaAIndoamericano'],
#  ['created_on',
#   'property_type',
#   'cant_prop',
#   'distancia_al_centro',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'property_type',
#   'cant_prop',
#   'distancia_al_centro',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'property_type',
#   'cant_prop',
#   'distancia_al_centro',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'cant_prop',
#   'distancia_al_centro',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'cant_prop',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'property_type',
#   'cant_prop',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'property_type',
#   'cant_prop',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'cant_prop',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'cant_prop',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'property_type',
#   'cant_prop',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'cant_prop',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'cant_prop',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'cant_prop',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'cant_prop',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'property_type',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'property_type',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'distancia_al_centro',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'property_type',
#   'distancia_al_centro',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'distancia_al_centro',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'distancia_al_centro',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'distancia_al_centro',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'distancia_al_centro',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'property_type',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'property_type',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'property_type',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on', 'lat', 'lon', 'surface_total_in_m2', 'cant_prop'],
#  ['created_on', 'lat', 'lon', 'surface_total_in_m2', 'distancia_al_centro'],
#  ['created_on',
#   'lat',
#   'lon',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano'],
#  ['created_on', 'lat', 'lon', 'surface_total_in_m2', 'cant_subtes_cercanos'],
#  ['created_on', 'lat', 'lon', 'surface_total_in_m2', 'cant_trenes_cercanos'],
#  ['created_on', 'lat', 'lon', 'surface_total_in_m2', 'distancia_delitoMenor'],
#  ['created_on', 'lat', 'lon', 'surface_total_in_m2', 'distancia_delitoGrave'],
#  ['created_on', 'lat', 'lon', 'cant_prop', 'distancia_al_centro'],
#  ['created_on', 'lat', 'lon', 'cant_prop', 'distanciaAIndoamericano'],
#  ['created_on', 'lat', 'lon', 'cant_prop', 'cant_subtes_cercanos'],
#  ['created_on', 'lat', 'lon', 'cant_prop', 'cant_trenes_cercanos'],
#  ['created_on', 'lat', 'lon', 'cant_prop', 'distancia_delitoMenor'],
#  ['created_on', 'lat', 'lon', 'cant_prop', 'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'lon',
#   'distancia_al_centro',
#   'distanciaAIndoamericano'],
#  ['created_on', 'lat', 'lon', 'distancia_al_centro', 'cant_subtes_cercanos'],
#  ['created_on', 'lat', 'lon', 'distancia_al_centro', 'cant_trenes_cercanos'],
#  ['created_on', 'lat', 'lon', 'distancia_al_centro', 'distancia_delitoMenor'],
#  ['created_on', 'lat', 'lon', 'distancia_al_centro', 'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'lon',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'lat',
#   'lon',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'lat',
#   'lon',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lat',
#   'lon',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ['created_on', 'lat', 'lon', 'cant_subtes_cercanos', 'cant_trenes_cercanos'],
#  ['created_on', 'lat', 'lon', 'cant_subtes_cercanos', 'distancia_delitoMenor'],
#  ['created_on', 'lat', 'lon', 'cant_subtes_cercanos', 'distancia_delitoGrave'],
#  ['created_on', 'lat', 'lon', 'cant_trenes_cercanos', 'distancia_delitoMenor'],
#  ['created_on', 'lat', 'lon', 'cant_trenes_cercanos', 'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'lon',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'cant_prop',
#   'distancia_al_centro'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'cant_prop',
#   'distanciaAIndoamericano'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'cant_prop',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'cant_prop',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'cant_prop',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'cant_prop',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distanciaAIndoamericano'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'surface_total_in_m2',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'cant_prop',
#   'distancia_al_centro',
#   'distanciaAIndoamericano'],
#  ['created_on',
#   'lat',
#   'cant_prop',
#   'distancia_al_centro',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'lat',
#   'cant_prop',
#   'distancia_al_centro',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'lat',
#   'cant_prop',
#   'distancia_al_centro',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lat',
#   'cant_prop',
#   'distancia_al_centro',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'cant_prop',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'lat',
#   'cant_prop',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'lat',
#   'cant_prop',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lat',
#   'cant_prop',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'cant_prop',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'lat',
#   'cant_prop',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lat',
#   'cant_prop',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'cant_prop',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lat',
#   'cant_prop',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'cant_prop',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'lat',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'lat',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lat',
#   'distancia_al_centro',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'distancia_al_centro',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'lat',
#   'distancia_al_centro',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lat',
#   'distancia_al_centro',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'distancia_al_centro',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lat',
#   'distancia_al_centro',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'distancia_al_centro',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'lat',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lat',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lat',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lat',
#   'cant_subtes_cercanos',
#   'cant_trenes_cercanos',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'cant_subtes_cercanos',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lat',
#   'cant_trenes_cercanos',
#   'distancia_delitoMenor',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lon',
#   'surface_total_in_m2',
#   'cant_prop',
#   'distancia_al_centro'],
#  ['created_on',
#   'lon',
#   'surface_total_in_m2',
#   'cant_prop',
#   'distanciaAIndoamericano'],
#  ['created_on',
#   'lon',
#   'surface_total_in_m2',
#   'cant_prop',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'lon',
#   'surface_total_in_m2',
#   'cant_prop',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'lon',
#   'surface_total_in_m2',
#   'cant_prop',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lon',
#   'surface_total_in_m2',
#   'cant_prop',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lon',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distanciaAIndoamericano'],
#  ['created_on',
#   'lon',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'lon',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'lon',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lon',
#   'surface_total_in_m2',
#   'distancia_al_centro',
#   'distancia_delitoGrave'],
#  ['created_on',
#   'lon',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'cant_subtes_cercanos'],
#  ['created_on',
#   'lon',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'cant_trenes_cercanos'],
#  ['created_on',
#   'lon',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'distancia_delitoMenor'],
#  ['created_on',
#   'lon',
#   'surface_total_in_m2',
#   'distanciaAIndoamericano',
#   'distancia_delitoGrave'],
#  ...]

# %%
resultados = []
y = np.array(dataCapital['price_usd_per_m2'])

for j in list_columnas: 
    x = np.array(dataCapital.loc[:,j])
    x_train, x_test, y_train, y_test = train_test_split(x, y , test_size = 0.33, random_state = 42)
    resultados.append(linearR(x_train, x_test, y_train, y_test))

# %%
resultados.index(min(resultados))
# Out:
# 4074

# %%
list_columnas[4074]
# Out:
# ['created_on',
#  'property_type',
#  'lat',
#  'lon',
#  'surface_total_in_m2',
#  'cant_prop',
#  'distancia_al_centro',
#  'cant_subtes_cercanos',
#  'cant_trenes_cercanos',
#  'distancia_delitoMenor',
#  'distancia_delitoGrave']

# %%
x = np.array(dataCapital.loc[:,list_columnas[resultados.index(min(resultados))]])
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size = 0.33, random_state = 42)
linreg = LinearRegression()
linreg.fit(x_train, y_train)
y_pred = linreg.predict(x_test)

# %%
predicc = []
for i in range(len(y_test)):
    predicc.append((y_test[i], y_pred[i]))

predicc
# Out:
# [(3717.1764705882342, 2490.9897815473378),
#  (3608.695652173913, 2456.5663683251478),
#  (2836.7843137254908, 2700.7088723843917),
#  (1567.5675675675675, 1579.7257890528999),
#  (2720.36170212766, 2746.594809660688),
#  (4584.6153846153848, 2330.7962207100354),
#  (1477.7777777777774, 2102.4368956210092),
#  (1952.1432692307687, 1540.3505474911071),
#  (3110.1607142857142, 2728.0986815132201),
#  (2838.427947598253, 3425.2023756620474),
#  (4166.666666666667, 4200.8644737591967),
#  (1818.1818181818185, 1819.4936991995201),
#  (672.64573991031386, 1682.0687562874518),
#  (2500.0, 1638.9434625916183),
#  (2101.449275362319, 1705.1799636422656),
#  (3420.0, 2851.1720466581173),
#  (2365.853658536585, 2037.1735427728854),
#  (1000.0, 1500.5707905725576),
#  (3251.7482517482517, 4230.3705311901867),
#  (1460.8433734939758, 2082.2203207896091),
#  (1182.5726141078835, 1788.7104481002316),
#  (1894.7368421052633, 3128.0227365880273),
#  (2608.695652173913, 2363.625543102622),
#  (2241.3793103448274, 2515.2953501665033),
#  (3688.524590163935, 3676.3490703119896),
#  (2286.5853658536585, 2424.3271125578322),
#  (801.68776371308013, 1800.7583305560984),
#  (2800.0, 2323.8582283137366),
#  (1968.9281395348839, 2159.7701679575257),
#  (3100.0, 2980.3765930053778),
#  (802.00501253132848, 1772.8419800405391),
#  (2600.0, 3247.6366894212551),
#  (4270.27027027027, 3440.6885563558899),
#  (2282.608695652174, 2786.8599889990874),
#  (1521.7391304347825, 2196.6638438738883),
#  (2045.4545454545453, 2784.4881694484502),
#  (1766.666666666667, 1661.0483555099927),
#  (3163.8643965517244, 2417.4986380725168),
#  (2303.4883720930234, 2403.7519957157783),
#  (2077.9220779220777, 2287.2218203470111),
#  (2500.0, 1614.2139970567077),
#  (1400.6514657980454, 1961.1246206262149),
#  (5459.7701149425284, 4409.9460717737675),
