# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

data = pd.read_csv("setEntrenamiento.csv", low_memory = False)
data = data.drop('Unnamed: 0', axis = 1)
data['created_on'] = pd.to_datetime(data['created_on'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86846 entries, 0 to 86845
# Data columns (total 22 columns):
# created_on                 86846 non-null datetime64[ns]
# property_type              86846 non-null object
# lat                        86846 non-null float64
# lon                        86846 non-null float64
# barrio                     86846 non-null object
# price_aprox_usd            86846 non-null float64
# price_usd_per_m2           86846 non-null float64
# surface_total_in_m2        86846 non-null float64
# surface_covered_in_m2      86846 non-null float64
# zona                       86846 non-null object
# pileta                     86846 non-null int64
# cochera                    86846 non-null int64
# aire acondicionado         86846 non-null int64
# seguridad                  86846 non-null int64
# patio                      86846 non-null int64
# amenities                  86846 non-null int64
# distanciaCentro            86846 non-null float64
# ...

# %%
def fechaNumerica(x):
    return 10000*x.year + 100*x.month + x.day

# %%
dicc_tipos_prop = {"apartment" : 1, "house" : 2, "PH" : 3, "store" : 4}
dicc_tipos_zona = {"Bs.As. G.B.A. Zona Norte": 1, "Bs.As. G.B.A. Zona Oeste": 2, "Bs.As. G.B.A. Zona Sur": 3, "Capital Federal": 4 }
data.loc[:, 'property_type'] = data.property_type.apply(lambda x: dicc_tipos_prop.get(x))
data.loc[:, 'zona'] = data.zona.apply(lambda x: dicc_tipos_zona.get(x))
#data.loc[:, 'distancia_al_centro'] = data.distancia_al_centro.apply(lambda x: int(x))
data.loc[:, 'created_on'] = data.created_on.apply(fechaNumerica)
#dataCapital = data.loc[data.state_name.str.contains('Capital Federal'), :]

# %%
data
# Out:
#        created_on property_type        lat        lon           barrio  \
# 0        20140110          None -34.626980 -58.403893    San Cristobal
# 1        20140110          None -34.564311 -58.435499          Palermo
# 2        20140111          None -34.567363 -58.438127         Belgrano
# 3        20140111          None -34.625791 -58.451452        Caballito
# 4        20140121          None -34.639326 -58.505648       Villa Luro
# 5        20140124          None -34.554660 -58.482712         Saavedra
# 6        20140124          None -34.639266 -58.478694         Floresta
# 7        20140128          None -34.583501 -58.406318          Palermo
# 8        20140201          None -34.625341 -58.481072         Floresta
# 9        20140206          None -34.577168 -58.538654     Villa Lugano
# 10       20140206          None -34.577168 -58.538654     Villa Lugano
# 11       20140206          None -34.577168 -58.538654     Villa Lugano
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score, KFold
from sklearn.linear_model import LinearRegression

columnas = ['created_on', 'property_type','pileta', 'lat', 'lon' ,'cochera', 'surface_total_in_m2',\
            'surface_covered_in_m2', 'seguridad', 'amenities','zona' ,\
            'subtes_cercanos', 'trenes_cercanos']

x = np.array(data.loc[:,columnas])
y = np.array(data['price_aprox_usd'])
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
from sklearn.metrics import mean_squared_error
def linearR(x_train, x_test, y_train, y_test):
    linreg = LinearRegression()
    linreg.fit(x_train, y_train)
    y_pred = linreg.predict(x_test)
    #return y_pred
    return np.sqrt(mean_squared_error(y_test, y_pred))

# %%
import itertools


columnas = ['created_on', 'property_type','pileta', 'lat', 'lon' ,'cochera', 'surface_total_in_m2',\
            'surface_covered_in_m2', 'seguridad', 'amenities','zona' ,\
            'subtes_cercanos', 'trenes_cercanos']

list_columnas = []

for r in range(2, len(columnas)):

    res = itertools.combinations(columnas, r)
    for e in res:
        list_columnas.append(list(e))
list_columnas
# Out:
# [['created_on', 'property_type'],
#  ['created_on', 'pileta'],
#  ['created_on', 'lat'],
#  ['created_on', 'lon'],
#  ['created_on', 'cochera'],
#  ['created_on', 'surface_total_in_m2'],
#  ['created_on', 'surface_covered_in_m2'],
#  ['created_on', 'seguridad'],
#  ['created_on', 'amenities'],
#  ['created_on', 'zona'],
#  ['created_on', 'subtes_cercanos'],
#  ['created_on', 'trenes_cercanos'],
#  ['property_type', 'pileta'],
#  ['property_type', 'lat'],
#  ['property_type', 'lon'],
#  ['property_type', 'cochera'],
#  ['property_type', 'surface_total_in_m2'],
#  ['property_type', 'surface_covered_in_m2'],
#  ['property_type', 'seguridad'],
#  ['property_type', 'amenities'],
#  ['property_type', 'zona'],
#  ['property_type', 'subtes_cercanos'],
#  ['property_type', 'trenes_cercanos'],
#  ['pileta', 'lat'],
#  ['pileta', 'lon'],
#  ['pileta', 'cochera'],
#  ['pileta', 'surface_total_in_m2'],
#  ['pileta', 'surface_covered_in_m2'],
#  ['pileta', 'seguridad'],
# ...

# %%
resultados = []
y = np.array(data['price_usd_per_m2'])

for j in list_columnas: 
    x = np.array(data.loc[:,j])
    x_train, x_test, y_train, y_test = train_test_split(x, y , test_size = 0.33, random_state = 42)
    resultados.append(linearR(x_train, x_test, y_train, y_test))

# %%
resultados.index(min(resultados))
# Out:
# 8174

# %%
list_columnas[resultados.index(min(resultados))]
# Out:
# ['created_on',
#  'property_type',
#  'lat',
#  'lon',
#  'cochera',
#  'surface_total_in_m2',
#  'surface_covered_in_m2',
#  'seguridad',
#  'amenities',
#  'zona',
#  'subtes_cercanos',
#  'trenes_cercanos']

# %%
min(resultados)
# Out:
# 908.32583325316955

# %%
len(resultados)
# Out:
# 8177

# %%
x = np.array(data.loc[:,list_columnas[resultados.index(min(resultados))]])
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size = 0.33, random_state = 42)
linreg = LinearRegression()
linreg.fit(x_train, y_train)
y_pred = linreg.predict(x_test)

# %%
predicc = []
for i in range(len(y_test)):
    predicc.append((y_test[i], y_pred[i]))

predicc
# Out:
# [(2755.1020408163267, 1327.9890065605541),
#  (1850.0, 1781.6400422064435),
#  (1065.2173913043478, 2080.9826622881628),
#  (1229.1666666666667, 1100.9296544205972),
#  (2219.730941704036, 1656.8956323243292),
#  (322.58064516129031, 1207.1820418277021),
#  (1434.4262295081967, 2225.0937888487206),
#  (625.0, 492.75953174702227),
#  (2447.7277894736844, 2413.0295945897196),
#  (190.0, 1954.5621596441888),
#  (2395.833333333333, 3128.0891808959823),
#  (2684.2592592592591, 2758.8396688066678),
#  (2744.3609022556398, 2817.4225538878491),
#  (2000.0, 1029.8667285332449),
#  (400.0, 750.65010977710699),
#  (2687.8529411764707, 3059.6998344084823),
#  (2052.7859237536659, 1845.7623414610098),
#  (1000.0, 1528.2920518671708),
#  (1239.1304347826087, 1993.2788408151209),
#  (2449.1767500000001, 2099.4132825975212),
#  (1289.1304347826087, 1256.573931256713),
#  (2218.75, 1707.8762786185362),
#  (1619.7183098591549, 1851.9011850714123),
#  (2468.4210526315792, 2807.7190156281686),
# ...

# %%
#Implemento CART: Clasification and Regression Trees
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

regressor = DecisionTreeRegressor(max_depth = 2)
dt_fit = regressor.fit(x_train, y_train)
dt_scores = cross_val_score(dt_fit, x_train, y_train, cv = 5)
np.mean(dt_scores)
# Out:
# 0.4099288195931578

# %%
x = np.array(data.loc[:,list_columnas[resultados.index(min(resultados))]])
y = np.array(data['price_aprox_usd'])
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)

dt = DecisionTreeRegressor(max_depth = 14)
dt_fit = dt.fit(x_train, y_train)

dt_scores = cross_val_score(dt, x_train, y_train, cv = 10)
print("mean cross validation score: {}".format(np.mean(dt_scores)))
print("score without cv: {}".format(dt_fit.score(x_train, y_train)))

 #on the test or hold-out set
from sklearn.metrics import r2_score
print(r2_score(y_test, dt_fit.predict(x_test)))
print(dt_fit.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-dbfa20c84e1f> in <module>()
# ----> 1 x = np.array(data.loc[:,list_columnas[resultados.index(min(resultados))]])
#       2 y = np.array(data['price_aprox_usd'])
#       3 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)
#       4
#       5 dt = DecisionTreeRegressor(max_depth = 14)
#
# NameError: name 'list_columnas' is not defined

# %%
y_pred = dt_fit.predict(x_test)
predicc = []
for i in range(len(y_test)):
    predicc.append((y_test[i], y_pred[i]))

predicc
# Out:
# [(2800000.0, 2850000.0),
#  (110000.0, 124479.67125),
#  (220003.47, 208046.18206896551),
#  (270000.0, 146000.0),
#  (123000.0, 127868.77777777778),
#  (340000.0, 465688.14189473691),
#  (150000.0, 208936.7816091954),
#  (190000.0, 201800.0),
#  (149000.0, 129913.3213670886),
#  (75000.0, 90738.147067669168),
#  (200000.0, 227523.87534883723),
#  (120000.0, 109531.26472081218),
#  (245000.0, 402666.66666666669),
#  (55000.0, 69477.548252427179),
#  (112000.0, 107067.41403333331),
#  (1300000.0, 1787058.8235294118),
#  (265000.0, 238580.35714285713),
#  (145000.0, 111833.33333333333),
#  (93994.0, 92262.946808510635),
#  (298000.0, 384091.8367346939),
#  (87530.0, 77861.76470588235),
#  (140000.0, 146468.75),
#  (85512.910000000003, 97757.287862595447),
#  (240000.0, 313403.77307692304),
#  (92000.0, 75960.488181818189),
#  (535000.0, 555353.84615384613),
#  (280000.0, 350571.42857142858),
#  (480000.0, 334925.80538461538),
#  (405000.0, 384091.8367346939),
#  (83000.0, 93875.0),
# ...

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=16, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
def generarMuestra(df):
    muestra = df.sample(frac = 0.8, replace = True)
  

    x_train = np.array(muestra.loc[:,['created_on', 'property_type', 'lat', 'lon', 'cochera', 'surface_total_in_m2',\
                       'surface_covered_in_m2', 'seguridad', 'amenities', 'zona', 'subtes_cercanos', 'trenes_cercanos']])
    y_train = np.array(muestra.loc[:, 'price_aprox_usd'])

    return x_train, y_train

def generarTest(df):
    test = df.sample(frac = 0.2)
  

    x_test = np.array(test.loc[:,['created_on', 'property_type', 'lat', 'lon', 'cochera', 'surface_total_in_m2',\
                       'surface_covered_in_m2', 'seguridad', 'amenities', 'zona', 'subtes_cercanos', 'trenes_cercanos']])
    y_test = np.array(test.loc[:, 'price_aprox_usd'])

    return x_test, y_test

# %%
testBagging = data.loc[:, ['created_on', 'property_type', 'lat', 'lon', 'cochera', 'surface_total_in_m2',\
                       'surface_covered_in_m2', 'price_aprox_usd', 'seguridad', 'amenities', 'zona', 'subtes_cercanos', 'trenes_cercanos']]
x_train1, y_train1 = generarMuestra(testBagging)
x_train2, y_train2 = generarMuestra(testBagging)
x_train3, y_train3 = generarMuestra(testBagging)
x_train4, y_train4 = generarMuestra(testBagging)
x_train5, y_train5 = generarMuestra(testBagging)

x_test, y_test = generarTest(testBagging)

dt = DecisionTreeRegressor(max_depth = 14)
dt_fit1 = dt.fit(x_train1, y_train1)
dt_fit2 = dt.fit(x_train2, y_train2)
dt_fit3 = dt.fit(x_train3, y_train3)
#dt_fit4 = dt.fit(x_train4, y_train4)
#dt_fit5 = dt.fit(x_train5, y_train5)

# %%
dt_scores1 = cross_val_score(dt, x_train1, y_train1, cv = 11)
print("mean cross validation score: {}".format(np.mean(dt_scores1)))
dt_scores2 = cross_val_score(dt, x_train2, y_train2, cv = 11)
print("mean cross validation score: {}".format(np.mean(dt_scores2)))
dt_scores3 = cross_val_score(dt, x_train3, y_train3, cv = 11)
print("mean cross validation score: {}".format(np.mean(dt_scores3)))
#dt_scores4 = cross_val_score(dt, x_train4, y_train4, cv = 11)
#print("mean cross validation score: {}".format(np.mean(dt_scores4)))
#dt_scores5 = cross_val_score(dt, x_train5, y_train5, cv = 11)
#print("mean cross validation score: {}".format(np.mean(dt_scores5)))
#print("score without cv: {}".format(dt_fit.score(x_train1, y_train1)))
# Out:
# mean cross validation score: 0.748369084837
# mean cross validation score: 0.796398078249
# mean cross validation score: 0.785545024644

# %%
predictions = []

predictions.append(dt_fit1.predict(x_test))
predictions.append(dt_fit2.predict(x_test))
predictions.append(dt_fit3.predict(x_test))
#predictions.append(dt_fit4.predict(x_test))
#predictions.append(dt_fit5.predict(x_test))

dfPredictions = pd.DataFrame(predictions)
avgPrediction = dfPredictions.mean(axis=0).values

np.sqrt(mean_squared_error(y_test, avgPrediction))
#5trees 186594.58951060136
#4trees 155819.94625066125
#3trees 149426.31084846103
#2trees 182278.88921424065
# Out:
# 142653.4930379618

# %%
result = pd.DataFrame(y_test)
result['prediction'] = avgPrediction
result
# Out:
#                 0    prediction
# 0       116000.00  8.397895e+04
# 1       215000.00  3.175000e+05
# 2       360000.00  3.557838e+05
# 3        90000.00  2.106223e+05
# 4       195000.00  2.516197e+05
# 5       250000.00  2.347639e+05
# 6       130000.00  1.266286e+05
# 7        65000.00  9.322496e+04
# 8       125080.00  1.117439e+05
# 9       155000.00  2.106223e+05
# 10      320000.00  2.549302e+05
# 11      234452.00  2.806647e+05
# 12      123500.00  9.829118e+04
# 13      107000.00  9.036957e+04
# 14      104000.00  8.038602e+04
# 15      160000.00  1.607632e+05
# 16       59000.00  8.500000e+04
# 17       85000.00  7.345085e+04
# 18       87000.00  9.631140e+04
# 19      125700.00  1.064106e+05
# 20      210000.00  1.759899e+05
# 21      140000.00  1.411382e+05
# 22      120000.00  1.050000e+05
# 23       99000.00  1.072630e+05
# 24      870000.00  8.024221e+05
# 25      410000.00  4.663671e+05
# 26       79616.38  7.756414e+04
# 27      231125.92  1.894316e+05
# ...

# %%
def salvarSupTotal(reg):
    if reg['surface_total_in_m2'] == 0:
        reg['surface_total_in_m2'] = 100
    return reg['surface_total_in_m2']

def salvarSupCovered(reg):
    
    if reg['surface_covered_in_m2'] == 0:
        reg['surface_covered_in_m2'] = 100
    return reg['surface_covered_in_m2']

# %%
setTesteo = pd.read_csv("setTesteo.csv", low_memory=False)
testId = setTesteo['id']
setTesteo = setTesteo.loc[:, ['created_on', 'property_type', 'lat', 'lon', 'cochera', 'surface_total_in_m2',\
                       'surface_covered_in_m2', 'seguridad', 'amenities', 'zona', 'subtes_cercanos', 'trenes_cercanos']]
setTesteo['created_on'] = pd.to_datetime(setTesteo['created_on'])
dicc_tipos_prop = {"apartment" : 1, "house" : 2, "PH" : 3, "store" : 4}
dicc_tipos_zona = {"Bs.As. G.B.A. Zona Norte": 1, "Bs.As. G.B.A. Zona Oeste": 2, "Bs.As. G.B.A. Zona Sur": 3, "Capital Federal": 4, "Buenos Aires Interior": 4 }
setTesteo.loc[:, 'property_type'] = setTesteo.property_type.apply(lambda x: dicc_tipos_prop.get(x))
setTesteo.loc[:, 'zona'] = setTesteo.zona.apply(lambda x: dicc_tipos_zona.get(x))
setTesteo.loc[:, 'created_on'] = setTesteo.created_on.apply(fechaNumerica)
setTesteo['surface_total_in_m2'] = setTesteo.apply(salvarSupTotal, axis=1)
setTesteo['surface_covered_in_m2'] = setTesteo.apply(salvarSupCovered, axis=1)
setTesteo
# Out:
#        created_on  property_type        lat        lon  cochera  \
# 0        20170824              1 -34.610988 -58.363464        1
# 1        20170825              1 -34.583720 -58.425026        0
# 2        20170801              1 -34.589363 -58.412880        0
# 3        20170801              1 -34.587481 -58.450823        0
# 4        20170801              1 -34.587481 -58.450823        0
# 5        20170801              1 -34.587481 -58.450823        0
# 6        20170801              1 -34.587481 -58.450823        0
# 7        20170801              1 -34.587481 -58.450823        0
# 8        20170801              1 -34.578721 -58.457095        0
# 9        20170801              1 -34.608808 -58.421084        0
# 10       20170801              1 -34.608808 -58.421084        0
# 11       20170801              1 -34.608808 -58.421084        0
# 12       20170801              1 -34.613029 -58.363783        0
# 13       20170801              1 -34.562211 -58.442515        0
# ...

# %%
predicciones = []

predicciones.append(dt_fit1.predict(setTesteo))
predicciones.append(dt_fit2.predict(setTesteo))
predicciones.append(dt_fit3.predict(setTesteo))

dfPredictions = pd.DataFrame(predicciones)
avgPrediction = dfPredictions.mean(axis=0).values

# %%
dataPredictions = {'id' : testId,
        'price_usd' : avgPrediction}
testPrediction = pd.DataFrame(dataPredictions)
testPrediction
# Out:
#             id      price_usd
# 0         3632  878888.888889
# 1         3633  440193.423158
# 2      2263404  181234.626579
# 3      2263405   86306.455172
# 4      2263406  133448.389524
# 5      2263407   86306.455172
# 6      2263408   86306.455172
# 7      2263409   86306.455172
# 8      2263410  212460.683232
# 9      2263411  110657.140144
# 10     2263412  110657.140144
# 11     2263413  110657.140144
# 12     2263415  343466.666667
# 13     2263416  397794.930909
# 14     2263417  112385.611548
# 15     2263418  112385.611548
# 16     2263419  112385.611548
# 17     2263420  112385.611548
# 18     2263421  112385.611548
# 19     2263422  112385.611548
# 20     2263423  112385.611548
# 21     2263424  112385.611548
# 22     2263425  133448.389524
# 23     2263426  133448.389524
# 24     2263427  133448.389524
# 25     2263428  133448.389524
# 26     2263429  133448.389524
# 27     2263430  112385.611548
# 28     2263431  112385.611548
# 29     2263432   86306.455172
# ...

# %%
#exportar csv con formato para kaggle
fileName = "pricePrediction.csv"
testPrediction.to_csv(fileName, sep=',', index = False)

# %%
setTesteo2 = pd.read_csv("setTesteo.csv", low_memory=False)
testId = setTesteo2['id']
setTesteo2['created_on'] = pd.to_datetime(setTesteo2['created_on'])
dicc_tipos_prop = {"apartment" : 1, "house" : 2, "PH" : 3, "store" : 4}
dicc_tipos_zona = {"Bs.As. G.B.A. Zona Norte": 1, "Bs.As. G.B.A. Zona Oeste": 2, "Bs.As. G.B.A. Zona Sur": 3, "Capital Federal": 4, "Buenos Aires Interior": 4 }
setTesteo2.loc[:, 'property_type'] = setTesteo2.property_type.apply(lambda x: dicc_tipos_prop.get(x))
setTesteo2.loc[:, 'zona'] = setTesteo2.zona.apply(lambda x: dicc_tipos_zona.get(x))
setTesteo2.loc[:, 'created_on'] = setTesteo2.created_on.apply(fechaNumerica)
setTesteo2['surface_total_in_m2'] = setTesteo2.apply(salvarSupTotal, axis=1)
setTesteo2['surface_covered_in_m2'] = setTesteo2.apply(salvarSupCovered, axis=1)
setTesteo2 = setTesteo2.drop('Unnamed: 0', axis = 1)
setTesteo2 = setTesteo2.drop('barrio', axis = 1)
setTesteo2
# Out:
#             id  created_on  property_type        lat        lon  \
# 0         3632    20170824              1 -34.610988 -58.363464
# 1         3633    20170825              1 -34.583720 -58.425026
# 2      2263404    20170801              1 -34.589363 -58.412880
# 3      2263405    20170801              1 -34.587481 -58.450823
# 4      2263406    20170801              1 -34.587481 -58.450823
# 5      2263407    20170801              1 -34.587481 -58.450823
# 6      2263408    20170801              1 -34.587481 -58.450823
# 7      2263409    20170801              1 -34.587481 -58.450823
# 8      2263410    20170801              1 -34.578721 -58.457095
# 9      2263411    20170801              1 -34.608808 -58.421084
# 10     2263412    20170801              1 -34.608808 -58.421084
# 11     2263413    20170801              1 -34.608808 -58.421084
# 12     2263415    20170801              1 -34.613029 -58.363783
# 13     2263416    20170801              1 -34.562211 -58.442515
# ...

# %%
testBagging2 = data
#testBagging2['created_on'] = pd.to_datetime(testBagging2['created_on'])
dicc_tipos_prop = {"apartment" : 1, "house" : 2, "PH" : 3, "store" : 4}
dicc_tipos_zona = {"Bs.As. G.B.A. Zona Norte": 1, "Bs.As. G.B.A. Zona Oeste": 2, "Bs.As. G.B.A. Zona Sur": 3, "Capital Federal": 4, "Buenos Aires Interior": 4 }
#testBagging2.loc[:, 'property_type'] = testBagging2.property_type.apply(lambda x: dicc_tipos_prop.get(x))
#testBagging2.loc[:, 'zona'] = testBagging2.zona.apply(lambda x: dicc_tipos_zona.get(x))
#testBagging2.loc[:, 'created_on'] = testBagging2.created_on.apply(fechaNumerica)
testBagging2 = testBagging2.drop('barrio', axis = 1)
testBagging2 = testBagging2.drop('price_usd_per_m2', axis = 1)

x_train12, y_train12 = generarMuestra(testBagging2)
x_train22, y_train22 = generarMuestra(testBagging2)
x_train32, y_train32 = generarMuestra(testBagging2)

x_test2, y_test2 = generarTest(testBagging2)

dt2 = DecisionTreeRegressor(max_depth = 25)
dt_fit12 = dt2.fit(x_train12, y_train12)
dt_fit22 = dt2.fit(x_train22, y_train22)
dt_fit32 = dt2.fit(x_train32, y_train32)
# Out:
#        created_on  property_type        lat        lon  price_aprox_usd  \
# 0        20140110              1 -34.626980 -58.403893          77000.0
# 1        20140110              1 -34.564311 -58.435499         390000.0
# 2        20140111              1 -34.567363 -58.438127         250000.0
# 3        20140111              1 -34.625791 -58.451452         153000.0
# 4        20140121              1 -34.639326 -58.505648         165000.0
# 5        20140124              3 -34.554660 -58.482712         180000.0
# 6        20140124              1 -34.639266 -58.478694         110000.0
# 7        20140128              1 -34.583501 -58.406318         410000.0
# 8        20140201              1 -34.625341 -58.481072         100000.0
# 9        20140206              1 -34.577168 -58.538654          78000.0
# 10       20140206              1 -34.577168 -58.538654          68000.0
# 11       20140206              1 -34.577168 -58.538654          72000.0
# ...

# %%
dt_scores12 = cross_val_score(dt2, x_train12, y_train12, cv = 11)
print("mean cross validation score: {}".format(np.mean(dt_scores12)))
dt_scores22 = cross_val_score(dt2, x_train22, y_train22, cv = 11)
print("mean cross validation score: {}".format(np.mean(dt_scores22)))
dt_scores32 = cross_val_score(dt2, x_train32, y_train32, cv = 11)
print("mean cross validation score: {}".format(np.mean(dt_scores32)))
# Out:
# mean cross validation score: 0.811061121296
# mean cross validation score: 0.757266255278
# mean cross validation score: 0.759335438564

# %%
predicciones2 = []

predicciones2.append(dt_fit12.predict(setTesteo2))
predicciones2.append(dt_fit22.predict(setTesteo2))
predicciones2.append(dt_fit32.predict(setTesteo2))

dfPredictions2 = pd.DataFrame(predicciones2)
avgPrediction2 = dfPredictions2.mean(axis=0).values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-172-2a4e147db7d6> in <module>()
#       1 predicciones2 = []
#       2
# ----> 3 predicciones2.append(dt_fit12.predict(setTesteo2))
#       4 predicciones2.append(dt_fit22.predict(setTesteo2))
#       5 predicciones2.append(dt_fit32.predict(setTesteo2))
#
# /home/martin/Documents/OrgaDeDatos/anaconda2/lib/python2.7/site-packages/sklearn/tree/tree.pyc in predict(self, X, check_input)
#     402         """
#     403
# --> 404         X = self._validate_X_predict(X, check_input)
#     405         proba = self.tree_.predict(X)
#     406         n_samples = X.shape[0]
#
# /home/martin/Documents/OrgaDeDatos/anaconda2/lib/python2.7/site-packages/sklearn/tree/tree.pyc in _validate_X_predict(self, X, check_input)
#     374                              "match the input. Model n_features is %s and "
# ...
