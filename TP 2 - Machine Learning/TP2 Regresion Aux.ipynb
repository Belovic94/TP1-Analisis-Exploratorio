# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

data = pd.read_csv("setTesteo.csv", low_memory = False)
data = data.drop('Unnamed: 0', axis = 1)
data['created_on'] = pd.to_datetime(data['created_on'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14166 entries, 0 to 14165
# Data columns (total 20 columns):
# created_on                 14166 non-null datetime64[ns]
# property_type              14166 non-null object
# lat                        14166 non-null float64
# lon                        14166 non-null float64
# barrio                     14166 non-null object
# surface_total_in_m2        14166 non-null float64
# surface_covered_in_m2      14166 non-null float64
# zona                       14166 non-null object
# pileta                     14166 non-null int64
# cochera                    14166 non-null int64
# aire acondicionado         14166 non-null int64
# seguridad                  14166 non-null int64
# patio                      14166 non-null int64
# amenities                  14166 non-null int64
# distanciaCentro            14166 non-null float64
# distanciaAIndoamericano    14166 non-null float64
# distanciaAFuerteApache     14166 non-null float64
# distanciaACarlosGardel     14166 non-null float64
# subtes_cercanos            14166 non-null int64
# trenes_cercanos            14166 non-null int64
# dtypes: datetime64[ns](1), float64(8), int64(8), object(3)
# memory usage: 2.2+ MB

# %%
def fechaNumerica(x):
    return 10000*x.year + 100*x.month + x.day

# %%
dicc_tipos_prop = {"apartment" : 1, "house" : 2, "PH" : 3, "store" : 4}
dicc_tipos_zona = {"Bs.As. G.B.A. Zona Norte": 1, "Bs.As. G.B.A. Zona Oeste": 2, "Bs.As. G.B.A. Zona Sur": 3, "Capital Federal": 4 }
data.loc[:, 'property_type'] = data.property_type.apply(lambda x: dicc_tipos_prop.get(x))
data.loc[:, 'zona'] = data.zona.apply(lambda x: dicc_tipos_zona.get(x))
data.loc[:, 'created_on'] = data.created_on.apply(fechaNumerica)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86846 entries, 0 to 86845
# Data columns (total 22 columns):
# created_on                 86846 non-null int64
# property_type              86846 non-null int64
# lat                        86846 non-null float64
# lon                        86846 non-null float64
# barrio                     86846 non-null object
# price_aprox_usd            86846 non-null float64
# price_usd_per_m2           86846 non-null float64
# surface_total_in_m2        86846 non-null float64
# surface_covered_in_m2      86846 non-null float64
# zona                       86846 non-null int64
# pileta                     86846 non-null int64
# cochera                    86846 non-null int64
# aire acondicionado         86846 non-null int64
# seguridad                  86846 non-null int64
# patio                      86846 non-null int64
# amenities                  86846 non-null int64
# distanciaCentro            86846 non-null float64
# distanciaAIndoamericano    86846 non-null float64
# distanciaAFuerteApache     86846 non-null float64
# distanciaACarlosGardel     86846 non-null float64
# subtes_cercanos            86846 non-null int64
# trenes_cercanos            86846 non-null int64
# dtypes: float64(10), int64(11), object(1)
# memory usage: 14.6+ MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score, KFold
from sklearn.linear_model import LinearRegression

columnas = ['created_on', 'property_type','pileta', 'lat', 'lon' ,'cochera', 'surface_total_in_m2',\
            'surface_covered_in_m2', 'seguridad', 'amenities','zona' ,\
            'subtes_cercanos', 'trenes_cercanos']

x = np.array(data.loc[:,columnas])
y = np.array(data['price_aprox_usd'])
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
#Algoritmo de Linear Regression
from sklearn.metrics import mean_squared_error
def linearR(x_train, x_test, y_train, y_test):
    linreg = LinearRegression()
    linreg.fit(x_train, y_train)
    y_pred = linreg.predict(x_test)
    return mean_squared_error(y_test, y_pred)

# %%
#Creo todas las combinaciones posibles con estas columnas
import itertools

columnas = ['created_on', 'property_type','pileta', 'lat', 'lon' ,'cochera', 'surface_total_in_m2',\
            'surface_covered_in_m2', 'seguridad', 'amenities','zona' ,\
            'subtes_cercanos', 'trenes_cercanos']

list_columnas = []

for r in range(2, len(columnas)):

    res = itertools.combinations(columnas, r)
    for e in res:
        list_columnas.append(list(e))
list_columnas
# Out:
# [['created_on', 'property_type'],
#  ['created_on', 'pileta'],
#  ['created_on', 'lat'],
#  ['created_on', 'lon'],
#  ['created_on', 'cochera'],
#  ['created_on', 'surface_total_in_m2'],
#  ['created_on', 'surface_covered_in_m2'],
#  ['created_on', 'seguridad'],
#  ['created_on', 'amenities'],
#  ['created_on', 'zona'],
#  ['created_on', 'subtes_cercanos'],
#  ['created_on', 'trenes_cercanos'],
#  ['property_type', 'pileta'],
#  ['property_type', 'lat'],
#  ['property_type', 'lon'],
#  ['property_type', 'cochera'],
#  ['property_type', 'surface_total_in_m2'],
#  ['property_type', 'surface_covered_in_m2'],
#  ['property_type', 'seguridad'],
#  ['property_type', 'amenities'],
#  ['property_type', 'zona'],
#  ['property_type', 'subtes_cercanos'],
#  ['property_type', 'trenes_cercanos'],
#  ['pileta', 'lat'],
#  ['pileta', 'lon'],
#  ['pileta', 'cochera'],
#  ['pileta', 'surface_total_in_m2'],
#  ['pileta', 'surface_covered_in_m2'],
#  ['pileta', 'seguridad'],
#  ['pileta', 'amenities'],
#  ['pileta', 'zona'],
#  ['pileta', 'subtes_cercanos'],
#  ['pileta', 'trenes_cercanos'],
#  ['lat', 'lon'],
#  ['lat', 'cochera'],
#  ['lat', 'surface_total_in_m2'],
#  ['lat', 'surface_covered_in_m2'],
#  ['lat', 'seguridad'],
#  ['lat', 'amenities'],
#  ['lat', 'zona'],
#  ['lat', 'subtes_cercanos'],
#  ['lat', 'trenes_cercanos'],
#  ['lon', 'cochera'],
#  ['lon', 'surface_total_in_m2'],
#  ['lon', 'surface_covered_in_m2'],
#  ['lon', 'seguridad'],
#  ['lon', 'amenities'],
#  ['lon', 'zona'],
#  ['lon', 'subtes_cercanos'],
#  ['lon', 'trenes_cercanos'],
#  ['cochera', 'surface_total_in_m2'],
#  ['cochera', 'surface_covered_in_m2'],
#  ['cochera', 'seguridad'],
#  ['cochera', 'amenities'],
#  ['cochera', 'zona'],
#  ['cochera', 'subtes_cercanos'],
#  ['cochera', 'trenes_cercanos'],
#  ['surface_total_in_m2', 'surface_covered_in_m2'],
#  ['surface_total_in_m2', 'seguridad'],
#  ['surface_total_in_m2', 'amenities'],
#  ['surface_total_in_m2', 'zona'],
#  ['surface_total_in_m2', 'subtes_cercanos'],
#  ['surface_total_in_m2', 'trenes_cercanos'],
#  ['surface_covered_in_m2', 'seguridad'],
#  ['surface_covered_in_m2', 'amenities'],
#  ['surface_covered_in_m2', 'zona'],
#  ['surface_covered_in_m2', 'subtes_cercanos'],
#  ['surface_covered_in_m2', 'trenes_cercanos'],
#  ['seguridad', 'amenities'],
#  ['seguridad', 'zona'],
#  ['seguridad', 'subtes_cercanos'],
#  ['seguridad', 'trenes_cercanos'],
#  ['amenities', 'zona'],
#  ['amenities', 'subtes_cercanos'],
#  ['amenities', 'trenes_cercanos'],
#  ['zona', 'subtes_cercanos'],
#  ['zona', 'trenes_cercanos'],
#  ['subtes_cercanos', 'trenes_cercanos'],
#  ['created_on', 'property_type', 'pileta'],
#  ['created_on', 'property_type', 'lat'],
#  ['created_on', 'property_type', 'lon'],
#  ['created_on', 'property_type', 'cochera'],
#  ['created_on', 'property_type', 'surface_total_in_m2'],
#  ['created_on', 'property_type', 'surface_covered_in_m2'],
#  ['created_on', 'property_type', 'seguridad'],
#  ['created_on', 'property_type', 'amenities'],
#  ['created_on', 'property_type', 'zona'],
#  ['created_on', 'property_type', 'subtes_cercanos'],
#  ['created_on', 'property_type', 'trenes_cercanos'],
#  ['created_on', 'pileta', 'lat'],
#  ['created_on', 'pileta', 'lon'],
#  ['created_on', 'pileta', 'cochera'],
#  ['created_on', 'pileta', 'surface_total_in_m2'],
#  ['created_on', 'pileta', 'surface_covered_in_m2'],
#  ['created_on', 'pileta', 'seguridad'],
#  ['created_on', 'pileta', 'amenities'],
#  ['created_on', 'pileta', 'zona'],
#  ['created_on', 'pileta', 'subtes_cercanos'],
#  ['created_on', 'pileta', 'trenes_cercanos'],
#  ['created_on', 'lat', 'lon'],
#  ['created_on', 'lat', 'cochera'],
#  ['created_on', 'lat', 'surface_total_in_m2'],
#  ['created_on', 'lat', 'surface_covered_in_m2'],
#  ['created_on', 'lat', 'seguridad'],
#  ['created_on', 'lat', 'amenities'],
#  ['created_on', 'lat', 'zona'],
#  ['created_on', 'lat', 'subtes_cercanos'],
#  ['created_on', 'lat', 'trenes_cercanos'],
#  ['created_on', 'lon', 'cochera'],
#  ['created_on', 'lon', 'surface_total_in_m2'],
#  ['created_on', 'lon', 'surface_covered_in_m2'],
#  ['created_on', 'lon', 'seguridad'],
#  ['created_on', 'lon', 'amenities'],
#  ['created_on', 'lon', 'zona'],
#  ['created_on', 'lon', 'subtes_cercanos'],
#  ['created_on', 'lon', 'trenes_cercanos'],
#  ['created_on', 'cochera', 'surface_total_in_m2'],
#  ['created_on', 'cochera', 'surface_covered_in_m2'],
#  ['created_on', 'cochera', 'seguridad'],
#  ['created_on', 'cochera', 'amenities'],
#  ['created_on', 'cochera', 'zona'],
#  ['created_on', 'cochera', 'subtes_cercanos'],
#  ['created_on', 'cochera', 'trenes_cercanos'],
#  ['created_on', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['created_on', 'surface_total_in_m2', 'seguridad'],
#  ['created_on', 'surface_total_in_m2', 'amenities'],
#  ['created_on', 'surface_total_in_m2', 'zona'],
#  ['created_on', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['created_on', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['created_on', 'surface_covered_in_m2', 'seguridad'],
#  ['created_on', 'surface_covered_in_m2', 'amenities'],
#  ['created_on', 'surface_covered_in_m2', 'zona'],
#  ['created_on', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['created_on', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['created_on', 'seguridad', 'amenities'],
#  ['created_on', 'seguridad', 'zona'],
#  ['created_on', 'seguridad', 'subtes_cercanos'],
#  ['created_on', 'seguridad', 'trenes_cercanos'],
#  ['created_on', 'amenities', 'zona'],
#  ['created_on', 'amenities', 'subtes_cercanos'],
#  ['created_on', 'amenities', 'trenes_cercanos'],
#  ['created_on', 'zona', 'subtes_cercanos'],
#  ['created_on', 'zona', 'trenes_cercanos'],
#  ['created_on', 'subtes_cercanos', 'trenes_cercanos'],
#  ['property_type', 'pileta', 'lat'],
#  ['property_type', 'pileta', 'lon'],
#  ['property_type', 'pileta', 'cochera'],
#  ['property_type', 'pileta', 'surface_total_in_m2'],
#  ['property_type', 'pileta', 'surface_covered_in_m2'],
#  ['property_type', 'pileta', 'seguridad'],
#  ['property_type', 'pileta', 'amenities'],
#  ['property_type', 'pileta', 'zona'],
#  ['property_type', 'pileta', 'subtes_cercanos'],
#  ['property_type', 'pileta', 'trenes_cercanos'],
#  ['property_type', 'lat', 'lon'],
#  ['property_type', 'lat', 'cochera'],
#  ['property_type', 'lat', 'surface_total_in_m2'],
#  ['property_type', 'lat', 'surface_covered_in_m2'],
#  ['property_type', 'lat', 'seguridad'],
#  ['property_type', 'lat', 'amenities'],
#  ['property_type', 'lat', 'zona'],
#  ['property_type', 'lat', 'subtes_cercanos'],
#  ['property_type', 'lat', 'trenes_cercanos'],
#  ['property_type', 'lon', 'cochera'],
#  ['property_type', 'lon', 'surface_total_in_m2'],
#  ['property_type', 'lon', 'surface_covered_in_m2'],
#  ['property_type', 'lon', 'seguridad'],
#  ['property_type', 'lon', 'amenities'],
#  ['property_type', 'lon', 'zona'],
#  ['property_type', 'lon', 'subtes_cercanos'],
#  ['property_type', 'lon', 'trenes_cercanos'],
#  ['property_type', 'cochera', 'surface_total_in_m2'],
#  ['property_type', 'cochera', 'surface_covered_in_m2'],
#  ['property_type', 'cochera', 'seguridad'],
#  ['property_type', 'cochera', 'amenities'],
#  ['property_type', 'cochera', 'zona'],
#  ['property_type', 'cochera', 'subtes_cercanos'],
#  ['property_type', 'cochera', 'trenes_cercanos'],
#  ['property_type', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['property_type', 'surface_total_in_m2', 'seguridad'],
#  ['property_type', 'surface_total_in_m2', 'amenities'],
#  ['property_type', 'surface_total_in_m2', 'zona'],
#  ['property_type', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['property_type', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['property_type', 'surface_covered_in_m2', 'seguridad'],
#  ['property_type', 'surface_covered_in_m2', 'amenities'],
#  ['property_type', 'surface_covered_in_m2', 'zona'],
#  ['property_type', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['property_type', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['property_type', 'seguridad', 'amenities'],
#  ['property_type', 'seguridad', 'zona'],
#  ['property_type', 'seguridad', 'subtes_cercanos'],
#  ['property_type', 'seguridad', 'trenes_cercanos'],
#  ['property_type', 'amenities', 'zona'],
#  ['property_type', 'amenities', 'subtes_cercanos'],
#  ['property_type', 'amenities', 'trenes_cercanos'],
#  ['property_type', 'zona', 'subtes_cercanos'],
#  ['property_type', 'zona', 'trenes_cercanos'],
#  ['property_type', 'subtes_cercanos', 'trenes_cercanos'],
#  ['pileta', 'lat', 'lon'],
#  ['pileta', 'lat', 'cochera'],
#  ['pileta', 'lat', 'surface_total_in_m2'],
#  ['pileta', 'lat', 'surface_covered_in_m2'],
#  ['pileta', 'lat', 'seguridad'],
#  ['pileta', 'lat', 'amenities'],
#  ['pileta', 'lat', 'zona'],
#  ['pileta', 'lat', 'subtes_cercanos'],
#  ['pileta', 'lat', 'trenes_cercanos'],
#  ['pileta', 'lon', 'cochera'],
#  ['pileta', 'lon', 'surface_total_in_m2'],
#  ['pileta', 'lon', 'surface_covered_in_m2'],
#  ['pileta', 'lon', 'seguridad'],
#  ['pileta', 'lon', 'amenities'],
#  ['pileta', 'lon', 'zona'],
#  ['pileta', 'lon', 'subtes_cercanos'],
#  ['pileta', 'lon', 'trenes_cercanos'],
#  ['pileta', 'cochera', 'surface_total_in_m2'],
#  ['pileta', 'cochera', 'surface_covered_in_m2'],
#  ['pileta', 'cochera', 'seguridad'],
#  ['pileta', 'cochera', 'amenities'],
#  ['pileta', 'cochera', 'zona'],
#  ['pileta', 'cochera', 'subtes_cercanos'],
#  ['pileta', 'cochera', 'trenes_cercanos'],
#  ['pileta', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['pileta', 'surface_total_in_m2', 'seguridad'],
#  ['pileta', 'surface_total_in_m2', 'amenities'],
#  ['pileta', 'surface_total_in_m2', 'zona'],
#  ['pileta', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['pileta', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['pileta', 'surface_covered_in_m2', 'seguridad'],
#  ['pileta', 'surface_covered_in_m2', 'amenities'],
#  ['pileta', 'surface_covered_in_m2', 'zona'],
#  ['pileta', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['pileta', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['pileta', 'seguridad', 'amenities'],
#  ['pileta', 'seguridad', 'zona'],
#  ['pileta', 'seguridad', 'subtes_cercanos'],
#  ['pileta', 'seguridad', 'trenes_cercanos'],
#  ['pileta', 'amenities', 'zona'],
#  ['pileta', 'amenities', 'subtes_cercanos'],
#  ['pileta', 'amenities', 'trenes_cercanos'],
#  ['pileta', 'zona', 'subtes_cercanos'],
#  ['pileta', 'zona', 'trenes_cercanos'],
#  ['pileta', 'subtes_cercanos', 'trenes_cercanos'],
#  ['lat', 'lon', 'cochera'],
#  ['lat', 'lon', 'surface_total_in_m2'],
#  ['lat', 'lon', 'surface_covered_in_m2'],
#  ['lat', 'lon', 'seguridad'],
#  ['lat', 'lon', 'amenities'],
#  ['lat', 'lon', 'zona'],
#  ['lat', 'lon', 'subtes_cercanos'],
#  ['lat', 'lon', 'trenes_cercanos'],
#  ['lat', 'cochera', 'surface_total_in_m2'],
#  ['lat', 'cochera', 'surface_covered_in_m2'],
#  ['lat', 'cochera', 'seguridad'],
#  ['lat', 'cochera', 'amenities'],
#  ['lat', 'cochera', 'zona'],
#  ['lat', 'cochera', 'subtes_cercanos'],
#  ['lat', 'cochera', 'trenes_cercanos'],
#  ['lat', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['lat', 'surface_total_in_m2', 'seguridad'],
#  ['lat', 'surface_total_in_m2', 'amenities'],
#  ['lat', 'surface_total_in_m2', 'zona'],
#  ['lat', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['lat', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['lat', 'surface_covered_in_m2', 'seguridad'],
#  ['lat', 'surface_covered_in_m2', 'amenities'],
#  ['lat', 'surface_covered_in_m2', 'zona'],
#  ['lat', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['lat', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['lat', 'seguridad', 'amenities'],
#  ['lat', 'seguridad', 'zona'],
#  ['lat', 'seguridad', 'subtes_cercanos'],
#  ['lat', 'seguridad', 'trenes_cercanos'],
#  ['lat', 'amenities', 'zona'],
#  ['lat', 'amenities', 'subtes_cercanos'],
#  ['lat', 'amenities', 'trenes_cercanos'],
#  ['lat', 'zona', 'subtes_cercanos'],
#  ['lat', 'zona', 'trenes_cercanos'],
#  ['lat', 'subtes_cercanos', 'trenes_cercanos'],
#  ['lon', 'cochera', 'surface_total_in_m2'],
#  ['lon', 'cochera', 'surface_covered_in_m2'],
#  ['lon', 'cochera', 'seguridad'],
#  ['lon', 'cochera', 'amenities'],
#  ['lon', 'cochera', 'zona'],
#  ['lon', 'cochera', 'subtes_cercanos'],
#  ['lon', 'cochera', 'trenes_cercanos'],
#  ['lon', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['lon', 'surface_total_in_m2', 'seguridad'],
#  ['lon', 'surface_total_in_m2', 'amenities'],
#  ['lon', 'surface_total_in_m2', 'zona'],
#  ['lon', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['lon', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['lon', 'surface_covered_in_m2', 'seguridad'],
#  ['lon', 'surface_covered_in_m2', 'amenities'],
#  ['lon', 'surface_covered_in_m2', 'zona'],
#  ['lon', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['lon', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['lon', 'seguridad', 'amenities'],
#  ['lon', 'seguridad', 'zona'],
#  ['lon', 'seguridad', 'subtes_cercanos'],
#  ['lon', 'seguridad', 'trenes_cercanos'],
#  ['lon', 'amenities', 'zona'],
#  ['lon', 'amenities', 'subtes_cercanos'],
#  ['lon', 'amenities', 'trenes_cercanos'],
#  ['lon', 'zona', 'subtes_cercanos'],
#  ['lon', 'zona', 'trenes_cercanos'],
#  ['lon', 'subtes_cercanos', 'trenes_cercanos'],
#  ['cochera', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['cochera', 'surface_total_in_m2', 'seguridad'],
#  ['cochera', 'surface_total_in_m2', 'amenities'],
#  ['cochera', 'surface_total_in_m2', 'zona'],
#  ['cochera', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['cochera', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['cochera', 'surface_covered_in_m2', 'seguridad'],
#  ['cochera', 'surface_covered_in_m2', 'amenities'],
#  ['cochera', 'surface_covered_in_m2', 'zona'],
#  ['cochera', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['cochera', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['cochera', 'seguridad', 'amenities'],
#  ['cochera', 'seguridad', 'zona'],
#  ['cochera', 'seguridad', 'subtes_cercanos'],
#  ['cochera', 'seguridad', 'trenes_cercanos'],
#  ['cochera', 'amenities', 'zona'],
#  ['cochera', 'amenities', 'subtes_cercanos'],
#  ['cochera', 'amenities', 'trenes_cercanos'],
#  ['cochera', 'zona', 'subtes_cercanos'],
#  ['cochera', 'zona', 'trenes_cercanos'],
#  ['cochera', 'subtes_cercanos', 'trenes_cercanos'],
#  ['surface_total_in_m2', 'surface_covered_in_m2', 'seguridad'],
#  ['surface_total_in_m2', 'surface_covered_in_m2', 'amenities'],
#  ['surface_total_in_m2', 'surface_covered_in_m2', 'zona'],
#  ['surface_total_in_m2', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['surface_total_in_m2', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['surface_total_in_m2', 'seguridad', 'amenities'],
#  ['surface_total_in_m2', 'seguridad', 'zona'],
#  ['surface_total_in_m2', 'seguridad', 'subtes_cercanos'],
#  ['surface_total_in_m2', 'seguridad', 'trenes_cercanos'],
#  ['surface_total_in_m2', 'amenities', 'zona'],
#  ['surface_total_in_m2', 'amenities', 'subtes_cercanos'],
#  ['surface_total_in_m2', 'amenities', 'trenes_cercanos'],
#  ['surface_total_in_m2', 'zona', 'subtes_cercanos'],
#  ['surface_total_in_m2', 'zona', 'trenes_cercanos'],
#  ['surface_total_in_m2', 'subtes_cercanos', 'trenes_cercanos'],
#  ['surface_covered_in_m2', 'seguridad', 'amenities'],
#  ['surface_covered_in_m2', 'seguridad', 'zona'],
#  ['surface_covered_in_m2', 'seguridad', 'subtes_cercanos'],
#  ['surface_covered_in_m2', 'seguridad', 'trenes_cercanos'],
#  ['surface_covered_in_m2', 'amenities', 'zona'],
#  ['surface_covered_in_m2', 'amenities', 'subtes_cercanos'],
#  ['surface_covered_in_m2', 'amenities', 'trenes_cercanos'],
#  ['surface_covered_in_m2', 'zona', 'subtes_cercanos'],
#  ['surface_covered_in_m2', 'zona', 'trenes_cercanos'],
#  ['surface_covered_in_m2', 'subtes_cercanos', 'trenes_cercanos'],
#  ['seguridad', 'amenities', 'zona'],
#  ['seguridad', 'amenities', 'subtes_cercanos'],
#  ['seguridad', 'amenities', 'trenes_cercanos'],
#  ['seguridad', 'zona', 'subtes_cercanos'],
#  ['seguridad', 'zona', 'trenes_cercanos'],
#  ['seguridad', 'subtes_cercanos', 'trenes_cercanos'],
#  ['amenities', 'zona', 'subtes_cercanos'],
#  ['amenities', 'zona', 'trenes_cercanos'],
#  ['amenities', 'subtes_cercanos', 'trenes_cercanos'],
#  ['zona', 'subtes_cercanos', 'trenes_cercanos'],
#  ['created_on', 'property_type', 'pileta', 'lat'],
#  ['created_on', 'property_type', 'pileta', 'lon'],
#  ['created_on', 'property_type', 'pileta', 'cochera'],
#  ['created_on', 'property_type', 'pileta', 'surface_total_in_m2'],
#  ['created_on', 'property_type', 'pileta', 'surface_covered_in_m2'],
#  ['created_on', 'property_type', 'pileta', 'seguridad'],
#  ['created_on', 'property_type', 'pileta', 'amenities'],
#  ['created_on', 'property_type', 'pileta', 'zona'],
#  ['created_on', 'property_type', 'pileta', 'subtes_cercanos'],
#  ['created_on', 'property_type', 'pileta', 'trenes_cercanos'],
#  ['created_on', 'property_type', 'lat', 'lon'],
#  ['created_on', 'property_type', 'lat', 'cochera'],
#  ['created_on', 'property_type', 'lat', 'surface_total_in_m2'],
#  ['created_on', 'property_type', 'lat', 'surface_covered_in_m2'],
#  ['created_on', 'property_type', 'lat', 'seguridad'],
#  ['created_on', 'property_type', 'lat', 'amenities'],
#  ['created_on', 'property_type', 'lat', 'zona'],
#  ['created_on', 'property_type', 'lat', 'subtes_cercanos'],
#  ['created_on', 'property_type', 'lat', 'trenes_cercanos'],
#  ['created_on', 'property_type', 'lon', 'cochera'],
#  ['created_on', 'property_type', 'lon', 'surface_total_in_m2'],
#  ['created_on', 'property_type', 'lon', 'surface_covered_in_m2'],
#  ['created_on', 'property_type', 'lon', 'seguridad'],
#  ['created_on', 'property_type', 'lon', 'amenities'],
#  ['created_on', 'property_type', 'lon', 'zona'],
#  ['created_on', 'property_type', 'lon', 'subtes_cercanos'],
#  ['created_on', 'property_type', 'lon', 'trenes_cercanos'],
#  ['created_on', 'property_type', 'cochera', 'surface_total_in_m2'],
#  ['created_on', 'property_type', 'cochera', 'surface_covered_in_m2'],
#  ['created_on', 'property_type', 'cochera', 'seguridad'],
#  ['created_on', 'property_type', 'cochera', 'amenities'],
#  ['created_on', 'property_type', 'cochera', 'zona'],
#  ['created_on', 'property_type', 'cochera', 'subtes_cercanos'],
#  ['created_on', 'property_type', 'cochera', 'trenes_cercanos'],
#  ['created_on',
#   'property_type',
#   'surface_total_in_m2',
#   'surface_covered_in_m2'],
#  ['created_on', 'property_type', 'surface_total_in_m2', 'seguridad'],
#  ['created_on', 'property_type', 'surface_total_in_m2', 'amenities'],
#  ['created_on', 'property_type', 'surface_total_in_m2', 'zona'],
#  ['created_on', 'property_type', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['created_on', 'property_type', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['created_on', 'property_type', 'surface_covered_in_m2', 'seguridad'],
#  ['created_on', 'property_type', 'surface_covered_in_m2', 'amenities'],
#  ['created_on', 'property_type', 'surface_covered_in_m2', 'zona'],
#  ['created_on', 'property_type', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['created_on', 'property_type', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['created_on', 'property_type', 'seguridad', 'amenities'],
#  ['created_on', 'property_type', 'seguridad', 'zona'],
#  ['created_on', 'property_type', 'seguridad', 'subtes_cercanos'],
#  ['created_on', 'property_type', 'seguridad', 'trenes_cercanos'],
#  ['created_on', 'property_type', 'amenities', 'zona'],
#  ['created_on', 'property_type', 'amenities', 'subtes_cercanos'],
#  ['created_on', 'property_type', 'amenities', 'trenes_cercanos'],
#  ['created_on', 'property_type', 'zona', 'subtes_cercanos'],
#  ['created_on', 'property_type', 'zona', 'trenes_cercanos'],
#  ['created_on', 'property_type', 'subtes_cercanos', 'trenes_cercanos'],
#  ['created_on', 'pileta', 'lat', 'lon'],
#  ['created_on', 'pileta', 'lat', 'cochera'],
#  ['created_on', 'pileta', 'lat', 'surface_total_in_m2'],
#  ['created_on', 'pileta', 'lat', 'surface_covered_in_m2'],
#  ['created_on', 'pileta', 'lat', 'seguridad'],
#  ['created_on', 'pileta', 'lat', 'amenities'],
#  ['created_on', 'pileta', 'lat', 'zona'],
#  ['created_on', 'pileta', 'lat', 'subtes_cercanos'],
#  ['created_on', 'pileta', 'lat', 'trenes_cercanos'],
#  ['created_on', 'pileta', 'lon', 'cochera'],
#  ['created_on', 'pileta', 'lon', 'surface_total_in_m2'],
#  ['created_on', 'pileta', 'lon', 'surface_covered_in_m2'],
#  ['created_on', 'pileta', 'lon', 'seguridad'],
#  ['created_on', 'pileta', 'lon', 'amenities'],
#  ['created_on', 'pileta', 'lon', 'zona'],
#  ['created_on', 'pileta', 'lon', 'subtes_cercanos'],
#  ['created_on', 'pileta', 'lon', 'trenes_cercanos'],
#  ['created_on', 'pileta', 'cochera', 'surface_total_in_m2'],
#  ['created_on', 'pileta', 'cochera', 'surface_covered_in_m2'],
#  ['created_on', 'pileta', 'cochera', 'seguridad'],
#  ['created_on', 'pileta', 'cochera', 'amenities'],
#  ['created_on', 'pileta', 'cochera', 'zona'],
#  ['created_on', 'pileta', 'cochera', 'subtes_cercanos'],
#  ['created_on', 'pileta', 'cochera', 'trenes_cercanos'],
#  ['created_on', 'pileta', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['created_on', 'pileta', 'surface_total_in_m2', 'seguridad'],
#  ['created_on', 'pileta', 'surface_total_in_m2', 'amenities'],
#  ['created_on', 'pileta', 'surface_total_in_m2', 'zona'],
#  ['created_on', 'pileta', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['created_on', 'pileta', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['created_on', 'pileta', 'surface_covered_in_m2', 'seguridad'],
#  ['created_on', 'pileta', 'surface_covered_in_m2', 'amenities'],
#  ['created_on', 'pileta', 'surface_covered_in_m2', 'zona'],
#  ['created_on', 'pileta', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['created_on', 'pileta', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['created_on', 'pileta', 'seguridad', 'amenities'],
#  ['created_on', 'pileta', 'seguridad', 'zona'],
#  ['created_on', 'pileta', 'seguridad', 'subtes_cercanos'],
#  ['created_on', 'pileta', 'seguridad', 'trenes_cercanos'],
#  ['created_on', 'pileta', 'amenities', 'zona'],
#  ['created_on', 'pileta', 'amenities', 'subtes_cercanos'],
#  ['created_on', 'pileta', 'amenities', 'trenes_cercanos'],
#  ['created_on', 'pileta', 'zona', 'subtes_cercanos'],
#  ['created_on', 'pileta', 'zona', 'trenes_cercanos'],
#  ['created_on', 'pileta', 'subtes_cercanos', 'trenes_cercanos'],
#  ['created_on', 'lat', 'lon', 'cochera'],
#  ['created_on', 'lat', 'lon', 'surface_total_in_m2'],
#  ['created_on', 'lat', 'lon', 'surface_covered_in_m2'],
#  ['created_on', 'lat', 'lon', 'seguridad'],
#  ['created_on', 'lat', 'lon', 'amenities'],
#  ['created_on', 'lat', 'lon', 'zona'],
#  ['created_on', 'lat', 'lon', 'subtes_cercanos'],
#  ['created_on', 'lat', 'lon', 'trenes_cercanos'],
#  ['created_on', 'lat', 'cochera', 'surface_total_in_m2'],
#  ['created_on', 'lat', 'cochera', 'surface_covered_in_m2'],
#  ['created_on', 'lat', 'cochera', 'seguridad'],
#  ['created_on', 'lat', 'cochera', 'amenities'],
#  ['created_on', 'lat', 'cochera', 'zona'],
#  ['created_on', 'lat', 'cochera', 'subtes_cercanos'],
#  ['created_on', 'lat', 'cochera', 'trenes_cercanos'],
#  ['created_on', 'lat', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['created_on', 'lat', 'surface_total_in_m2', 'seguridad'],
#  ['created_on', 'lat', 'surface_total_in_m2', 'amenities'],
#  ['created_on', 'lat', 'surface_total_in_m2', 'zona'],
#  ['created_on', 'lat', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['created_on', 'lat', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['created_on', 'lat', 'surface_covered_in_m2', 'seguridad'],
#  ['created_on', 'lat', 'surface_covered_in_m2', 'amenities'],
#  ['created_on', 'lat', 'surface_covered_in_m2', 'zona'],
#  ['created_on', 'lat', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['created_on', 'lat', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['created_on', 'lat', 'seguridad', 'amenities'],
#  ['created_on', 'lat', 'seguridad', 'zona'],
#  ['created_on', 'lat', 'seguridad', 'subtes_cercanos'],
#  ['created_on', 'lat', 'seguridad', 'trenes_cercanos'],
#  ['created_on', 'lat', 'amenities', 'zona'],
#  ['created_on', 'lat', 'amenities', 'subtes_cercanos'],
#  ['created_on', 'lat', 'amenities', 'trenes_cercanos'],
#  ['created_on', 'lat', 'zona', 'subtes_cercanos'],
#  ['created_on', 'lat', 'zona', 'trenes_cercanos'],
#  ['created_on', 'lat', 'subtes_cercanos', 'trenes_cercanos'],
#  ['created_on', 'lon', 'cochera', 'surface_total_in_m2'],
#  ['created_on', 'lon', 'cochera', 'surface_covered_in_m2'],
#  ['created_on', 'lon', 'cochera', 'seguridad'],
#  ['created_on', 'lon', 'cochera', 'amenities'],
#  ['created_on', 'lon', 'cochera', 'zona'],
#  ['created_on', 'lon', 'cochera', 'subtes_cercanos'],
#  ['created_on', 'lon', 'cochera', 'trenes_cercanos'],
#  ['created_on', 'lon', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['created_on', 'lon', 'surface_total_in_m2', 'seguridad'],
#  ['created_on', 'lon', 'surface_total_in_m2', 'amenities'],
#  ['created_on', 'lon', 'surface_total_in_m2', 'zona'],
#  ['created_on', 'lon', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['created_on', 'lon', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['created_on', 'lon', 'surface_covered_in_m2', 'seguridad'],
#  ['created_on', 'lon', 'surface_covered_in_m2', 'amenities'],
#  ['created_on', 'lon', 'surface_covered_in_m2', 'zona'],
#  ['created_on', 'lon', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['created_on', 'lon', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['created_on', 'lon', 'seguridad', 'amenities'],
#  ['created_on', 'lon', 'seguridad', 'zona'],
#  ['created_on', 'lon', 'seguridad', 'subtes_cercanos'],
#  ['created_on', 'lon', 'seguridad', 'trenes_cercanos'],
#  ['created_on', 'lon', 'amenities', 'zona'],
#  ['created_on', 'lon', 'amenities', 'subtes_cercanos'],
#  ['created_on', 'lon', 'amenities', 'trenes_cercanos'],
#  ['created_on', 'lon', 'zona', 'subtes_cercanos'],
#  ['created_on', 'lon', 'zona', 'trenes_cercanos'],
#  ['created_on', 'lon', 'subtes_cercanos', 'trenes_cercanos'],
#  ['created_on', 'cochera', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['created_on', 'cochera', 'surface_total_in_m2', 'seguridad'],
#  ['created_on', 'cochera', 'surface_total_in_m2', 'amenities'],
#  ['created_on', 'cochera', 'surface_total_in_m2', 'zona'],
#  ['created_on', 'cochera', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['created_on', 'cochera', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['created_on', 'cochera', 'surface_covered_in_m2', 'seguridad'],
#  ['created_on', 'cochera', 'surface_covered_in_m2', 'amenities'],
#  ['created_on', 'cochera', 'surface_covered_in_m2', 'zona'],
#  ['created_on', 'cochera', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['created_on', 'cochera', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['created_on', 'cochera', 'seguridad', 'amenities'],
#  ['created_on', 'cochera', 'seguridad', 'zona'],
#  ['created_on', 'cochera', 'seguridad', 'subtes_cercanos'],
#  ['created_on', 'cochera', 'seguridad', 'trenes_cercanos'],
#  ['created_on', 'cochera', 'amenities', 'zona'],
#  ['created_on', 'cochera', 'amenities', 'subtes_cercanos'],
#  ['created_on', 'cochera', 'amenities', 'trenes_cercanos'],
#  ['created_on', 'cochera', 'zona', 'subtes_cercanos'],
#  ['created_on', 'cochera', 'zona', 'trenes_cercanos'],
#  ['created_on', 'cochera', 'subtes_cercanos', 'trenes_cercanos'],
#  ['created_on', 'surface_total_in_m2', 'surface_covered_in_m2', 'seguridad'],
#  ['created_on', 'surface_total_in_m2', 'surface_covered_in_m2', 'amenities'],
#  ['created_on', 'surface_total_in_m2', 'surface_covered_in_m2', 'zona'],
#  ['created_on',
#   'surface_total_in_m2',
#   'surface_covered_in_m2',
#   'subtes_cercanos'],
#  ['created_on',
#   'surface_total_in_m2',
#   'surface_covered_in_m2',
#   'trenes_cercanos'],
#  ['created_on', 'surface_total_in_m2', 'seguridad', 'amenities'],
#  ['created_on', 'surface_total_in_m2', 'seguridad', 'zona'],
#  ['created_on', 'surface_total_in_m2', 'seguridad', 'subtes_cercanos'],
#  ['created_on', 'surface_total_in_m2', 'seguridad', 'trenes_cercanos'],
#  ['created_on', 'surface_total_in_m2', 'amenities', 'zona'],
#  ['created_on', 'surface_total_in_m2', 'amenities', 'subtes_cercanos'],
#  ['created_on', 'surface_total_in_m2', 'amenities', 'trenes_cercanos'],
#  ['created_on', 'surface_total_in_m2', 'zona', 'subtes_cercanos'],
#  ['created_on', 'surface_total_in_m2', 'zona', 'trenes_cercanos'],
#  ['created_on', 'surface_total_in_m2', 'subtes_cercanos', 'trenes_cercanos'],
#  ['created_on', 'surface_covered_in_m2', 'seguridad', 'amenities'],
#  ['created_on', 'surface_covered_in_m2', 'seguridad', 'zona'],
#  ['created_on', 'surface_covered_in_m2', 'seguridad', 'subtes_cercanos'],
#  ['created_on', 'surface_covered_in_m2', 'seguridad', 'trenes_cercanos'],
#  ['created_on', 'surface_covered_in_m2', 'amenities', 'zona'],
#  ['created_on', 'surface_covered_in_m2', 'amenities', 'subtes_cercanos'],
#  ['created_on', 'surface_covered_in_m2', 'amenities', 'trenes_cercanos'],
#  ['created_on', 'surface_covered_in_m2', 'zona', 'subtes_cercanos'],
#  ['created_on', 'surface_covered_in_m2', 'zona', 'trenes_cercanos'],
#  ['created_on', 'surface_covered_in_m2', 'subtes_cercanos', 'trenes_cercanos'],
#  ['created_on', 'seguridad', 'amenities', 'zona'],
#  ['created_on', 'seguridad', 'amenities', 'subtes_cercanos'],
#  ['created_on', 'seguridad', 'amenities', 'trenes_cercanos'],
#  ['created_on', 'seguridad', 'zona', 'subtes_cercanos'],
#  ['created_on', 'seguridad', 'zona', 'trenes_cercanos'],
#  ['created_on', 'seguridad', 'subtes_cercanos', 'trenes_cercanos'],
#  ['created_on', 'amenities', 'zona', 'subtes_cercanos'],
#  ['created_on', 'amenities', 'zona', 'trenes_cercanos'],
#  ['created_on', 'amenities', 'subtes_cercanos', 'trenes_cercanos'],
#  ['created_on', 'zona', 'subtes_cercanos', 'trenes_cercanos'],
#  ['property_type', 'pileta', 'lat', 'lon'],
#  ['property_type', 'pileta', 'lat', 'cochera'],
#  ['property_type', 'pileta', 'lat', 'surface_total_in_m2'],
#  ['property_type', 'pileta', 'lat', 'surface_covered_in_m2'],
#  ['property_type', 'pileta', 'lat', 'seguridad'],
#  ['property_type', 'pileta', 'lat', 'amenities'],
#  ['property_type', 'pileta', 'lat', 'zona'],
#  ['property_type', 'pileta', 'lat', 'subtes_cercanos'],
#  ['property_type', 'pileta', 'lat', 'trenes_cercanos'],
#  ['property_type', 'pileta', 'lon', 'cochera'],
#  ['property_type', 'pileta', 'lon', 'surface_total_in_m2'],
#  ['property_type', 'pileta', 'lon', 'surface_covered_in_m2'],
#  ['property_type', 'pileta', 'lon', 'seguridad'],
#  ['property_type', 'pileta', 'lon', 'amenities'],
#  ['property_type', 'pileta', 'lon', 'zona'],
#  ['property_type', 'pileta', 'lon', 'subtes_cercanos'],
#  ['property_type', 'pileta', 'lon', 'trenes_cercanos'],
#  ['property_type', 'pileta', 'cochera', 'surface_total_in_m2'],
#  ['property_type', 'pileta', 'cochera', 'surface_covered_in_m2'],
#  ['property_type', 'pileta', 'cochera', 'seguridad'],
#  ['property_type', 'pileta', 'cochera', 'amenities'],
#  ['property_type', 'pileta', 'cochera', 'zona'],
#  ['property_type', 'pileta', 'cochera', 'subtes_cercanos'],
#  ['property_type', 'pileta', 'cochera', 'trenes_cercanos'],
#  ['property_type', 'pileta', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['property_type', 'pileta', 'surface_total_in_m2', 'seguridad'],
#  ['property_type', 'pileta', 'surface_total_in_m2', 'amenities'],
#  ['property_type', 'pileta', 'surface_total_in_m2', 'zona'],
#  ['property_type', 'pileta', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['property_type', 'pileta', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['property_type', 'pileta', 'surface_covered_in_m2', 'seguridad'],
#  ['property_type', 'pileta', 'surface_covered_in_m2', 'amenities'],
#  ['property_type', 'pileta', 'surface_covered_in_m2', 'zona'],
#  ['property_type', 'pileta', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['property_type', 'pileta', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['property_type', 'pileta', 'seguridad', 'amenities'],
#  ['property_type', 'pileta', 'seguridad', 'zona'],
#  ['property_type', 'pileta', 'seguridad', 'subtes_cercanos'],
#  ['property_type', 'pileta', 'seguridad', 'trenes_cercanos'],
#  ['property_type', 'pileta', 'amenities', 'zona'],
#  ['property_type', 'pileta', 'amenities', 'subtes_cercanos'],
#  ['property_type', 'pileta', 'amenities', 'trenes_cercanos'],
#  ['property_type', 'pileta', 'zona', 'subtes_cercanos'],
#  ['property_type', 'pileta', 'zona', 'trenes_cercanos'],
#  ['property_type', 'pileta', 'subtes_cercanos', 'trenes_cercanos'],
#  ['property_type', 'lat', 'lon', 'cochera'],
#  ['property_type', 'lat', 'lon', 'surface_total_in_m2'],
#  ['property_type', 'lat', 'lon', 'surface_covered_in_m2'],
#  ['property_type', 'lat', 'lon', 'seguridad'],
#  ['property_type', 'lat', 'lon', 'amenities'],
#  ['property_type', 'lat', 'lon', 'zona'],
#  ['property_type', 'lat', 'lon', 'subtes_cercanos'],
#  ['property_type', 'lat', 'lon', 'trenes_cercanos'],
#  ['property_type', 'lat', 'cochera', 'surface_total_in_m2'],
#  ['property_type', 'lat', 'cochera', 'surface_covered_in_m2'],
#  ['property_type', 'lat', 'cochera', 'seguridad'],
#  ['property_type', 'lat', 'cochera', 'amenities'],
#  ['property_type', 'lat', 'cochera', 'zona'],
#  ['property_type', 'lat', 'cochera', 'subtes_cercanos'],
#  ['property_type', 'lat', 'cochera', 'trenes_cercanos'],
#  ['property_type', 'lat', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['property_type', 'lat', 'surface_total_in_m2', 'seguridad'],
#  ['property_type', 'lat', 'surface_total_in_m2', 'amenities'],
#  ['property_type', 'lat', 'surface_total_in_m2', 'zona'],
#  ['property_type', 'lat', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['property_type', 'lat', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['property_type', 'lat', 'surface_covered_in_m2', 'seguridad'],
#  ['property_type', 'lat', 'surface_covered_in_m2', 'amenities'],
#  ['property_type', 'lat', 'surface_covered_in_m2', 'zona'],
#  ['property_type', 'lat', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['property_type', 'lat', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['property_type', 'lat', 'seguridad', 'amenities'],
#  ['property_type', 'lat', 'seguridad', 'zona'],
#  ['property_type', 'lat', 'seguridad', 'subtes_cercanos'],
#  ['property_type', 'lat', 'seguridad', 'trenes_cercanos'],
#  ['property_type', 'lat', 'amenities', 'zona'],
#  ['property_type', 'lat', 'amenities', 'subtes_cercanos'],
#  ['property_type', 'lat', 'amenities', 'trenes_cercanos'],
#  ['property_type', 'lat', 'zona', 'subtes_cercanos'],
#  ['property_type', 'lat', 'zona', 'trenes_cercanos'],
#  ['property_type', 'lat', 'subtes_cercanos', 'trenes_cercanos'],
#  ['property_type', 'lon', 'cochera', 'surface_total_in_m2'],
#  ['property_type', 'lon', 'cochera', 'surface_covered_in_m2'],
#  ['property_type', 'lon', 'cochera', 'seguridad'],
#  ['property_type', 'lon', 'cochera', 'amenities'],
#  ['property_type', 'lon', 'cochera', 'zona'],
#  ['property_type', 'lon', 'cochera', 'subtes_cercanos'],
#  ['property_type', 'lon', 'cochera', 'trenes_cercanos'],
#  ['property_type', 'lon', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['property_type', 'lon', 'surface_total_in_m2', 'seguridad'],
#  ['property_type', 'lon', 'surface_total_in_m2', 'amenities'],
#  ['property_type', 'lon', 'surface_total_in_m2', 'zona'],
#  ['property_type', 'lon', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['property_type', 'lon', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['property_type', 'lon', 'surface_covered_in_m2', 'seguridad'],
#  ['property_type', 'lon', 'surface_covered_in_m2', 'amenities'],
#  ['property_type', 'lon', 'surface_covered_in_m2', 'zona'],
#  ['property_type', 'lon', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['property_type', 'lon', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['property_type', 'lon', 'seguridad', 'amenities'],
#  ['property_type', 'lon', 'seguridad', 'zona'],
#  ['property_type', 'lon', 'seguridad', 'subtes_cercanos'],
#  ['property_type', 'lon', 'seguridad', 'trenes_cercanos'],
#  ['property_type', 'lon', 'amenities', 'zona'],
#  ['property_type', 'lon', 'amenities', 'subtes_cercanos'],
#  ['property_type', 'lon', 'amenities', 'trenes_cercanos'],
#  ['property_type', 'lon', 'zona', 'subtes_cercanos'],
#  ['property_type', 'lon', 'zona', 'trenes_cercanos'],
#  ['property_type', 'lon', 'subtes_cercanos', 'trenes_cercanos'],
#  ['property_type', 'cochera', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['property_type', 'cochera', 'surface_total_in_m2', 'seguridad'],
#  ['property_type', 'cochera', 'surface_total_in_m2', 'amenities'],
#  ['property_type', 'cochera', 'surface_total_in_m2', 'zona'],
#  ['property_type', 'cochera', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['property_type', 'cochera', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['property_type', 'cochera', 'surface_covered_in_m2', 'seguridad'],
#  ['property_type', 'cochera', 'surface_covered_in_m2', 'amenities'],
#  ['property_type', 'cochera', 'surface_covered_in_m2', 'zona'],
#  ['property_type', 'cochera', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['property_type', 'cochera', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['property_type', 'cochera', 'seguridad', 'amenities'],
#  ['property_type', 'cochera', 'seguridad', 'zona'],
#  ['property_type', 'cochera', 'seguridad', 'subtes_cercanos'],
#  ['property_type', 'cochera', 'seguridad', 'trenes_cercanos'],
#  ['property_type', 'cochera', 'amenities', 'zona'],
#  ['property_type', 'cochera', 'amenities', 'subtes_cercanos'],
#  ['property_type', 'cochera', 'amenities', 'trenes_cercanos'],
#  ['property_type', 'cochera', 'zona', 'subtes_cercanos'],
#  ['property_type', 'cochera', 'zona', 'trenes_cercanos'],
#  ['property_type', 'cochera', 'subtes_cercanos', 'trenes_cercanos'],
#  ['property_type',
#   'surface_total_in_m2',
#   'surface_covered_in_m2',
#   'seguridad'],
#  ['property_type',
#   'surface_total_in_m2',
#   'surface_covered_in_m2',
#   'amenities'],
#  ['property_type', 'surface_total_in_m2', 'surface_covered_in_m2', 'zona'],
#  ['property_type',
#   'surface_total_in_m2',
#   'surface_covered_in_m2',
#   'subtes_cercanos'],
#  ['property_type',
#   'surface_total_in_m2',
#   'surface_covered_in_m2',
#   'trenes_cercanos'],
#  ['property_type', 'surface_total_in_m2', 'seguridad', 'amenities'],
#  ['property_type', 'surface_total_in_m2', 'seguridad', 'zona'],
#  ['property_type', 'surface_total_in_m2', 'seguridad', 'subtes_cercanos'],
#  ['property_type', 'surface_total_in_m2', 'seguridad', 'trenes_cercanos'],
#  ['property_type', 'surface_total_in_m2', 'amenities', 'zona'],
#  ['property_type', 'surface_total_in_m2', 'amenities', 'subtes_cercanos'],
#  ['property_type', 'surface_total_in_m2', 'amenities', 'trenes_cercanos'],
#  ['property_type', 'surface_total_in_m2', 'zona', 'subtes_cercanos'],
#  ['property_type', 'surface_total_in_m2', 'zona', 'trenes_cercanos'],
#  ['property_type',
#   'surface_total_in_m2',
#   'subtes_cercanos',
#   'trenes_cercanos'],
#  ['property_type', 'surface_covered_in_m2', 'seguridad', 'amenities'],
#  ['property_type', 'surface_covered_in_m2', 'seguridad', 'zona'],
#  ['property_type', 'surface_covered_in_m2', 'seguridad', 'subtes_cercanos'],
#  ['property_type', 'surface_covered_in_m2', 'seguridad', 'trenes_cercanos'],
#  ['property_type', 'surface_covered_in_m2', 'amenities', 'zona'],
#  ['property_type', 'surface_covered_in_m2', 'amenities', 'subtes_cercanos'],
#  ['property_type', 'surface_covered_in_m2', 'amenities', 'trenes_cercanos'],
#  ['property_type', 'surface_covered_in_m2', 'zona', 'subtes_cercanos'],
#  ['property_type', 'surface_covered_in_m2', 'zona', 'trenes_cercanos'],
#  ['property_type',
#   'surface_covered_in_m2',
#   'subtes_cercanos',
#   'trenes_cercanos'],
#  ['property_type', 'seguridad', 'amenities', 'zona'],
#  ['property_type', 'seguridad', 'amenities', 'subtes_cercanos'],
#  ['property_type', 'seguridad', 'amenities', 'trenes_cercanos'],
#  ['property_type', 'seguridad', 'zona', 'subtes_cercanos'],
#  ['property_type', 'seguridad', 'zona', 'trenes_cercanos'],
#  ['property_type', 'seguridad', 'subtes_cercanos', 'trenes_cercanos'],
#  ['property_type', 'amenities', 'zona', 'subtes_cercanos'],
#  ['property_type', 'amenities', 'zona', 'trenes_cercanos'],
#  ['property_type', 'amenities', 'subtes_cercanos', 'trenes_cercanos'],
#  ['property_type', 'zona', 'subtes_cercanos', 'trenes_cercanos'],
#  ['pileta', 'lat', 'lon', 'cochera'],
#  ['pileta', 'lat', 'lon', 'surface_total_in_m2'],
#  ['pileta', 'lat', 'lon', 'surface_covered_in_m2'],
#  ['pileta', 'lat', 'lon', 'seguridad'],
#  ['pileta', 'lat', 'lon', 'amenities'],
#  ['pileta', 'lat', 'lon', 'zona'],
#  ['pileta', 'lat', 'lon', 'subtes_cercanos'],
#  ['pileta', 'lat', 'lon', 'trenes_cercanos'],
#  ['pileta', 'lat', 'cochera', 'surface_total_in_m2'],
#  ['pileta', 'lat', 'cochera', 'surface_covered_in_m2'],
#  ['pileta', 'lat', 'cochera', 'seguridad'],
#  ['pileta', 'lat', 'cochera', 'amenities'],
#  ['pileta', 'lat', 'cochera', 'zona'],
#  ['pileta', 'lat', 'cochera', 'subtes_cercanos'],
#  ['pileta', 'lat', 'cochera', 'trenes_cercanos'],
#  ['pileta', 'lat', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['pileta', 'lat', 'surface_total_in_m2', 'seguridad'],
#  ['pileta', 'lat', 'surface_total_in_m2', 'amenities'],
#  ['pileta', 'lat', 'surface_total_in_m2', 'zona'],
#  ['pileta', 'lat', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['pileta', 'lat', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['pileta', 'lat', 'surface_covered_in_m2', 'seguridad'],
#  ['pileta', 'lat', 'surface_covered_in_m2', 'amenities'],
#  ['pileta', 'lat', 'surface_covered_in_m2', 'zona'],
#  ['pileta', 'lat', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['pileta', 'lat', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['pileta', 'lat', 'seguridad', 'amenities'],
#  ['pileta', 'lat', 'seguridad', 'zona'],
#  ['pileta', 'lat', 'seguridad', 'subtes_cercanos'],
#  ['pileta', 'lat', 'seguridad', 'trenes_cercanos'],
#  ['pileta', 'lat', 'amenities', 'zona'],
#  ['pileta', 'lat', 'amenities', 'subtes_cercanos'],
#  ['pileta', 'lat', 'amenities', 'trenes_cercanos'],
#  ['pileta', 'lat', 'zona', 'subtes_cercanos'],
#  ['pileta', 'lat', 'zona', 'trenes_cercanos'],
#  ['pileta', 'lat', 'subtes_cercanos', 'trenes_cercanos'],
#  ['pileta', 'lon', 'cochera', 'surface_total_in_m2'],
#  ['pileta', 'lon', 'cochera', 'surface_covered_in_m2'],
#  ['pileta', 'lon', 'cochera', 'seguridad'],
#  ['pileta', 'lon', 'cochera', 'amenities'],
#  ['pileta', 'lon', 'cochera', 'zona'],
#  ['pileta', 'lon', 'cochera', 'subtes_cercanos'],
#  ['pileta', 'lon', 'cochera', 'trenes_cercanos'],
#  ['pileta', 'lon', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['pileta', 'lon', 'surface_total_in_m2', 'seguridad'],
#  ['pileta', 'lon', 'surface_total_in_m2', 'amenities'],
#  ['pileta', 'lon', 'surface_total_in_m2', 'zona'],
#  ['pileta', 'lon', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['pileta', 'lon', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['pileta', 'lon', 'surface_covered_in_m2', 'seguridad'],
#  ['pileta', 'lon', 'surface_covered_in_m2', 'amenities'],
#  ['pileta', 'lon', 'surface_covered_in_m2', 'zona'],
#  ['pileta', 'lon', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['pileta', 'lon', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['pileta', 'lon', 'seguridad', 'amenities'],
#  ['pileta', 'lon', 'seguridad', 'zona'],
#  ['pileta', 'lon', 'seguridad', 'subtes_cercanos'],
#  ['pileta', 'lon', 'seguridad', 'trenes_cercanos'],
#  ['pileta', 'lon', 'amenities', 'zona'],
#  ['pileta', 'lon', 'amenities', 'subtes_cercanos'],
#  ['pileta', 'lon', 'amenities', 'trenes_cercanos'],
#  ['pileta', 'lon', 'zona', 'subtes_cercanos'],
#  ['pileta', 'lon', 'zona', 'trenes_cercanos'],
#  ['pileta', 'lon', 'subtes_cercanos', 'trenes_cercanos'],
#  ['pileta', 'cochera', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['pileta', 'cochera', 'surface_total_in_m2', 'seguridad'],
#  ['pileta', 'cochera', 'surface_total_in_m2', 'amenities'],
#  ['pileta', 'cochera', 'surface_total_in_m2', 'zona'],
#  ['pileta', 'cochera', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['pileta', 'cochera', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['pileta', 'cochera', 'surface_covered_in_m2', 'seguridad'],
#  ['pileta', 'cochera', 'surface_covered_in_m2', 'amenities'],
#  ['pileta', 'cochera', 'surface_covered_in_m2', 'zona'],
#  ['pileta', 'cochera', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['pileta', 'cochera', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['pileta', 'cochera', 'seguridad', 'amenities'],
#  ['pileta', 'cochera', 'seguridad', 'zona'],
#  ['pileta', 'cochera', 'seguridad', 'subtes_cercanos'],
#  ['pileta', 'cochera', 'seguridad', 'trenes_cercanos'],
#  ['pileta', 'cochera', 'amenities', 'zona'],
#  ['pileta', 'cochera', 'amenities', 'subtes_cercanos'],
#  ['pileta', 'cochera', 'amenities', 'trenes_cercanos'],
#  ['pileta', 'cochera', 'zona', 'subtes_cercanos'],
#  ['pileta', 'cochera', 'zona', 'trenes_cercanos'],
#  ['pileta', 'cochera', 'subtes_cercanos', 'trenes_cercanos'],
#  ['pileta', 'surface_total_in_m2', 'surface_covered_in_m2', 'seguridad'],
#  ['pileta', 'surface_total_in_m2', 'surface_covered_in_m2', 'amenities'],
#  ['pileta', 'surface_total_in_m2', 'surface_covered_in_m2', 'zona'],
#  ['pileta', 'surface_total_in_m2', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['pileta', 'surface_total_in_m2', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['pileta', 'surface_total_in_m2', 'seguridad', 'amenities'],
#  ['pileta', 'surface_total_in_m2', 'seguridad', 'zona'],
#  ['pileta', 'surface_total_in_m2', 'seguridad', 'subtes_cercanos'],
#  ['pileta', 'surface_total_in_m2', 'seguridad', 'trenes_cercanos'],
#  ['pileta', 'surface_total_in_m2', 'amenities', 'zona'],
#  ['pileta', 'surface_total_in_m2', 'amenities', 'subtes_cercanos'],
#  ['pileta', 'surface_total_in_m2', 'amenities', 'trenes_cercanos'],
#  ['pileta', 'surface_total_in_m2', 'zona', 'subtes_cercanos'],
#  ['pileta', 'surface_total_in_m2', 'zona', 'trenes_cercanos'],
#  ['pileta', 'surface_total_in_m2', 'subtes_cercanos', 'trenes_cercanos'],
#  ['pileta', 'surface_covered_in_m2', 'seguridad', 'amenities'],
#  ['pileta', 'surface_covered_in_m2', 'seguridad', 'zona'],
#  ['pileta', 'surface_covered_in_m2', 'seguridad', 'subtes_cercanos'],
#  ['pileta', 'surface_covered_in_m2', 'seguridad', 'trenes_cercanos'],
#  ['pileta', 'surface_covered_in_m2', 'amenities', 'zona'],
#  ['pileta', 'surface_covered_in_m2', 'amenities', 'subtes_cercanos'],
#  ['pileta', 'surface_covered_in_m2', 'amenities', 'trenes_cercanos'],
#  ['pileta', 'surface_covered_in_m2', 'zona', 'subtes_cercanos'],
#  ['pileta', 'surface_covered_in_m2', 'zona', 'trenes_cercanos'],
#  ['pileta', 'surface_covered_in_m2', 'subtes_cercanos', 'trenes_cercanos'],
#  ['pileta', 'seguridad', 'amenities', 'zona'],
#  ['pileta', 'seguridad', 'amenities', 'subtes_cercanos'],
#  ['pileta', 'seguridad', 'amenities', 'trenes_cercanos'],
#  ['pileta', 'seguridad', 'zona', 'subtes_cercanos'],
#  ['pileta', 'seguridad', 'zona', 'trenes_cercanos'],
#  ['pileta', 'seguridad', 'subtes_cercanos', 'trenes_cercanos'],
#  ['pileta', 'amenities', 'zona', 'subtes_cercanos'],
#  ['pileta', 'amenities', 'zona', 'trenes_cercanos'],
#  ['pileta', 'amenities', 'subtes_cercanos', 'trenes_cercanos'],
#  ['pileta', 'zona', 'subtes_cercanos', 'trenes_cercanos'],
#  ['lat', 'lon', 'cochera', 'surface_total_in_m2'],
#  ['lat', 'lon', 'cochera', 'surface_covered_in_m2'],
#  ['lat', 'lon', 'cochera', 'seguridad'],
#  ['lat', 'lon', 'cochera', 'amenities'],
#  ['lat', 'lon', 'cochera', 'zona'],
#  ['lat', 'lon', 'cochera', 'subtes_cercanos'],
#  ['lat', 'lon', 'cochera', 'trenes_cercanos'],
#  ['lat', 'lon', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['lat', 'lon', 'surface_total_in_m2', 'seguridad'],
#  ['lat', 'lon', 'surface_total_in_m2', 'amenities'],
#  ['lat', 'lon', 'surface_total_in_m2', 'zona'],
#  ['lat', 'lon', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['lat', 'lon', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['lat', 'lon', 'surface_covered_in_m2', 'seguridad'],
#  ['lat', 'lon', 'surface_covered_in_m2', 'amenities'],
#  ['lat', 'lon', 'surface_covered_in_m2', 'zona'],
#  ['lat', 'lon', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['lat', 'lon', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['lat', 'lon', 'seguridad', 'amenities'],
#  ['lat', 'lon', 'seguridad', 'zona'],
#  ['lat', 'lon', 'seguridad', 'subtes_cercanos'],
#  ['lat', 'lon', 'seguridad', 'trenes_cercanos'],
#  ['lat', 'lon', 'amenities', 'zona'],
#  ['lat', 'lon', 'amenities', 'subtes_cercanos'],
#  ['lat', 'lon', 'amenities', 'trenes_cercanos'],
#  ['lat', 'lon', 'zona', 'subtes_cercanos'],
#  ['lat', 'lon', 'zona', 'trenes_cercanos'],
#  ['lat', 'lon', 'subtes_cercanos', 'trenes_cercanos'],
#  ['lat', 'cochera', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['lat', 'cochera', 'surface_total_in_m2', 'seguridad'],
#  ['lat', 'cochera', 'surface_total_in_m2', 'amenities'],
#  ['lat', 'cochera', 'surface_total_in_m2', 'zona'],
#  ['lat', 'cochera', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['lat', 'cochera', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['lat', 'cochera', 'surface_covered_in_m2', 'seguridad'],
#  ['lat', 'cochera', 'surface_covered_in_m2', 'amenities'],
#  ['lat', 'cochera', 'surface_covered_in_m2', 'zona'],
#  ['lat', 'cochera', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['lat', 'cochera', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['lat', 'cochera', 'seguridad', 'amenities'],
#  ['lat', 'cochera', 'seguridad', 'zona'],
#  ['lat', 'cochera', 'seguridad', 'subtes_cercanos'],
#  ['lat', 'cochera', 'seguridad', 'trenes_cercanos'],
#  ['lat', 'cochera', 'amenities', 'zona'],
#  ['lat', 'cochera', 'amenities', 'subtes_cercanos'],
#  ['lat', 'cochera', 'amenities', 'trenes_cercanos'],
#  ['lat', 'cochera', 'zona', 'subtes_cercanos'],
#  ['lat', 'cochera', 'zona', 'trenes_cercanos'],
#  ['lat', 'cochera', 'subtes_cercanos', 'trenes_cercanos'],
#  ['lat', 'surface_total_in_m2', 'surface_covered_in_m2', 'seguridad'],
#  ['lat', 'surface_total_in_m2', 'surface_covered_in_m2', 'amenities'],
#  ['lat', 'surface_total_in_m2', 'surface_covered_in_m2', 'zona'],
#  ['lat', 'surface_total_in_m2', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['lat', 'surface_total_in_m2', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['lat', 'surface_total_in_m2', 'seguridad', 'amenities'],
#  ['lat', 'surface_total_in_m2', 'seguridad', 'zona'],
#  ['lat', 'surface_total_in_m2', 'seguridad', 'subtes_cercanos'],
#  ['lat', 'surface_total_in_m2', 'seguridad', 'trenes_cercanos'],
#  ['lat', 'surface_total_in_m2', 'amenities', 'zona'],
#  ['lat', 'surface_total_in_m2', 'amenities', 'subtes_cercanos'],
#  ['lat', 'surface_total_in_m2', 'amenities', 'trenes_cercanos'],
#  ['lat', 'surface_total_in_m2', 'zona', 'subtes_cercanos'],
#  ['lat', 'surface_total_in_m2', 'zona', 'trenes_cercanos'],
#  ['lat', 'surface_total_in_m2', 'subtes_cercanos', 'trenes_cercanos'],
#  ['lat', 'surface_covered_in_m2', 'seguridad', 'amenities'],
#  ['lat', 'surface_covered_in_m2', 'seguridad', 'zona'],
#  ['lat', 'surface_covered_in_m2', 'seguridad', 'subtes_cercanos'],
#  ['lat', 'surface_covered_in_m2', 'seguridad', 'trenes_cercanos'],
#  ['lat', 'surface_covered_in_m2', 'amenities', 'zona'],
#  ['lat', 'surface_covered_in_m2', 'amenities', 'subtes_cercanos'],
#  ['lat', 'surface_covered_in_m2', 'amenities', 'trenes_cercanos'],
#  ['lat', 'surface_covered_in_m2', 'zona', 'subtes_cercanos'],
#  ['lat', 'surface_covered_in_m2', 'zona', 'trenes_cercanos'],
#  ['lat', 'surface_covered_in_m2', 'subtes_cercanos', 'trenes_cercanos'],
#  ['lat', 'seguridad', 'amenities', 'zona'],
#  ['lat', 'seguridad', 'amenities', 'subtes_cercanos'],
#  ['lat', 'seguridad', 'amenities', 'trenes_cercanos'],
#  ['lat', 'seguridad', 'zona', 'subtes_cercanos'],
#  ['lat', 'seguridad', 'zona', 'trenes_cercanos'],
#  ['lat', 'seguridad', 'subtes_cercanos', 'trenes_cercanos'],
#  ['lat', 'amenities', 'zona', 'subtes_cercanos'],
#  ['lat', 'amenities', 'zona', 'trenes_cercanos'],
#  ['lat', 'amenities', 'subtes_cercanos', 'trenes_cercanos'],
#  ['lat', 'zona', 'subtes_cercanos', 'trenes_cercanos'],
#  ['lon', 'cochera', 'surface_total_in_m2', 'surface_covered_in_m2'],
#  ['lon', 'cochera', 'surface_total_in_m2', 'seguridad'],
#  ['lon', 'cochera', 'surface_total_in_m2', 'amenities'],
#  ['lon', 'cochera', 'surface_total_in_m2', 'zona'],
#  ['lon', 'cochera', 'surface_total_in_m2', 'subtes_cercanos'],
#  ['lon', 'cochera', 'surface_total_in_m2', 'trenes_cercanos'],
#  ['lon', 'cochera', 'surface_covered_in_m2', 'seguridad'],
#  ['lon', 'cochera', 'surface_covered_in_m2', 'amenities'],
#  ['lon', 'cochera', 'surface_covered_in_m2', 'zona'],
#  ['lon', 'cochera', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['lon', 'cochera', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['lon', 'cochera', 'seguridad', 'amenities'],
#  ['lon', 'cochera', 'seguridad', 'zona'],
#  ['lon', 'cochera', 'seguridad', 'subtes_cercanos'],
#  ['lon', 'cochera', 'seguridad', 'trenes_cercanos'],
#  ['lon', 'cochera', 'amenities', 'zona'],
#  ['lon', 'cochera', 'amenities', 'subtes_cercanos'],
#  ['lon', 'cochera', 'amenities', 'trenes_cercanos'],
#  ['lon', 'cochera', 'zona', 'subtes_cercanos'],
#  ['lon', 'cochera', 'zona', 'trenes_cercanos'],
#  ['lon', 'cochera', 'subtes_cercanos', 'trenes_cercanos'],
#  ['lon', 'surface_total_in_m2', 'surface_covered_in_m2', 'seguridad'],
#  ['lon', 'surface_total_in_m2', 'surface_covered_in_m2', 'amenities'],
#  ['lon', 'surface_total_in_m2', 'surface_covered_in_m2', 'zona'],
#  ['lon', 'surface_total_in_m2', 'surface_covered_in_m2', 'subtes_cercanos'],
#  ['lon', 'surface_total_in_m2', 'surface_covered_in_m2', 'trenes_cercanos'],
#  ['lon', 'surface_total_in_m2', 'seguridad', 'amenities'],
#  ['lon', 'surface_total_in_m2', 'seguridad', 'zona'],
#  ['lon', 'surface_total_in_m2', 'seguridad', 'subtes_cercanos'],
#  ['lon', 'surface_total_in_m2', 'seguridad', 'trenes_cercanos'],
#  ['lon', 'surface_total_in_m2', 'amenities', 'zona'],
#  ['lon', 'surface_total_in_m2', 'amenities', 'subtes_cercanos'],
#  ['lon', 'surface_total_in_m2', 'amenities', 'trenes_cercanos'],
#  ['lon', 'surface_total_in_m2', 'zona', 'subtes_cercanos'],
#  ['lon', 'surface_total_in_m2', 'zona', 'trenes_cercanos'],
#  ['lon', 'surface_total_in_m2', 'subtes_cercanos', 'trenes_cercanos'],
#  ['lon', 'surface_covered_in_m2', 'seguridad', 'amenities'],
#  ['lon', 'surface_covered_in_m2', 'seguridad', 'zona'],
#  ['lon', 'surface_covered_in_m2', 'seguridad', 'subtes_cercanos'],
#  ['lon', 'surface_covered_in_m2', 'seguridad', 'trenes_cercanos'],
#  ['lon', 'surface_covered_in_m2', 'amenities', 'zona'],
#  ['lon', 'surface_covered_in_m2', 'amenities', 'subtes_cercanos'],
#  ['lon', 'surface_covered_in_m2', 'amenities', 'trenes_cercanos'],
#  ['lon', 'surface_covered_in_m2', 'zona', 'subtes_cercanos'],
#  ['lon', 'surface_covered_in_m2', 'zona', 'trenes_cercanos'],
#  ['lon', 'surface_covered_in_m2', 'subtes_cercanos', 'trenes_cercanos'],
#  ['lon', 'seguridad', 'amenities', 'zona'],
#  ...]

# %%
#prueba todas las combinaciones
resultados = []
y = np.array(data['price_aprox_usd'])

for j in list_columnas: 
    x = np.array(data.loc[:,j])
    x_train, x_test, y_train, y_test = train_test_split(x, y , test_size = 0.33, random_state = 42)
    resultados.append(linearR(x_train, x_test, y_train, y_test))

# %%
resultados.index(min(resultados))
# Out:
# 8164

# %%
list_columnas[resultados.index(min(resultados))]
# Out:
# ['created_on',
#  'property_type',
#  'pileta',
#  'lat',
#  'lon',
#  'cochera',
#  'surface_total_in_m2',
#  'surface_covered_in_m2',
#  'seguridad',
#  'amenities',
#  'zona',
#  'subtes_cercanos']

# %%
min(resultados)
# Out:
# 74589590721.942474

# %%
x = np.array(data.loc[:,list_columnas[resultados.index(min(resultados))]])
y = np.array(data['price_aprox_usd'])
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)

dt = DecisionTreeRegressor(max_depth = 10)
dt_fit = dt.fit(x_train, y_train)

dt_scores = cross_val_score(dt, x_train, y_train, cv = 10)
print("mean cross validation score: {}".format(np.mean(dt_scores)))
print("score without cv: {}".format(dt_fit.score(x_train, y_train)))

 #on the test or hold-out set
from sklearn.metrics import r2_score
print(r2_score(y_test, dt_fit.predict(x_test)))
print(dt_fit.score(x_test, y_test))
# Out:
# mean cross validation score: 0.5830482227253608
# score without cv: 0.8232761051115904
# 0.687591790507
# 0.687591790507

# %%
y_pred = dt_fit.predict(x_test)
predicc = []
for i in range(len(y_test)):
    predicc.append((y_test[i], y_pred[i]))

predicc
# Out:
# [(2800000.0, 2780000.0),
#  (110000.0, 113998.89464579898),
#  (220003.47, 172296.9808983051),
#  (270000.0, 330323.16666666669),
#  (123000.0, 113998.52159999999),
#  (340000.0, 494508.87204545457),
#  (150000.0, 219348.49427835055),
#  (190000.0, 225268.64304627251),
#  (149000.0, 140165.44041074254),
#  (75000.0, 91273.746615384662),
#  (200000.0, 282966.98326829274),
#  (120000.0, 105451.10200345423),
#  (245000.0, 395154.81632653059),
#  (55000.0, 81206.645291576686),
#  (112000.0, 103887.89362911264),
#  (1300000.0, 1424770.1149425288),
#  (265000.0, 240605.95104587157),
#  (145000.0, 160527.27554526745),
#  (93994.0, 91361.104000000021),
#  (298000.0, 397485.55035128805),
#  (87530.0, 93733.095714285708),
#  (140000.0, 164517.51894545453),
#  (85512.910000000003, 111958.80381516588),
#  (240000.0, 299751.90880872484),
#  (92000.0, 72135.174609375012),
#  (535000.0, 603085.9190556492),
#  (280000.0, 331216.49484536081),
#  (480000.0, 315968.50783783779),
#  (405000.0, 397485.55035128805),
#  (83000.0, 81876.381746133993),
#  (650000.0, 240605.95104587157),
#  (420000.0, 397485.55035128805),
#  (116000.0, 104568.70402489626),
#  (179000.0, 160527.27554526745),
#  (145000.0, 105005.82038461539),
#  (55000.0, 79628.286639839018),
#  (320000.0, 296705.8823529412),
#  (120000.0, 103887.89362911264),
#  (73200.0, 91361.104000000021),
#  (75202.600000000006, 113998.89464579898),
#  (255000.0, 132608.10256570711),
#  (92000.0, 75070.037222222221),
#  (790000.0, 816760.86956521741),
#  (138000.0, 162009.09090909091),
#  (295000.0, 330470.93766364554),
#  (105800.0, 103887.89362911264),
#  (44584.309999999998, 57344.005617977535),
#  (360000.0, 148351.43528861154),
#  (149000.0, 133186.81597517731),
#  (180000.0, 198822.8672769953),
#  (55000.0, 85436.813223140489),
#  (140000.0, 103887.89362911264),
#  (120000.0, 142872.27545038165),
#  (220000.0, 315968.50783783779),
#  (190000.0, 375884.66363636364),
#  (330858.0, 257305.84743932041),
#  (374345.0, 528008.57941333333),
#  (290000.0, 139709.04546218488),
#  (220000.0, 202408.50464409724),
#  (1500000.0, 1566666.6666666667),
#  (49000.0, 71135.065070866171),
#  (670000.0, 486121.2121212121),
#  (130000.0, 120545.01425120777),
#  (235000.0, 299751.90880872484),
#  (830000.0, 874105.24017467245),
# %%
mean_squared_error(y_test, y_pred)
# Out:
# 174709.94793525207

# %%
def GradientBoost(x_train, x_test, y_train, y_test, k):
    graBoost = GradientBoostingRegressor(n_estimators= k, max_depth = 5, min_samples_split =2, learning_rate = 0.1, loss = 'ls')
    graBoost.fit(x_train, y_train)
    y_pred = graBoost.predict(x_test)
    return mean_squared_error(y_test, y_pred)

# %%
#Buscando la mejor cantidad de arboles ( usar 150 arboles, despues no mejora mucho)
resultados = []
for k in range(100, 201, 10): 
    resultados.append(GradientBoost(x_train, x_test, y_train, y_test, k ))

# %%
#Buscando la mejor configuracion de columnas
resultados = []

y = np.array(data['price_aprox_usd'])

for col in list_columnas:
    x = np.array(data.loc[:,col])
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=7)
    resultados.append(GradientBoost(x_train, x_test, y_train, y_test, 1))

# %%
resultados
# Out:
# [98323683088.513672,
#  98323683088.513657,
#  98324068309.421906,
#  98298937165.544281,
#  98298937165.544281,
#  101112830978.08922,
#  106020844298.07985,
#  106038530054.57251,
#  107576080716.69269,
#  108382722387.97682,
#  108760621106.44112]

# %%
columnas = ['created_on', 'property_type','pileta', 'lat', 'lon' ,'cochera', 'surface_total_in_m2',\
            'surface_covered_in_m2', 'seguridad', 'amenities','zona' ,\
            'subtes_cercanos', 'trenes_cercanos']

list_columnas = []

for i in range(1, len(columnas) - 1):
    list_columnas.append(columnas[:len(columnas) - i])
list_columnas
# Out:
# [['created_on',
#   'property_type',
#   'pileta',
#   'lat',
#   'lon',
#   'cochera',
#   'surface_total_in_m2',
#   'surface_covered_in_m2',
#   'seguridad',
#   'amenities',
#   'zona',
#   'subtes_cercanos'],
#  ['created_on',
#   'property_type',
#   'pileta',
#   'lat',
#   'lon',
#   'cochera',
#   'surface_total_in_m2',
#   'surface_covered_in_m2',
#   'seguridad',
#   'amenities',
#   'zona'],
#  ['created_on',
#   'property_type',
#   'pileta',
#   'lat',
#   'lon',
#   'cochera',
#   'surface_total_in_m2',
#   'surface_covered_in_m2',
#   'seguridad',
#   'amenities'],
#  ['created_on',
#   'property_type',
#   'pileta',
#   'lat',
#   'lon',
#   'cochera',
#   'surface_total_in_m2',
#   'surface_covered_in_m2',
#   'seguridad'],
#  ['created_on',
#   'property_type',
#   'pileta',
#   'lat',
#   'lon',
#   'cochera',
#   'surface_total_in_m2',
#   'surface_covered_in_m2'],
#  ['created_on',
#   'property_type',
#   'pileta',
#   'lat',
#   'lon',
#   'cochera',
#   'surface_total_in_m2'],
#  ['created_on', 'property_type', 'pileta', 'lat', 'lon', 'cochera'],
#  ['created_on', 'property_type', 'pileta', 'lat', 'lon'],
#  ['created_on', 'property_type', 'pileta', 'lat'],
#  ['created_on', 'property_type', 'pileta'],
#  ['created_on', 'property_type']]
