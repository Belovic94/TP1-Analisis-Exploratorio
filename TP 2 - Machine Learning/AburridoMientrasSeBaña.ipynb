# %%
import pandas as pd
import numpy as np

# %%
dataFiltrada = pd.read_csv("dataFiltrada.csv", low_memory = False)
noPrice = pd.read_csv("properati_dataset_testing_noprice.csv", low_memory = False)

# %%
dataFiltrada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46003 entries, 0 to 46002
# Data columns (total 22 columns):
# Unnamed: 0                 46003 non-null int64
# index                      46003 non-null int64
# created_on                 46003 non-null object
# operation                  46003 non-null object
# property_type              46003 non-null object
# state_name                 46003 non-null object
# place_name                 46003 non-null object
# lat                        46003 non-null float64
# lon                        46003 non-null float64
# price                      46003 non-null float64
# surface_total_in_m2        46003 non-null float64
# price_usd_per_m2           46003 non-null float64
# cant_prop                  46003 non-null float64
# media_por_barrio           46003 non-null float64
# mediana_por_barrio         46003 non-null float64
# geoPos                     46003 non-null object
# distancia_al_centro        46003 non-null float64
# distanciaAIndoamericano    46003 non-null float64
# distanciaAFuerteApache     46003 non-null float64
# distanciaACarlosGardel     46003 non-null float64
# cant_subtes_cercanos       46003 non-null int64
# cant_trenes_cercanos       46003 non-null int64
# dtypes: float64(12), int64(4), object(6)
# memory usage: 7.7+ MB

# %%
noPrice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14166 entries, 0 to 14165
# Data columns (total 17 columns):
# id                         14166 non-null int64
# created_on                 14166 non-null object
# property_type              14166 non-null object
# operation                  14166 non-null object
# place_name                 14166 non-null object
# place_with_parent_names    14166 non-null object
# country_name               14166 non-null object
# state_name                 14166 non-null object
# lat-lon                    10487 non-null object
# lat                        10487 non-null float64
# lon                        10487 non-null float64
# surface_total_in_m2        11853 non-null float64
# surface_covered_in_m2      13005 non-null float64
# floor                      1368 non-null float64
# rooms                      7500 non-null float64
# expenses                   2543 non-null object
# description                14166 non-null object
# dtypes: float64(6), int64(1), object(10)
# memory usage: 1.8+ MB

# %%
concatenado = pd.concat([dataFiltrada, noPrice], axis=0, ignore_index=True)
concatenado
# Out:
#        Unnamed: 0  cant_prop  cant_subtes_cercanos  cant_trenes_cercanos  \
# 0             0.0     1004.0                   0.0                   0.0
# 1             1.0     1004.0                   0.0                   0.0
# 2             2.0     1004.0                   0.0                   0.0
# 3             3.0     1004.0                   0.0                   0.0
# 4             4.0     1004.0                   0.0                   0.0
# 5             5.0     1004.0                   0.0                   0.0
# 6             6.0     1004.0                   0.0                   0.0
# 7             7.0     1004.0                   0.0                   0.0
# 8             8.0     1004.0                   0.0                   0.0
# 9             9.0     1004.0                   0.0                   0.0
# 10           10.0     1004.0                   0.0                   0.0
# 11           11.0     1004.0                   0.0                   0.0
# 12           12.0     1004.0                   0.0                   0.0
# 13           13.0     1004.0                   0.0                   0.0
# 14           14.0     1004.0                   0.0                   0.0
# 15           15.0     1004.0                   0.0                   0.0
# 16           16.0     1004.0                   0.0                   0.0
# 17           17.0     1004.0                   0.0                   0.0
# 18           18.0     1004.0                   0.0                   0.0
# 19           19.0     1004.0                   0.0                   0.0
# 20           20.0     1004.0                   0.0                   0.0
# 21           21.0     1004.0                   0.0                   0.0
# 22           22.0     1004.0                   0.0                   0.0
# 23           23.0     1004.0                   0.0                   0.0
# 24           24.0     1004.0                   0.0                   0.0
# 25           25.0     1004.0                   0.0                   0.0
# 26           26.0     1004.0                   0.0                   0.0
# 27           27.0     1004.0                   0.0                   0.0
# 28           28.0     1004.0                   0.0                   0.0
# 29           29.0     1004.0                   0.0                   0.0
# ...           ...        ...                   ...                   ...
# 60139         NaN        NaN                   NaN                   NaN
# 60140         NaN        NaN                   NaN                   NaN
# 60141         NaN        NaN                   NaN                   NaN
# 60142         NaN        NaN                   NaN                   NaN
# 60143         NaN        NaN                   NaN                   NaN
# 60144         NaN        NaN                   NaN                   NaN
# 60145         NaN        NaN                   NaN                   NaN
# 60146         NaN        NaN                   NaN                   NaN
# 60147         NaN        NaN                   NaN                   NaN
# 60148         NaN        NaN                   NaN                   NaN
# 60149         NaN        NaN                   NaN                   NaN
# 60150         NaN        NaN                   NaN                   NaN
# 60151         NaN        NaN                   NaN                   NaN
# 60152         NaN        NaN                   NaN                   NaN
# 60153         NaN        NaN                   NaN                   NaN
# 60154         NaN        NaN                   NaN                   NaN
# 60155         NaN        NaN                   NaN                   NaN
# 60156         NaN        NaN                   NaN                   NaN
# 60157         NaN        NaN                   NaN                   NaN
# 60158         NaN        NaN                   NaN                   NaN
# 60159         NaN        NaN                   NaN                   NaN
# 60160         NaN        NaN                   NaN                   NaN
# 60161         NaN        NaN                   NaN                   NaN
# 60162         NaN        NaN                   NaN                   NaN
# 60163         NaN        NaN                   NaN                   NaN
# 60164         NaN        NaN                   NaN                   NaN
# 60165         NaN        NaN                   NaN                   NaN
# 60166         NaN        NaN                   NaN                   NaN
# 60167         NaN        NaN                   NaN                   NaN
# 60168         NaN        NaN                   NaN                   NaN
#
#       country_name  created_on  \
# 0              NaN  2014-03-25
# 1              NaN  2014-03-25
# 2              NaN  2014-03-25
# 3              NaN  2014-03-25
# 4              NaN  2014-03-25
# 5              NaN  2014-03-25
# 6              NaN  2014-03-25
# 7              NaN  2014-03-25
# 8              NaN  2014-03-25
# 9              NaN  2014-03-25
# 10             NaN  2014-03-25
# 11             NaN  2014-03-25
# 12             NaN  2014-03-25
# 13             NaN  2014-03-25
# 14             NaN  2014-03-25
# 15             NaN  2014-03-25
# 16             NaN  2014-03-25
# 17             NaN  2014-03-25
# 18             NaN  2014-03-25
# 19             NaN  2014-03-25
# 20             NaN  2014-03-25
# 21             NaN  2014-03-25
# 22             NaN  2014-03-25
# 23             NaN  2014-06-09
# 24             NaN  2014-06-09
# 25             NaN  2014-06-09
# 26             NaN  2014-06-09
# 27             NaN  2014-11-27
# 28             NaN  2014-12-11
# 29             NaN  2015-03-01
# ...            ...         ...
# 60139    Argentina  2017-08-05
# 60140    Argentina  2017-08-26
# 60141    Argentina  2017-08-21
# 60142    Argentina  2017-08-13
# 60143    Argentina  2017-08-28
# 60144    Argentina  2017-08-14
# 60145    Argentina  2017-08-05
# 60146    Argentina  2017-08-12
# 60147    Argentina  2017-08-28
# 60148    Argentina  2017-08-05
# 60149    Argentina  2017-08-11
# 60150    Argentina  2017-08-09
# 60151    Argentina  2017-08-26
# 60152    Argentina  2017-08-07
# 60153    Argentina  2017-08-24
# 60154    Argentina  2017-08-05
# 60155    Argentina  2017-08-05
# 60156    Argentina  2017-08-05
# 60157    Argentina  2017-08-20
# 60158    Argentina  2017-08-03
# 60159    Argentina  2017-08-26
# 60160    Argentina  2017-08-26
# 60161    Argentina  2017-08-19
# 60162    Argentina  2017-08-06
# 60163    Argentina  2017-08-06
# 60164    Argentina  2017-08-01
# 60165    Argentina  2017-08-17
# 60166    Argentina  2017-08-01
# 60167    Argentina  2017-08-25
# 60168    Argentina  2017-08-12
#
#                                              description  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 60139  Corredor Responsable: Rebeca Stern - C.U.C.I.C...
# 60140  Corredor Responsable: Rebeca Stern - C.U.C.I.C...
# 60141  Corredor Responsable: Daniel Acosta - CUCICBA ...
# 60142  Corredor Responsable: Daniel Acosta - CUCICBA ...
# 60143  Corredor Responsable: Jorge Salafia - CUCICBA ...
# 60144  Corredor Responsable: Mariano Aufseher - CUCIC...
# 60145  Corredor Responsable: Fernando Muñoz - CUCICBA...
# 60146  Corredor Responsable: Fernando Muñoz - CUCICBA...
# 60147  Corredor Responsable: Ariel Champanier - CUCIC...
# 60148  Corredor Responsable: Win Bienes Raices SRL - ...
# 60149  Corredor Responsable: Win Bienes Raices SRL - ...
# 60150  Corredor Responsable: Laura Avellaneda - CUCIC...
# 60151  Corredor Responsable: Mónica Silvia Martinuzzi...
# 60152  Corredor Responsable: Marisol Espinosa - CMCPM...
# 60153  Corredor Responsable: Graciela Sanchez - CUCIC...
# 60154  Corredor Responsable: LEONEL D'ATRI - CUCICBA ...
# 60155  Corredor Responsable: Flavia Aguirre - C.U.C.I...
# 60156  Corredor Responsable: Franco Savone - CUCICBA ...
# 60157  Corredor Responsable: Franco Savone - CUCICBA ...
# 60158  CODIGO: 03 ubicado en: BELGRANO 2000 -  Public...
# 60159  CODIGO: 1179-DD391249 ubicado en: Bonifacini 4...
# 60160  CODIGO: 287-12 ubicado en: BRASIL 704 -  Publi...
# 60161  Venta de Departamento 2 AMBIENTES en Ramos Mej...
# 60162  Venta de Departamento 3 AMBIENTES en Palermo S...
# 60163  Venta de Departamento 3 AMBIENTES en Palermo S...
# 60164  Edificio."Terrazas del Dique".Al Frente.Balcón...
# 60165  Venta de imperdible  PH  con patio  2 AMBIENTE...
# 60166  Venta de Casa 4 AMBIENTES en Lomas de Zamora, ...
# 60167  DEPARTAMENTO  EN VENTA / ALQUILER  | BELGRANO ...
# 60168  Venta de Chalet 4 AMBIENTES en CIRCUNSCRIPCIÓN...
#
#        distanciaACarlosGardel  distanciaAFuerteApache  \
# 0                35302.675135            37957.493256
# 1                31958.058490            34566.588870
# 2                28822.768850            31012.749860
# 3                39911.653815            42981.839727
# 4                35619.815135            38506.133573
# 5                35619.815135            38506.133573
# 6                35619.815135            38506.133573
# 7                35619.815135            38506.133573
# 8                35619.815135            38506.133573
# 9                35619.815135            38506.133573
# 10               35619.815135            38506.133573
# 11               35619.815135            38506.133573
# 12               35619.815135            38506.133573
# 13               35619.815135            38506.133573
# 14               35619.815135            38506.133573
# 15               31160.849778            33968.196055
# 16               39667.809009            42612.806051
# 17               35340.609024            38224.224055
# 18               28156.198028            30344.259993
# 19               39667.809009            42612.806051
# 20               35619.815135            38506.133573
# 21               32619.604723            34510.107212
# 22               35845.111248            38806.274578
# 23               35657.103295            38529.285627
# 24               32150.722170            34694.864413
# 25               32144.844882            34789.081058
# 26               30633.601216            33074.726603
# 27               36974.259249            39883.434279
# 28               31483.400085            34105.483374
# 29               37696.788254            40550.068785
# ...                       ...                     ...
# 60139                     NaN                     NaN
# 60140                     NaN                     NaN
# 60141                     NaN                     NaN
# 60142                     NaN                     NaN
# 60143                     NaN                     NaN
# 60144                     NaN                     NaN
# 60145                     NaN                     NaN
# 60146                     NaN                     NaN
# 60147                     NaN                     NaN
# 60148                     NaN                     NaN
# 60149                     NaN                     NaN
# 60150                     NaN                     NaN
# 60151                     NaN                     NaN
# 60152                     NaN                     NaN
# 60153                     NaN                     NaN
# 60154                     NaN                     NaN
# 60155                     NaN                     NaN
# 60156                     NaN                     NaN
# 60157                     NaN                     NaN
# 60158                     NaN                     NaN
# 60159                     NaN                     NaN
# 60160                     NaN                     NaN
# 60161                     NaN                     NaN
# 60162                     NaN                     NaN
# 60163                     NaN                     NaN
# 60164                     NaN                     NaN
# 60165                     NaN                     NaN
# 60166                     NaN                     NaN
# 60167                     NaN                     NaN
# 60168                     NaN                     NaN
#
#        distanciaAIndoamericano         ...           operation  \
# 0                 46042.422605         ...                sell
# 1                 42653.282345         ...                sell
# 2                 39028.318594         ...                sell
# 3                 50893.403467         ...                sell
# 4                 46536.173643         ...                sell
# 5                 46536.173643         ...                sell
# 6                 46536.173643         ...                sell
# 7                 46536.173643         ...                sell
# 8                 46536.173643         ...                sell
# 9                 46536.173643         ...                sell
# 10                46536.173643         ...                sell
# 11                46536.173643         ...                sell
# 12                46536.173643         ...                sell
# 13                46536.173643         ...                sell
# 14                46536.173643         ...                sell
# 15                42024.986424         ...                sell
# 16                50615.022219         ...                sell
# 17                46255.331782         ...                sell
# 18                38360.445651         ...                sell
# 19                50615.022219         ...                sell
# 20                46536.173643         ...                sell
# 21                42380.869540         ...                sell
# 22                46798.137173         ...                sell
# 23                46565.257505         ...                sell
# 24                42780.549470         ...                sell
# 25                42874.306230         ...                sell
# 26                41150.557001         ...                sell
# 27                47903.493389         ...                sell
# 28                42191.746998         ...                sell
# 29                48594.007119         ...                sell
# ...                        ...         ...                 ...
# 60139                      NaN         ...               venta
# 60140                      NaN         ...               venta
# 60141                      NaN         ...               venta
# 60142                      NaN         ...               venta
# 60143                      NaN         ...               venta
# 60144                      NaN         ...               venta
# 60145                      NaN         ...               venta
# 60146                      NaN         ...               venta
# 60147                      NaN         ...               venta
# 60148                      NaN         ...               venta
# 60149                      NaN         ...               venta
# 60150                      NaN         ...               venta
# 60151                      NaN         ...               venta
# 60152                      NaN         ...               venta
# 60153                      NaN         ...               venta
# 60154                      NaN         ...               venta
# 60155                      NaN         ...               venta
# 60156                      NaN         ...               venta
# 60157                      NaN         ...               venta
# 60158                      NaN         ...               venta
# 60159                      NaN         ...               venta
# 60160                      NaN         ...               venta
# 60161                      NaN         ...               venta
# 60162                      NaN         ...               venta
# 60163                      NaN         ...               venta
# 60164                      NaN         ...               venta
# 60165                      NaN         ...               venta
# 60166                      NaN         ...               venta
# 60167                      NaN         ...               venta
# 60168                      NaN         ...               venta
#
#              place_name                            place_with_parent_names  \
# 0                 Pilar                                                NaN
# 1                 Pilar                                                NaN
# 2                 Pilar                                                NaN
# 3                 Pilar                                                NaN
# 4                 Pilar                                                NaN
# 5                 Pilar                                                NaN
# 6                 Pilar                                                NaN
# 7                 Pilar                                                NaN
# 8                 Pilar                                                NaN
# 9                 Pilar                                                NaN
# 10                Pilar                                                NaN
# 11                Pilar                                                NaN
# 12                Pilar                                                NaN
# 13                Pilar                                                NaN
# 14                Pilar                                                NaN
# 15                Pilar                                                NaN
# 16                Pilar                                                NaN
# 17                Pilar                                                NaN
# 18                Pilar                                                NaN
# 19                Pilar                                                NaN
# 20                Pilar                                                NaN
# 21                Pilar                                                NaN
# 22                Pilar                                                NaN
# 23                Pilar                                                NaN
# 24                Pilar                                                NaN
# 25                Pilar                                                NaN
# 26                Pilar                                                NaN
# 27                Pilar                                                NaN
# 28                Pilar                                                NaN
# 29                Pilar                                                NaN
# ...                 ...                                                ...
# 60139     San Cristobal          |Argentina|Capital Federal|San Cristobal|
# 60140            Flores                 |Argentina|Capital Federal|Flores|
# 60141            Retiro                 |Argentina|Capital Federal|Retiro|
# 60142        Colegiales             |Argentina|Capital Federal|Colegiales|
# 60143             Nuñez                  |Argentina|Capital Federal|Nuñez|
# 60144           Palermo                |Argentina|Capital Federal|Palermo|
# 60145  Parque Patricios       |Argentina|Capital Federal|Parque Patricios|
# 60146        Colegiales             |Argentina|Capital Federal|Colegiales|
# 60147      Villa Devoto           |Argentina|Capital Federal|Villa Devoto|
# 60148         Ciudadela  |Argentina|Bs.As. G.B.A. Zona Oeste|Tres de Fe...
# 60149     Villa Urquiza          |Argentina|Capital Federal|Villa Urquiza|
# 60150          Barracas               |Argentina|Capital Federal|Barracas|
# 60151  Villa Santa Rita       |Argentina|Capital Federal|Villa Santa Rita|
# 60152             Haedo   |Argentina|Bs.As. G.B.A. Zona Oeste|Morón|Haedo|
# 60153        Villa Luro             |Argentina|Capital Federal|Villa Luro|
# 60154         Balvanera              |Argentina|Capital Federal|Balvanera|
# 60155           Almagro                |Argentina|Capital Federal|Almagro|
# 60156         Monserrat              |Argentina|Capital Federal|Monserrat|
# 60157          Belgrano               |Argentina|Capital Federal|Belgrano|
# 60158        Longchamps  |Argentina|Bs.As. G.B.A. Zona Sur|Almirante Br...
# 60159           Caseros  |Argentina|Bs.As. G.B.A. Zona Oeste|Tres de Fe...
# 60160   Villa Sarmiento  |Argentina|Bs.As. G.B.A. Zona Oeste|Morón|Vill...
# 60161       Ramos Mejía  |Argentina|Bs.As. G.B.A. Zona Oeste|La Matanza...
# 60162      Palermo Soho   |Argentina|Capital Federal|Palermo|Palermo Soho|
# 60163      Palermo Soho   |Argentina|Capital Federal|Palermo|Palermo Soho|
# 60164     Puerto Madero          |Argentina|Capital Federal|Puerto Madero|
# 60165         Temperley  |Argentina|Bs.As. G.B.A. Zona Sur|Lomas de Zam...
# 60166   Lomas de Zamora  |Argentina|Bs.As. G.B.A. Zona Sur|Lomas de Zam...
# 60167          Belgrano               |Argentina|Capital Federal|Belgrano|
# 60168      Ciudad Evita  |Argentina|Bs.As. G.B.A. Zona Oeste|La Matanza...
#
#           price  price_usd_per_m2  property_type  rooms  \
# 0      230000.0        319.444444          house    NaN
# 1      220000.0       1375.000000          house    NaN
# 2      210000.0       1166.666667          house    NaN
# 3      590000.0       1247.357294          house    NaN
# 4      172000.0        226.315789          house    NaN
# 5      338000.0        393.023256          house    NaN
# 6      195000.0        299.079755          house    NaN
# 7      320000.0        400.000000          house    NaN
# 8      198000.0        246.268657          house    NaN
# 9      355000.0        412.790698          house    NaN
# 10     265000.0        363.013699          house    NaN
# 11     449000.0        513.142857          house    NaN
# 12     485000.0        577.380952          house    NaN
# 13      97000.0       1763.636364      apartment    NaN
# 14     110000.0       2037.037037      apartment    NaN
# 15     290000.0        805.555556          house    NaN
# 16     350000.0       1166.666667          house    NaN
# 17     295000.0       1229.166667          house    NaN
# 18     260000.0       1444.444444          house    NaN
# 19     350000.0       1458.333333          house    NaN
# 20      90000.0       1058.823529          house    NaN
# 21     153000.0        577.358491          house    NaN
# 22      65000.0        325.000000      apartment    NaN
# 23      82000.0       1281.250000      apartment    NaN
# 24      59000.0       1311.111111      apartment    NaN
# 25     320000.0       1333.333333          house    NaN
# 26     265000.0       1472.222222          house    NaN
# 27     100000.0        588.235294          house    NaN
# 28      88000.0       1571.428571      apartment    NaN
# 29     140000.0        148.305085          house    NaN
# ...         ...               ...            ...    ...
# 60139       NaN               NaN   departamento    3.0
# 60140       NaN               NaN   departamento    2.0
# 60141       NaN               NaN   departamento    3.0
# 60142       NaN               NaN   departamento    3.0
# 60143       NaN               NaN   departamento    2.0
# 60144       NaN               NaN   departamento    4.0
# 60145       NaN               NaN             ph    3.0
# 60146       NaN               NaN   departamento    2.0
# 60147       NaN               NaN             ph    3.0
# 60148       NaN               NaN             ph    4.0
# 60149       NaN               NaN   departamento    2.0
# 60150       NaN               NaN   departamento    3.0
# 60151       NaN               NaN             ph    4.0
# 60152       NaN               NaN             ph    6.0
# 60153       NaN               NaN             ph    2.0
# 60154       NaN               NaN   departamento    4.0
# 60155       NaN               NaN   departamento    3.0
# 60156       NaN               NaN             ph    5.0
# 60157       NaN               NaN           casa    9.0
# 60158       NaN               NaN           casa    NaN
# 60159       NaN               NaN           casa    NaN
# 60160       NaN               NaN   departamento    NaN
# 60161       NaN               NaN             ph    2.0
# 60162       NaN               NaN   departamento    3.0
# 60163       NaN               NaN   departamento    3.0
# 60164       NaN               NaN   departamento    NaN
# 60165       NaN               NaN             ph    2.0
# 60166       NaN               NaN           casa    NaN
# 60167       NaN               NaN   departamento    NaN
# 60168       NaN               NaN           casa    4.0
#
#                      state_name  surface_covered_in_m2  surface_total_in_m2
# 0      Bs.As. G.B.A. Zona Norte                    NaN                720.0
# 1      Bs.As. G.B.A. Zona Norte                    NaN                160.0
# 2      Bs.As. G.B.A. Zona Norte                    NaN                180.0
# 3      Bs.As. G.B.A. Zona Norte                    NaN                473.0
# 4      Bs.As. G.B.A. Zona Norte                    NaN                760.0
# 5      Bs.As. G.B.A. Zona Norte                    NaN                860.0
# 6      Bs.As. G.B.A. Zona Norte                    NaN                652.0
# 7      Bs.As. G.B.A. Zona Norte                    NaN                800.0
# 8      Bs.As. G.B.A. Zona Norte                    NaN                804.0
# 9      Bs.As. G.B.A. Zona Norte                    NaN                860.0
# 10     Bs.As. G.B.A. Zona Norte                    NaN                730.0
# 11     Bs.As. G.B.A. Zona Norte                    NaN                875.0
# 12     Bs.As. G.B.A. Zona Norte                    NaN                840.0
# 13     Bs.As. G.B.A. Zona Norte                    NaN                 55.0
# 14     Bs.As. G.B.A. Zona Norte                    NaN                 54.0
# 15     Bs.As. G.B.A. Zona Norte                    NaN                360.0
# 16     Bs.As. G.B.A. Zona Norte                    NaN                300.0
# 17     Bs.As. G.B.A. Zona Norte                    NaN                240.0
# 18     Bs.As. G.B.A. Zona Norte                    NaN                180.0
# 19     Bs.As. G.B.A. Zona Norte                    NaN                240.0
# 20     Bs.As. G.B.A. Zona Norte                    NaN                 85.0
# 21     Bs.As. G.B.A. Zona Norte                    NaN                265.0
# 22     Bs.As. G.B.A. Zona Norte                    NaN                200.0
# 23     Bs.As. G.B.A. Zona Norte                    NaN                 64.0
# 24     Bs.As. G.B.A. Zona Norte                    NaN                 45.0
# 25     Bs.As. G.B.A. Zona Norte                    NaN                240.0
# 26     Bs.As. G.B.A. Zona Norte                    NaN                180.0
# 27     Bs.As. G.B.A. Zona Norte                    NaN                170.0
# 28     Bs.As. G.B.A. Zona Norte                    NaN                 56.0
# 29     Bs.As. G.B.A. Zona Norte                    NaN                944.0
# ...                         ...                    ...                  ...
# 60139           Capital Federal                   52.0                 55.0
# 60140           Capital Federal                   32.0                 32.0
# 60141           Capital Federal                   69.0                 69.0
# 60142           Capital Federal                   73.0                 73.0
# 60143           Capital Federal                   40.0                 45.0
# 60144           Capital Federal                   72.0                 80.0
# 60145           Capital Federal                   79.0                 84.0
# 60146           Capital Federal                   46.0                 46.0
# 60147           Capital Federal                  116.0                129.0
# 60148  Bs.As. G.B.A. Zona Oeste                  123.0                123.0
# 60149           Capital Federal                    3.0                 41.0
# 60150           Capital Federal                   58.0                 58.0
# 60151           Capital Federal                   57.0                101.0
# 60152  Bs.As. G.B.A. Zona Oeste                  120.0                132.0
# 60153           Capital Federal                   52.0                 59.0
# 60154           Capital Federal                   92.0                 94.0
# 60155           Capital Federal                   59.0                 74.0
# 60156           Capital Federal                  116.0                116.0
# 60157           Capital Federal                  373.0                475.0
# 60158    Bs.As. G.B.A. Zona Sur                  120.0                285.0
# 60159  Bs.As. G.B.A. Zona Oeste                  108.0                153.0
# 60160  Bs.As. G.B.A. Zona Oeste                   40.0                 82.0
# 60161  Bs.As. G.B.A. Zona Oeste                    NaN                 42.0
# 60162           Capital Federal                   60.0                 60.0
# 60163           Capital Federal                   60.0                 60.0
# 60164           Capital Federal                   96.0                109.0
# 60165    Bs.As. G.B.A. Zona Sur                   26.0                 38.0
# 60166    Bs.As. G.B.A. Zona Sur                  135.0                219.0
# 60167           Capital Federal                   48.0                 62.0
# 60168  Bs.As. G.B.A. Zona Oeste                  130.0                367.0
#
# [60169 rows x 31 columns]

# %%
concatenado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60169 entries, 0 to 60168
# Data columns (total 31 columns):
# Unnamed: 0                 46003 non-null float64
# cant_prop                  46003 non-null float64
# cant_subtes_cercanos       46003 non-null float64
# cant_trenes_cercanos       46003 non-null float64
# country_name               14166 non-null object
# created_on                 60169 non-null object
# description                14166 non-null object
# distanciaACarlosGardel     46003 non-null float64
# distanciaAFuerteApache     46003 non-null float64
# distanciaAIndoamericano    46003 non-null float64
# distancia_al_centro        46003 non-null float64
# expenses                   2543 non-null object
# floor                      1368 non-null float64
# geoPos                     46003 non-null object
# id                         14166 non-null float64
# index                      46003 non-null float64
# lat                        56490 non-null float64
# lat-lon                    10487 non-null object
# lon                        56490 non-null float64
# media_por_barrio           46003 non-null float64
# mediana_por_barrio         46003 non-null float64
# operation                  60169 non-null object
# place_name                 60169 non-null object
# place_with_parent_names    14166 non-null object
# price                      46003 non-null float64
# price_usd_per_m2           46003 non-null float64
# property_type              60169 non-null object
# rooms                      7500 non-null float64
# state_name                 60169 non-null object
# surface_covered_in_m2      13005 non-null float64
# surface_total_in_m2        57856 non-null float64
# dtypes: float64(20), object(11)
# memory usage: 14.2+ MB

# %%
concatenado.dropna(inplace=True, subset=['surface_covered_in_m2', 'surface_total_in_m2'], how='all')
concatenado.tail(20)
# Out:
#        Unnamed: 0  cant_prop  cant_subtes_cercanos  cant_trenes_cercanos  \
# 60149         NaN        NaN                   NaN                   NaN
# 60150         NaN        NaN                   NaN                   NaN
# 60151         NaN        NaN                   NaN                   NaN
# 60152         NaN        NaN                   NaN                   NaN
# 60153         NaN        NaN                   NaN                   NaN
# 60154         NaN        NaN                   NaN                   NaN
# 60155         NaN        NaN                   NaN                   NaN
# 60156         NaN        NaN                   NaN                   NaN
# 60157         NaN        NaN                   NaN                   NaN
# 60158         NaN        NaN                   NaN                   NaN
# 60159         NaN        NaN                   NaN                   NaN
# 60160         NaN        NaN                   NaN                   NaN
# 60161         NaN        NaN                   NaN                   NaN
# 60162         NaN        NaN                   NaN                   NaN
# 60163         NaN        NaN                   NaN                   NaN
# 60164         NaN        NaN                   NaN                   NaN
# 60165         NaN        NaN                   NaN                   NaN
# 60166         NaN        NaN                   NaN                   NaN
# 60167         NaN        NaN                   NaN                   NaN
# 60168         NaN        NaN                   NaN                   NaN
#
#       country_name  created_on  \
# 60149    Argentina  2017-08-11
# 60150    Argentina  2017-08-09
# 60151    Argentina  2017-08-26
# 60152    Argentina  2017-08-07
# 60153    Argentina  2017-08-24
# 60154    Argentina  2017-08-05
# 60155    Argentina  2017-08-05
# 60156    Argentina  2017-08-05
# 60157    Argentina  2017-08-20
# 60158    Argentina  2017-08-03
# 60159    Argentina  2017-08-26
# 60160    Argentina  2017-08-26
# 60161    Argentina  2017-08-19
# 60162    Argentina  2017-08-06
# 60163    Argentina  2017-08-06
# 60164    Argentina  2017-08-01
# 60165    Argentina  2017-08-17
# 60166    Argentina  2017-08-01
# 60167    Argentina  2017-08-25
# 60168    Argentina  2017-08-12
#
#                                              description  \
# 60149  Corredor Responsable: Win Bienes Raices SRL - ...
# 60150  Corredor Responsable: Laura Avellaneda - CUCIC...
# 60151  Corredor Responsable: Mónica Silvia Martinuzzi...
# 60152  Corredor Responsable: Marisol Espinosa - CMCPM...
# 60153  Corredor Responsable: Graciela Sanchez - CUCIC...
# 60154  Corredor Responsable: LEONEL D'ATRI - CUCICBA ...
# 60155  Corredor Responsable: Flavia Aguirre - C.U.C.I...
# 60156  Corredor Responsable: Franco Savone - CUCICBA ...
# 60157  Corredor Responsable: Franco Savone - CUCICBA ...
# 60158  CODIGO: 03 ubicado en: BELGRANO 2000 -  Public...
# 60159  CODIGO: 1179-DD391249 ubicado en: Bonifacini 4...
# 60160  CODIGO: 287-12 ubicado en: BRASIL 704 -  Publi...
# 60161  Venta de Departamento 2 AMBIENTES en Ramos Mej...
# 60162  Venta de Departamento 3 AMBIENTES en Palermo S...
# 60163  Venta de Departamento 3 AMBIENTES en Palermo S...
# 60164  Edificio."Terrazas del Dique".Al Frente.Balcón...
# 60165  Venta de imperdible  PH  con patio  2 AMBIENTE...
# 60166  Venta de Casa 4 AMBIENTES en Lomas de Zamora, ...
# 60167  DEPARTAMENTO  EN VENTA / ALQUILER  | BELGRANO ...
# 60168  Venta de Chalet 4 AMBIENTES en CIRCUNSCRIPCIÓN...
#
#        distanciaACarlosGardel  distanciaAFuerteApache  \
# 60149                     NaN                     NaN
# 60150                     NaN                     NaN
# 60151                     NaN                     NaN
# 60152                     NaN                     NaN
# 60153                     NaN                     NaN
# 60154                     NaN                     NaN
# 60155                     NaN                     NaN
# 60156                     NaN                     NaN
# 60157                     NaN                     NaN
# 60158                     NaN                     NaN
# 60159                     NaN                     NaN
# 60160                     NaN                     NaN
# 60161                     NaN                     NaN
# 60162                     NaN                     NaN
# 60163                     NaN                     NaN
# 60164                     NaN                     NaN
# 60165                     NaN                     NaN
# 60166                     NaN                     NaN
# 60167                     NaN                     NaN
# 60168                     NaN                     NaN
#
#        distanciaAIndoamericano         ...           operation  \
# 60149                      NaN         ...               venta
# 60150                      NaN         ...               venta
# 60151                      NaN         ...               venta
# 60152                      NaN         ...               venta
# 60153                      NaN         ...               venta
# 60154                      NaN         ...               venta
# 60155                      NaN         ...               venta
# 60156                      NaN         ...               venta
# 60157                      NaN         ...               venta
# 60158                      NaN         ...               venta
# 60159                      NaN         ...               venta
# 60160                      NaN         ...               venta
# 60161                      NaN         ...               venta
# 60162                      NaN         ...               venta
# 60163                      NaN         ...               venta
# 60164                      NaN         ...               venta
# 60165                      NaN         ...               venta
# 60166                      NaN         ...               venta
# 60167                      NaN         ...               venta
# 60168                      NaN         ...               venta
#
#              place_name                            place_with_parent_names  \
# 60149     Villa Urquiza          |Argentina|Capital Federal|Villa Urquiza|
# 60150          Barracas               |Argentina|Capital Federal|Barracas|
# 60151  Villa Santa Rita       |Argentina|Capital Federal|Villa Santa Rita|
# 60152             Haedo   |Argentina|Bs.As. G.B.A. Zona Oeste|Morón|Haedo|
# 60153        Villa Luro             |Argentina|Capital Federal|Villa Luro|
# 60154         Balvanera              |Argentina|Capital Federal|Balvanera|
# 60155           Almagro                |Argentina|Capital Federal|Almagro|
# 60156         Monserrat              |Argentina|Capital Federal|Monserrat|
# 60157          Belgrano               |Argentina|Capital Federal|Belgrano|
# 60158        Longchamps  |Argentina|Bs.As. G.B.A. Zona Sur|Almirante Br...
# 60159           Caseros  |Argentina|Bs.As. G.B.A. Zona Oeste|Tres de Fe...
# 60160   Villa Sarmiento  |Argentina|Bs.As. G.B.A. Zona Oeste|Morón|Vill...
# 60161       Ramos Mejía  |Argentina|Bs.As. G.B.A. Zona Oeste|La Matanza...
# 60162      Palermo Soho   |Argentina|Capital Federal|Palermo|Palermo Soho|
# 60163      Palermo Soho   |Argentina|Capital Federal|Palermo|Palermo Soho|
# 60164     Puerto Madero          |Argentina|Capital Federal|Puerto Madero|
# 60165         Temperley  |Argentina|Bs.As. G.B.A. Zona Sur|Lomas de Zam...
# 60166   Lomas de Zamora  |Argentina|Bs.As. G.B.A. Zona Sur|Lomas de Zam...
# 60167          Belgrano               |Argentina|Capital Federal|Belgrano|
# 60168      Ciudad Evita  |Argentina|Bs.As. G.B.A. Zona Oeste|La Matanza...
#
#       price  price_usd_per_m2  property_type  rooms                state_name  \
# 60149   NaN               NaN   departamento    2.0           Capital Federal
# 60150   NaN               NaN   departamento    3.0           Capital Federal
# 60151   NaN               NaN             ph    4.0           Capital Federal
# 60152   NaN               NaN             ph    6.0  Bs.As. G.B.A. Zona Oeste
# 60153   NaN               NaN             ph    2.0           Capital Federal
# 60154   NaN               NaN   departamento    4.0           Capital Federal
# 60155   NaN               NaN   departamento    3.0           Capital Federal
# 60156   NaN               NaN             ph    5.0           Capital Federal
# 60157   NaN               NaN           casa    9.0           Capital Federal
# 60158   NaN               NaN           casa    NaN    Bs.As. G.B.A. Zona Sur
# 60159   NaN               NaN           casa    NaN  Bs.As. G.B.A. Zona Oeste
# 60160   NaN               NaN   departamento    NaN  Bs.As. G.B.A. Zona Oeste
# 60161   NaN               NaN             ph    2.0  Bs.As. G.B.A. Zona Oeste
# 60162   NaN               NaN   departamento    3.0           Capital Federal
# 60163   NaN               NaN   departamento    3.0           Capital Federal
# 60164   NaN               NaN   departamento    NaN           Capital Federal
# 60165   NaN               NaN             ph    2.0    Bs.As. G.B.A. Zona Sur
# 60166   NaN               NaN           casa    NaN    Bs.As. G.B.A. Zona Sur
# 60167   NaN               NaN   departamento    NaN           Capital Federal
# 60168   NaN               NaN           casa    4.0  Bs.As. G.B.A. Zona Oeste
#
#        surface_covered_in_m2  surface_total_in_m2
# 60149                    3.0                 41.0
# 60150                   58.0                 58.0
# 60151                   57.0                101.0
# 60152                  120.0                132.0
# 60153                   52.0                 59.0
# 60154                   92.0                 94.0
# 60155                   59.0                 74.0
# 60156                  116.0                116.0
# 60157                  373.0                475.0
# 60158                  120.0                285.0
# 60159                  108.0                153.0
# 60160                   40.0                 82.0
# 60161                    NaN                 42.0
# 60162                   60.0                 60.0
# 60163                   60.0                 60.0
# 60164                   96.0                109.0
# 60165                   26.0                 38.0
# 60166                  135.0                219.0
# 60167                   48.0                 62.0
# 60168                  130.0                367.0
#
# [20 rows x 31 columns]
